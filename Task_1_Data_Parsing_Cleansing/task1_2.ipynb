# %% [markdown]
# # Assignment 1: Data Parsing, Cleansing and Integration
# ## Task 1 and 2
# #### Student Name: Toh Kah Hie
# #### Student ID: s3936897
#
# Date: 12/08/2022
#
# Version: 1.0
#
# Environment: Python 3 and Jupyter notebook
#
# Libraries used:
# * pandas
# * re
# * numpy
# * sklearn
# * itertools
# * matplotlib
# * datetime
# * xml
# * difflib
# * Counter
# * england (External .py created)
#
# ## Introduction
# This assessment provides students with hands on experience with parsing and cleaning a dataset. First, given an xml file, the internal structure is carefully studied and all necessary information are extracted and gathered into a DataFrame. After that, data cleaning and formatting is performed to remove any duplicates, errors and fill in some null values. The cleaned dataset would then be saved into a csv file.

# %% [markdown]
# ## Importing libraries

# %%
import xml.etree.ElementTree as etree
from itertools import chain
from collections import Counter
import pandas as pd
import re
import datetime
import england
import matplotlib.pyplot as plt
import numpy as np
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
import difflib
from matplotlib.cbook import boxplot_stats

# %% [markdown]
# ## Task 1. Parsing Data

# %% [markdown]
# ### 1.1. Examining and loading data

# %% [markdown]
# ![Heading of the xml file](img/xml_header.jpg)
# From a basic glance at the xml file in Notepad++, it can be seen the data is contained in \<JobAd\> and is nested under 2 tags \<Records\> \> \<Src\>
#
# ![Body of the xml file](img/xml_body.jpg)
# Looking at the \<JobAd\>s it can be seen that (for now) every tag has attributes **OpenDate** and **CloseDate**, and their children tags include:
# <ul>
# <li>&lt;Id&gt;</li>
# <li>&lt;Title&gt;</li>
# <li>&lt;Location&gt;</li>
# <li>&lt;Company&gt;</li>
# <li>&lt;ContractTime&gt;</li>
# <li>&lt;Category&gt;</li>
# <li>&lt;Salary&gt;</li>
# </ul>
#
# Additionally, all children tags contain **Character Data** (\<![CDATA[]]\>), by which these data would not be parsed by the xml parser.

# %%
# Parse the xml file using ElementTree
tree = etree.parse("./s3936897_dataset1.xml")

# %%
# Get the root of the tree, which should be <Records>
root = tree.getroot()
print("Root tag: ",root.tag)

# Under the root tag, surprisingly there is 107 children and they are all under the tag 'Src'
print("Number of children of root: ",len(root))
print("Child tags contain: ",set([child.tag for child in root]))
print('Number of nested tag under all <Src>s: ',Counter(chain.from_iterable([[children.tag for children in c] for c in root])))
# Out:
# Root tag:  Records
# Number of children of root:  107
# Child tags contain:  {'Src'}
# Number of nested tag under all <Src>s:  Counter({'JobAd': 50753, 'SourceName': 107})

# %%
# It is then hypothesized that there are several <JobAd>s under each <Src>
# Each children under each child of root is counted
print('Number of elements under root: ',len(root))
jb_ad_count = 0
print("\nFirst few <JobAD>s: ")

# For <Src> in root
for child in root:
    # Print first few <JobAd>
    if jb_ad_count <1000:
        print('Number of elements under ',child.tag,': ',len(child))
    
    # Counter to count number of nested tag for <Src>
    counter = Counter([nested.tag for nested in child])
    for key in counter.keys():
        # Print first few nested Tags
        if jb_ad_count <1000:
            print("Number of occurence of tag ",key,": ",counter[key])
        
        # Count the total number of <JobAd>
        if key == 'JobAd':
            jb_ad_count += counter[key]
            
    # Print first few <JobAd>        
    if jb_ad_count <1000:
        print("\n")
        
# Total number of <JobAd> present
print('\nNumber of <JobAd>s: ',jb_ad_count)
# Out:
# Number of elements under root:  107
#
# First few <JobAD>s:
# Number of elements under  Src :  659
# Number of occurence of tag  SourceName :  1
# Number of occurence of tag  JobAd :  658
#
#
# Number of elements under  Src :  7161
# Number of occurence of tag  SourceName :  1
# Number of occurence of tag  JobAd :  7160
#
# Number of <JobAd>s:  50753

# %% [markdown]
# From the output above, it can be seen that there are a total of 50,573 \<JobAd\> tags and under each child \<Src\> there is 1 \<SourceName\> and several \<JobAd\>s. Now we will look at the child's attributes

# %%
#Get child tags present in each children tag
print("Child tags present in nested tags (tag,nested_tag): \n",set(chain.from_iterable([[(child_elements.tag,children.tag) for children in child_elements] for child_elements in child for child in root])))

print("\nAttributes for each tag (tag,attributes): ",set(chain.from_iterable([[(ch.tag,frozenset(ch.attrib.keys())) for ch in c] for c in root])))
# Out:
# Child tags present in nested tags (tag,nested_tag):
#  {('JobAd', 'Salary'), ('JobAd', 'ContractType'), ('JobAd', 'ContractTime'), ('JobAd', 'Category'), ('JobAd', 'Id'), ('JobAd', 'Title'), ('JobAd', 'Location'), ('JobAd', 'Company')}
#
# Attributes for each tag (tag,attributes):  {('SourceName', frozenset()), ('JobAd', frozenset({'OpenDate', 'CloseDate'}))}

# %% [markdown]
# From here it can be seen that nested tags of \<JobAd\> includes 8 tags and 2 attributes (shown above) while \<SourceName\> contains no nested tags or attributes

# %%
limit = 5
i = 0
for children in root:
    # Print number of nested tags under <Src>
    counter = Counter(nested.tag for nested in children)
    
    # Print number of nested tags under child of <Src>
    ncounter = Counter(chain.from_iterable([[b.tag for b in a] for a in children]))
    
    val = list(ncounter.values())
    # If not all counts are the same means that there are values missing, print the first 5 with missing data
    if i < limit and not all(element == val[0] for element in val):
        print(counter)
        print(ncounter)
        print('\n')
        i += 1
# Out:
# Counter({'JobAd': 658, 'SourceName': 1})
# Counter({'Id': 658, 'Title': 658, 'Location': 658, 'Company': 658, 'Category': 658, 'Salary': 625, 'ContractTime': 441})
#
#
# Counter({'JobAd': 970, 'SourceName': 1})
# Counter({'Id': 970, 'Title': 970, 'Location': 970, 'Category': 970, 'ContractTime': 966, 'Salary': 924, 'ContractType': 909, 'Company': 850})
#
#
# Counter({'JobAd': 9224, 'SourceName': 1})
# Counter({'Id': 9224, 'Title': 9224, 'Location': 9224, 'Company': 9224, 'Category': 9224, 'Salary': 9224, 'ContractTime': 9085, 'ContractType': 139})
#
#
# Counter({'JobAd': 434, 'SourceName': 1})
# Counter({'Id': 434, 'Title': 434, 'Location': 434, 'ContractTime': 434, 'Category': 434, 'Salary': 417})
#
#
# Counter({'JobAd': 2536, 'SourceName': 1})
# Counter({'Id': 2536, 'Title': 2536, 'Location': 2536, 'Category': 2536, 'Salary': 2536, 'Company': 2527, 'ContractType': 2368, 'ContractTime': 168})

# %% [markdown]
# From a number of counts above, it can be see that under \<JobAd\>, not all contains all tags listed previously

# %% [markdown]
# ### 1.2 Parsing data into the required format

# %%
# Initialize a dictionary to store all data collected from the xml
dataDict = {}
dataDict['Id'] = []
dataDict['Title'] = []
dataDict['Location'] = []
dataDict['Company'] = []
dataDict['ContractType'] = []
dataDict['ContractTime'] = []
dataDict['Category'] = []
dataDict['Salary'] = []
dataDict['OpenDate'] = []
dataDict['CloseDate'] = []
dataDict['SourceName'] = []

for elem in tree.findall('Src'):
    for child in elem.findall('JobAd'):
        # Attributes
        dataDict['OpenDate'].append(child.attrib['OpenDate'])
        dataDict['CloseDate'].append(child.attrib['CloseDate'])
        # Nested Tags
        dataDict['Id'].append(child.findall('Id')[0].text)
        dataDict['Title'].append(child.findall('Title')[0].text)
        dataDict['Location'].append(child.findall('Location')[0].text)
        dataDict['ContractTime'].append(child.findall('ContractTime')[0].text if child.findall('ContractTime') else None)
        dataDict['Category'].append(child.findall('Category')[0].text if child.findall('Category') else None)
        dataDict['Salary'].append(child.findall('Salary')[0].text if child.findall('Salary') else None)
        dataDict['Company'].append(child.findall('Company')[0].text if child.findall('Company') else None)
        dataDict['ContractType'].append(child.findall('ContractType')[0].text if child.findall('ContractType') else None)
        
        # Child of the parent of each <JobAd>
        dataDict['SourceName'].append(elem.findall('SourceName')[0].text)

df = pd.DataFrame(dataDict)
# Save into a csv file to read afterwards
df.to_csv('job_ads.csv',index=False)
df.head()
# Out:
#          Id                                        Title     Location  \
# 0  70077187                              PTS Electrician     Plymouth
# 1  67945005  Technical Support Engineer  French Speaking  Southampton
# 2  71196024            Training Administrator  Rotherham    Rotherham
# 3  72459197    Engineering Services Manager  West London  West London
# 4  71684849         Electrical Estimator  Dartford, Kent     Dartford
#
#                 Company ContractType ContractTime          Category Salary  \
# 0  Resourcing Solutions         None     contract  Engineering Jobs  14400
# 1  Matchtech Group plc.         None         None  Engineering Jobs  24500
# 2              Randstad         None    permanent  Engineering Jobs  17250
# 3              Randstad         None    permanent  Engineering Jobs  46500
# 4              Randstad         None    permanent  Engineering Jobs  45000
#
#           OpenDate        CloseDate            SourceName
# 0  20121015T000000  20121214T000000  rengineeringjobs.com
# 1  20120624T000000  20120724T000000  rengineeringjobs.com
# 2  20120510T000000  20120808T000000  rengineeringjobs.com
# 3  20120705T120000  20121003T120000  rengineeringjobs.com
# 4  20120320T150000  20120519T150000  rengineeringjobs.com

# %% [markdown]
# ## Task 2. Auditing and cleansing the loaded data
#
# The newly saved data is loaded to check for errors ranging from duplicated values, null values, incorrect or incorrect format of values.

# %% [markdown]
# ### Task 2.1. Loading and Examaning data

# %%
df = pd.read_csv('job_ads.csv')

# %%
errorDict = {}
errorDict['indexOfdf'] = []
errorDict['Id'] = []
errorDict['ColumnName'] = []
errorDict['Original'] = []
errorDict['Modified'] = []
errorDict['Modified'] = []
errorDict['ErrorType'] = []
errorDict['Fixing'] = []
# Initialize a dictionary that records data problems and actions made to fix it

# %%
# Check initial datatypes
df.dtypes
# Out:
# Id               int64
# Title           object
# Location        object
# Company         object
# ContractType    object
# ContractTime    object
# Category        object
# Salary          object
# OpenDate        object
# CloseDate       object
# SourceName      object
# dtype: object

# %% [markdown]
# From the output above it can be seen that all data types are of **Object** data type
#
# According to the specifications, columns and data types of the dataset should be as follows:
# <ul>
#     <li>Id : Integer (8 digit integer)</li>
#     <li>TItle: Strings (Null values as 'non-specified')</li>
#     <li>Location: String (Null values as 'non-specified')</li>
#     <li>Company: String (Null values as 'non-specified')</li>
#     <li>ContractType: String ['full_time','part_time','non-specified']</li>
#     <li>ContractTime: String  ['permanent','contract','non-specified']</li>
#     <li>Category: String ['IT Jobs','Healthcare & Nursing Jobs','Engineering Jobs','Accounting & FInance Jobs','Sales Jobs','Hospitality & Catering Jobs','Teaching Jobs','PR,Advertising & Marketing Jobs']</li>
#     <li>Salary: Float (No null values allowed, 2 decimal places)</li>
#     <li>OpenDate: Datetime (YYYY-MM-DD HH:MM:SS)</li>
#     <li>CloseDate: Datetime (YYYY-MM-DD HH:MM:SS)</li>
#     <li>SourceName: String (Null values should be 'non-specified')</li>
# </ul>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50753 entries, 0 to 50752
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Id            50753 non-null  int64
#  1   Title         50753 non-null  object
#  2   Location      50753 non-null  object
#  3   Company       48177 non-null  object
#  4   ContractType  27320 non-null  object
#  5   ContractTime  42009 non-null  object
#  6   Category      50753 non-null  object
#  7   Salary        50116 non-null  object
#  8   OpenDate      50753 non-null  object
#  9   CloseDate     50753 non-null  object
#  10  SourceName    50753 non-null  object
# dtypes: int64(1), object(10)
# memory usage: 4.3+ MB

# %% [markdown]
# From the output above it can be see that columns 'Company','ContractType','ContractTime' and 'Salary' contain null values. Those values would be cleaned accordingly

# %%
def addToErrorDict(errorDict,index,Id,cname,ori,mod,etype,fixing):
#     num_invalid = len(df[filtr])
    errorDict['indexOfdf'].append(index)
    errorDict['Id'].append(Id)
    errorDict['ColumnName'].append(cname)
    errorDict['Original'].append(ori)
    errorDict['Modified'].append(mod)
    errorDict['ErrorType'].append(etype)
    errorDict['Fixing'].append(fixing)
    return errorDict

# %% [markdown]
# The above function adds necessary error info into the Error Dictionary

# %% [markdown]
# ### Task 2.2 Examining and Cleaning Id Column

# %%
# Get duplicated Ids
df[df['Id'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [Id, Title, Location, Company, ContractType, ContractTime, Category, Salary, OpenDate, CloseDate, SourceName]
# Index: []

# %% [markdown]
# It seems that every single Id in the dataset is unique!

# %%
# Match the Id using regex to see if the Id has 8 digits
df[~df['Id'].astype('str').str.match(r'\d{8}',na=False)]
# Out:
# Empty DataFrame
# Columns: [Id, Title, Location, Company, ContractType, ContractTime, Category, Salary, OpenDate, CloseDate, SourceName]
# Index: []

# %% [markdown]
# It can also be seen that every Id in the dataset has 8 digits, which matches the required format, no cleaning required!

# %% [markdown]
# ### Task 2.3 Examining and Cleaning ContractType Column

# %%
# Get number of unique contract types
df['ContractType'].value_counts()
# Out:
#              11273
# full_time    11244
# -             3363
# part_time     1440
# Name: ContractType, dtype: int64

# %% [markdown]
# From the output above it can be seen that there are no typos to the values, but null values came in form of empty values or just a dash (-). All these values would be replaced with 'non-specified'

# %%
# Get contract types that is not full time or part time
valid_contracts = df['ContractType'].isin(['full_time','part_time'])
df[~valid_contracts]
# Out:
#              Id                                           Title     Location  \
# 0      70077187                                 PTS Electrician     Plymouth
# 1      67945005     Technical Support Engineer  French Speaking  Southampton
# 2      71196024               Training Administrator  Rotherham    Rotherham
# 3      72459197       Engineering Services Manager  West London  West London
# 4      71684849            Electrical Estimator  Dartford, Kent     Dartford
# ...         ...                                             ...          ...
# 50747  68704692                  Graduate SoftwareWeb Developer       London
# 50748  72653749      GCHQ Graduate Technologists  various roles   Cheltenham
# 50749  72420369           Graduate Operations Technical Analyst   Hungerford
# 50750  72653751  Barclays Future Leaders Development Programmes      Hackney
# 50752  70139229    Health & Social Care Tutor/Assessor  Bristol           UK
#
#                                      Company ContractType ContractTime  \
# 0                       Resourcing Solutions          NaN     contract
# 1                       Matchtech Group plc.          NaN          NaN
# 2                                   Randstad          NaN    permanent
# 3                                   Randstad          NaN    permanent
# 4                                   Randstad          NaN    permanent
# ...                                      ...          ...          ...
# 50747  UNKNOWN   auto added by vacany import          NaN          NaN
# 50748                                   GCHQ          NaN          NaN
# 50749  UNKNOWN   auto added by vacany import          NaN          NaN
# 50750                               Barclays          NaN          NaN
# 50752                   Pursuit Training Ltd          NaN    permanent
#
#                Category Salary         OpenDate        CloseDate  \
# 0      Engineering Jobs  14400  20121015T000000  20121214T000000
# 1      Engineering Jobs  24500  20120624T000000  20120724T000000
# 2      Engineering Jobs  17250  20120510T000000  20120808T000000
# 3      Engineering Jobs  46500  20120705T120000  20121003T120000
# 4      Engineering Jobs  45000  20120320T150000  20120519T150000
# ...                 ...    ...              ...              ...
# 50747           IT Jobs  25000  20120112T120000  20120312T120000
# 50748  Engineering Jobs  25400  20120412T000000  20120611T000000
# 50749           IT Jobs    NaN  20130913T150000  20131112T150000
# 50750           IT Jobs  36000  20130721T150000  20130919T150000
# 50752     Teaching Jobs  18000  20120811T000000  20121010T000000
#
#                  SourceName
# 0      rengineeringjobs.com
# 1      rengineeringjobs.com
# 2      rengineeringjobs.com
# 3      rengineeringjobs.com
# 4      rengineeringjobs.com
# ...                     ...
# 50747            grb.uk.com
# 50748            grb.uk.com
# 50749            grb.uk.com
# 50750            grb.uk.com
# 50752        cvjobstore.com
#
# [38069 rows x 11 columns]

# %%
# Record error to errorDict
for ind in df[~valid_contracts].index:
    errorDict = addToErrorDict(errorDict,ind,df['Id'][ind],'ContractType','None','Non-specified','Missing values','Set missing values to non-specified')

# %%
# Replace all invalid values with non-specified
df.loc[~valid_contracts,'ContractType'] = 'non-specified'
df[~valid_contracts].head()
# Out:
#          Id                                        Title     Location  \
# 0  70077187                              PTS Electrician     Plymouth
# 1  67945005  Technical Support Engineer  French Speaking  Southampton
# 2  71196024            Training Administrator  Rotherham    Rotherham
# 3  72459197    Engineering Services Manager  West London  West London
# 4  71684849         Electrical Estimator  Dartford, Kent     Dartford
#
#                 Company   ContractType ContractTime          Category Salary  \
# 0  Resourcing Solutions  non-specified     contract  Engineering Jobs  14400
# 1  Matchtech Group plc.  non-specified          NaN  Engineering Jobs  24500
# 2              Randstad  non-specified    permanent  Engineering Jobs  17250
# 3              Randstad  non-specified    permanent  Engineering Jobs  46500
# 4              Randstad  non-specified    permanent  Engineering Jobs  45000
#
#           OpenDate        CloseDate            SourceName
# 0  20121015T000000  20121214T000000  rengineeringjobs.com
# 1  20120624T000000  20120724T000000  rengineeringjobs.com
# 2  20120510T000000  20120808T000000  rengineeringjobs.com
# 3  20120705T120000  20121003T120000  rengineeringjobs.com
# 4  20120320T150000  20120519T150000  rengineeringjobs.com

# %% [markdown]
# ### Task 2.4 Examining and Cleaning ContractTime Column

# %%
df['ContractTime'].value_counts()
# Out:
# permanent    31010
# contract      5610
# -             3201
#               2188
# Name: ContractTime, dtype: int64

# %% [markdown]
# There are also missing values present in the column 'ContractTime'. They will all be set to non-specified as well

# %%
# Get contract times that is not permanent or contract
valid_contracts = df['ContractTime'].isin(['permanent','contract'])
# Record every error into errorDict
for ind in df[~valid_contracts].index:
    errorDict = addToErrorDict(errorDict,ind,df['Id'][ind],'ContractTime','None','Non-specified','Missing values','Set missing values to non-specified')

# Replace those invalid values as non-specified
df.loc[~valid_contracts,'ContractTime'] = 'non-specified'
df[~valid_contracts]
# Out:
#              Id                                           Title  \
# 1      67945005     Technical Support Engineer  French Speaking
# 5      67944712                     Theatre Lead/Deputy Manager
# 6      67946379         Technical Director  Strategic Modelling
# 10     66160421                       Structural CAD Technician
# 11     67946033        Offshore Project Manager of HVDC package
# ...         ...                                             ...
# 50741  72531462                            EI/POS net developer
# 50747  68704692                  Graduate SoftwareWeb Developer
# 50748  72653749      GCHQ Graduate Technologists  various roles
# 50749  72420369           Graduate Operations Technical Analyst
# 50750  72653751  Barclays Future Leaders Development Programmes
#
#             Location                                Company   ContractType  \
# 1        Southampton                   Matchtech Group plc.  non-specified
# 5                 UK                   Matchtech Group plc.  non-specified
# 6             Woking                   Matchtech Group plc.  non-specified
# 10     South Croydon                   Matchtech Group plc.  non-specified
# 11            London                   Matchtech Group plc.  non-specified
# ...              ...                                    ...            ...
# 50741             UK                                  JobG8  non-specified
# 50747         London  UNKNOWN   auto added by vacany import  non-specified
# 50748     Cheltenham                                   GCHQ  non-specified
# 50749     Hungerford  UNKNOWN   auto added by vacany import  non-specified
# 50750        Hackney                               Barclays  non-specified
#
#         ContractTime          Category Salary         OpenDate  \
# 1      non-specified  Engineering Jobs  24500  20120624T000000
# 5      non-specified  Engineering Jobs    NaN  20120424T000000
# 6      non-specified  Engineering Jobs  61500  20121214T000000
# 10     non-specified  Engineering Jobs  24500  20130221T120000
# 11     non-specified  Engineering Jobs  51000  20120617T000000
# ...              ...               ...    ...              ...
# 50741  non-specified           IT Jobs  60000  20130408T120000
# 50747  non-specified           IT Jobs  25000  20120112T120000
# 50748  non-specified  Engineering Jobs  25400  20120412T000000
# 50749  non-specified           IT Jobs    NaN  20130913T150000
# 50750  non-specified           IT Jobs  36000  20130721T150000
#
#              CloseDate              SourceName
# 1      20120724T000000    rengineeringjobs.com
# 5      20120524T000000    rengineeringjobs.com
# 6      20130113T000000    rengineeringjobs.com
# 10     20130307T120000    rengineeringjobs.com
# 11     20120701T000000    rengineeringjobs.com
# ...                ...                     ...
# 50741  20130607T120000  cardandpaymentjobs.com
# 50747  20120312T120000              grb.uk.com
# 50748  20120611T000000              grb.uk.com
# 50749  20131112T150000              grb.uk.com
# 50750  20130919T150000              grb.uk.com
#
# [14133 rows x 11 columns]

# %% [markdown]
# Here ends the cleaning for the column ContractTime

# %% [markdown]
# ### Task 2.5 Examining and Loading Category Column

# %%
df['Category'].value_counts()
# Out:
# IT Jobs                             13170
# Healthcare & Nursing Jobs            8067
# Engineering Jobs                     7517
# Accounting & Finance Jobs            6772
# Sales Jobs                           4869
# Hospitality & Catering Jobs          4376
# Teaching Jobs                        3455
# PR, Advertising & Marketing Jobs     2527
# Name: Category, dtype: int64

# %% [markdown]
# From the value counts above, it can be seen that there are no typos on values for the Category column. Thus, this column is kept as is.

# %% [markdown]
# ### Task 2.6 Examining and Loading Date Columns

# %%
df[['OpenDate','CloseDate']].head()
# Out:
#           OpenDate        CloseDate
# 0  20121015T000000  20121214T000000
# 1  20120624T000000  20120724T000000
# 2  20120510T000000  20120808T000000
# 3  20120705T120000  20121003T120000
# 4  20120320T150000  20120519T150000

# %% [markdown]
# It can be seen that the OpenDate and CloseDate column does not have the correct data type (Datetime). Thus, they will all be converted into the correct format

# %%
# Record error to errorDict
errorDict = addToErrorDict(errorDict,'ALL','ALL','OpenDate','String','DateTime','Incorrect Data format','Convert from string to datetime')

# %%
# Function to format date string into dates
def FormatDate(date_str,date_pattern,ordered):
    date_time =re.match(date_pattern,date_str)
    # If regex find no match, print out the date and do not change the vale
    if date_time == None:
        print("Invalid Date found")
        print(date_str)
        return date_str
    else:
        date_time = date_time.groups()
        # If date is YYYYMMDD
        if ordered:
            date = datetime.datetime.strptime(date_time[0],'%Y%m%d').date()
        else:
            date = datetime.datetime.strptime(date_time[0],'%Y%d%m').date()
        # Convert time string to time
        time = datetime.datetime.strptime(date_time[1],'%H%M%S').time()
        
        # Return converted datetime
        return datetime.datetime.combine(date,time)

# %%
date_pattern = r'(20[1-2]\d(?:0[1-9]|1[0-2])(?:0[1-9]|[1-2][0-9]|3[0-1]))T(\d{6})'
df['OpenDate'] = df['OpenDate'].apply(lambda x: FormatDate(x,date_pattern,True))
# Out:
# Invalid Date found
# 20122405T120000

# %% [markdown]
# From here it shows that there is one date that is incorrect in format. it seems that the month and date is reversed. This incident will be recorded in the ErrorDict and corrected

# %%
rvr_date_pattern = r'(20[1-2]\d(?:0[1-9]|[1-2][0-9]|3[0-1])(?:0[1-9]|1[0-2]))T(\d{6})'
incorrect_date = df['OpenDate'].str.fullmatch(pat = rvr_date_pattern, na=False)
df[incorrect_date]

errorDict = addToErrorDict(errorDict,df.index[incorrect_date],df[incorrect_date]['Id'],'OpenDate','String','DateTime','Incorrect Data format (Reversed)','Convert from string to datetime')

df.loc[incorrect_date,'OpenDate'] = df.loc[incorrect_date,'OpenDate'].apply(lambda x: FormatDate(x,rvr_date_pattern,False))
df[incorrect_date]
# Out:
#             Id                         Title     Location     Company  \
# 8588  71335675  Technical Digital Consultant  Craigiehall  Hudson  IT
#
#        ContractType ContractTime Category Salary             OpenDate  \
# 8588  non-specified    permanent  IT Jobs  26000  2012-05-24 12:00:00
#
#             CloseDate    SourceName
# 8588  20120623T120000  jobserve.com

# %% [markdown]
# Now that the column OpenDate is formatted, it is time to format CloseDate column

# %%
errorDict = addToErrorDict(errorDict,'ALL','ALL','CloseDate','String','DateTime','Incorrect Data format','Convert from string to datetime')

# %%
date_pattern = r'(20[1-2]\d(?:0[1-9]|1[0-2])(?:0[1-9]|[1-2][0-9]|3[0-1]))T(\d{6})'
df['CloseDate'] = df['CloseDate'].apply(lambda x: FormatDate(x,date_pattern,True))

# %% [markdown]
# It seems that there is no error within the CloseDate column and everything is converted to datetime safely. Now is the time to check if there are any violation in the dates (if OpenDate > CloseDate)

# %%
valid_duration = df['CloseDate'] > df['OpenDate']
df[~valid_duration]
# Out:
#              Id                                              Title  \
# 3931   66600505                               AREA SALES EXECUTIVE
# 14972  68699721                 Product Specialist  Sports Therapy
# 39133  71659260             Reservations Manager  6 Month Contract
# 42944  71224150  SENIOR M&E/ELECTRICAL ENGINEERWATERBRISTOLCONT...
# 44223  68849704               Telesales and Information Operatives
#
#              Location                  Company   ContractType   ContractTime  \
# 3931            Leeds         Candidate Source  non-specified      permanent
# 14972   West Midlands       Delta Consultants.  non-specified      permanent
# 39133          London             Stafffinders  non-specified  non-specified
# 42944         Bristol  Progressive Recruitment  non-specified  non-specified
# 44223  Wellingborough           Fox Resourcing  non-specified  non-specified
#
#                           Category Salary             OpenDate  \
# 3931                    Sales Jobs  30000  2014-01-13 12:00:00
# 14972                   Sales Jobs  25000  2013-10-06 12:00:00
# 39133  Hospitality & Catering Jobs  21500  2012-03-11 00:00:00
# 42944             Engineering Jobs  57600  2012-03-14 00:00:00
# 44223                   Sales Jobs  10742  2013-06-21 00:00:00
#
#                 CloseDate                      SourceName
# 3931  2013-11-14 12:00:00                cv-library.co.uk
# 14972 2013-09-06 12:00:00                   totaljobs.com
# 39133 2012-01-11 00:00:00  jobs.catererandhotelkeeper.com
# 42944 2012-02-13 00:00:00               gojobsearch.co.uk
# 44223 2013-06-07 00:00:00                 jobstoday.co.uk

# %% [markdown]
# From the table above, there are several data with invalid duration, there is a possiblity that the user filled in the dates in the wrong order. Thus, these 2 values are switched over to deal with this error

# %%
df[['OpenDate','CloseDate']] = df[['OpenDate','CloseDate']].astype("string")
# Convert to string for the swapping
df.dtypes
# Out:
# Id               int64
# Title           object
# Location        object
# Company         object
# ContractType    object
# ContractTime    object
# Category        object
# Salary          object
# OpenDate        string
# CloseDate       string
# SourceName      object
# dtype: object

# %%
# Record every error to errorDict
for ind in df.index[~valid_duration]:
    open_date = str(df['OpenDate'][ind])
    close_date = str(df['CloseDate'][ind])
    errorDict = addToErrorDict(errorDict,ind,df['Id'][ind],"OpenDate,CloseDate"," ".join([open_date,close_date])," ".join([close_date,open_date]),'Invalid Duration','Switch values from the columns')

# %%
# Swap values
df.loc[~valid_duration,['OpenDate','CloseDate']] = df.loc[~valid_duration,['CloseDate','OpenDate']].values
df[~valid_duration]
# Out:
#              Id                                              Title  \
# 3931   66600505                               AREA SALES EXECUTIVE
# 14972  68699721                 Product Specialist  Sports Therapy
# 39133  71659260             Reservations Manager  6 Month Contract
# 42944  71224150  SENIOR M&E/ELECTRICAL ENGINEERWATERBRISTOLCONT...
# 44223  68849704               Telesales and Information Operatives
#
#              Location                  Company   ContractType   ContractTime  \
# 3931            Leeds         Candidate Source  non-specified      permanent
# 14972   West Midlands       Delta Consultants.  non-specified      permanent
# 39133          London             Stafffinders  non-specified  non-specified
# 42944         Bristol  Progressive Recruitment  non-specified  non-specified
# 44223  Wellingborough           Fox Resourcing  non-specified  non-specified
#
#                           Category Salary             OpenDate  \
# 3931                    Sales Jobs  30000  2013-11-14 12:00:00
# 14972                   Sales Jobs  25000  2013-09-06 12:00:00
# 39133  Hospitality & Catering Jobs  21500  2012-01-11 00:00:00
# 42944             Engineering Jobs  57600  2012-02-13 00:00:00
# 44223                   Sales Jobs  10742  2013-06-07 00:00:00
#
#                  CloseDate                      SourceName
# 3931   2014-01-13 12:00:00                cv-library.co.uk
# 14972  2013-10-06 12:00:00                   totaljobs.com
# 39133  2012-03-11 00:00:00  jobs.catererandhotelkeeper.com
# 42944  2012-03-14 00:00:00               gojobsearch.co.uk
# 44223  2013-06-21 00:00:00                 jobstoday.co.uk

# %% [markdown]
# Now the all the duration is valid, all data of these 2 columns will be converted to DateTime

# %%
df['OpenDate'] = pd.to_datetime(df['OpenDate'])
df['CloseDate'] = pd.to_datetime(df['CloseDate'])
df.dtypes
# Out:
# Id                       int64
# Title                   object
# Location                object
# Company                 object
# ContractType            object
# ContractTime            object
# Category                object
# Salary                  object
# OpenDate        datetime64[ns]
# CloseDate       datetime64[ns]
# SourceName              object
# dtype: object

# %% [markdown]
# Here we have done converting and fixing the columns OpenDate and CloseDate

# %% [markdown]
# ### Task 2.7 Examining and Cleaning SourceName Column

# %%
# Get data with null SourceName
df[df['SourceName'].isna()]
# Out:
# Empty DataFrame
# Columns: [Id, Title, Location, Company, ContractType, ContractTime, Category, Salary, OpenDate, CloseDate, SourceName]
# Index: []

# %% [markdown]
# It seems like every row of data has a SourceName!

# %%
# Get SourceName that contains something that is not work or space
df[df['SourceName'].str.contains('[^\s\w]+')]
# Out:
#              Id                                           Title  \
# 0      70077187                                 PTS Electrician
# 1      67945005     Technical Support Engineer  French Speaking
# 2      71196024               Training Administrator  Rotherham
# 3      72459197       Engineering Services Manager  West London
# 4      71684849            Electrical Estimator  Dartford, Kent
# ...         ...                                             ...
# 50748  72653749      GCHQ Graduate Technologists  various roles
# 50749  72420369           Graduate Operations Technical Analyst
# 50750  72653751  Barclays Future Leaders Development Programmes
# 50751  66372417              Graduate Engineer (Water industry)
# 50752  70139229    Health & Social Care Tutor/Assessor  Bristol
#
#                 Location                                Company  \
# 0               Plymouth                   Resourcing Solutions
# 1            Southampton                   Matchtech Group plc.
# 2              Rotherham                               Randstad
# 3            West London                               Randstad
# 4               Dartford                               Randstad
# ...                  ...                                    ...
# 50748         Cheltenham                                   GCHQ
# 50749         Hungerford  UNKNOWN   auto added by vacany import
# 50750            Hackney                               Barclays
# 50751  South Lanarkshire                Carrington West Limited
# 50752                 UK                   Pursuit Training Ltd
#
#         ContractType   ContractTime          Category Salary  \
# 0      non-specified       contract  Engineering Jobs  14400
# 1      non-specified  non-specified  Engineering Jobs  24500
# 2      non-specified      permanent  Engineering Jobs  17250
# 3      non-specified      permanent  Engineering Jobs  46500
# 4      non-specified      permanent  Engineering Jobs  45000
# ...              ...            ...               ...    ...
# 50748  non-specified  non-specified  Engineering Jobs  25400
# 50749  non-specified  non-specified           IT Jobs    NaN
# 50750  non-specified  non-specified           IT Jobs  36000
# 50751      full_time       contract  Engineering Jobs  20000
# 50752  non-specified      permanent     Teaching Jobs  18000
#
#                  OpenDate           CloseDate            SourceName
# 0     2012-10-15 00:00:00 2012-12-14 00:00:00  rengineeringjobs.com
# 1     2012-06-24 00:00:00 2012-07-24 00:00:00  rengineeringjobs.com
# 2     2012-05-10 00:00:00 2012-08-08 00:00:00  rengineeringjobs.com
# 3     2012-07-05 12:00:00 2012-10-03 12:00:00  rengineeringjobs.com
# 4     2012-03-20 15:00:00 2012-05-19 15:00:00  rengineeringjobs.com
# ...                   ...                 ...                   ...
# 50748 2012-04-12 00:00:00 2012-06-11 00:00:00            grb.uk.com
# 50749 2013-09-13 15:00:00 2013-11-12 15:00:00            grb.uk.com
# 50750 2013-07-21 15:00:00 2013-09-19 15:00:00            grb.uk.com
# 50751 2013-01-19 00:00:00 2013-04-19 00:00:00     thegraduate.co.uk
# 50752 2012-08-11 00:00:00 2012-10-10 00:00:00        cvjobstore.com
#
# [45928 rows x 11 columns]

# %% [markdown]
# It seems like some of the source names are websites. They all look correct, thus they will be filtered out

# %%
df[df['SourceName'].str.contains('[^\s\w\.]+')]
# Out:
#              Id                                    Title           Location  \
# 658    67299034           Security Systems Sales Manager      East Midlands
# 659    66893534       Skills For Life Tutor (**** Hours)  South West London
# 660    66925525                    Trainee Web Developer            Byfleet
# 661    71556865               Licensed Animal Technician          Cambridge
# 662    69079681  Assistant Project Manager  Installation            Redhill
# ...         ...                                      ...                ...
# 50360  69928387                    Head of Maths Faculty    Nottinghamshire
# 50361  67058705                   Faculty Leader Science      Hertfordshire
# 50362  71287706                  Assistant Director  MIS     Stoke-On-Trent
# 50363  71552520                     Maths Subject Leader        Bournemouth
# 50364  67390271         Head of Modern Foreign Languages         Manchester
#
#                                      Company   ContractType   ContractTime  \
# 658                                  SSR C T  non-specified      permanent
# 659                                       R3  non-specified      permanent
# 660                Clockwork Recruitment Ltd  non-specified      permanent
# 661                               S3 Science  non-specified      permanent
# 662          Zebra Technical Recruitment Ltd  non-specified      permanent
# ...                                      ...            ...            ...
# 50360                     The Holgate School  non-specified  non-specified
# 50361                  Francis Combe Academy  non-specified  non-specified
# 50362  Stoke on Trent College Cauldon Campus  non-specified  non-specified
# 50363                       Harewood College  non-specified  non-specified
# 50364                    Cedar Mount Academy  non-specified  non-specified
#
#                         Category   Salary            OpenDate  \
# 658                   Sales Jobs    45000 2012-01-23 12:00:00
# 659                Teaching Jobs    22000 2013-11-15 15:00:00
# 660                      IT Jobs    22500 2012-06-23 00:00:00
# 661    Healthcare & Nursing Jobs    19193 2012-09-17 12:00:00
# 662             Engineering Jobs    35000 2012-02-19 00:00:00
# ...                          ...      ...                 ...
# 50360              Teaching Jobs      NaN 2012-10-27 15:00:00
# 50361              Teaching Jobs      NaN 2013-10-07 15:00:00
# 50362              Teaching Jobs  39194.0 2012-02-08 00:00:00
# 50363              Teaching Jobs   5106.0 2013-02-09 12:00:00
# 50364              Teaching Jobs   6696.0 2012-08-08 15:00:00
#
#                 CloseDate                   SourceName
# 658   2012-02-22 12:00:00             cv-library.co.uk
# 659   2014-02-13 15:00:00             cv-library.co.uk
# 660   2012-07-23 00:00:00             cv-library.co.uk
# 661   2012-10-17 12:00:00             cv-library.co.uk
# 662   2012-05-19 00:00:00             cv-library.co.uk
# ...                   ...                          ...
# 50360 2012-11-10 15:00:00  Teaching jobs - TES Connect
# 50361 2013-12-06 15:00:00  Teaching jobs - TES Connect
# 50362 2012-04-08 00:00:00  Teaching jobs - TES Connect
# 50363 2013-04-10 12:00:00  Teaching jobs - TES Connect
# 50364 2012-09-07 15:00:00  Teaching jobs - TES Connect
#
# [7602 rows x 11 columns]

# %% [markdown]
# Some of them contains "-" as well, they seem to not be wrong thus we will continue

# %%
df[df['SourceName'].str.contains('[^\s\w\.\-]+')]
# Out:
# Empty DataFrame
# Columns: [Id, Title, Location, Company, ContractType, ContractTime, Category, Salary, OpenDate, CloseDate, SourceName]
# Index: []

# %% [markdown]
# Here we end our examination for the column SourceName, it seems like all is well!

# %% [markdown]
# ### Task 2.7 Examining and Cleaning Title Column

# %%
# Capitalize each word of title and record all into errorDict
df['Title'] = df['Title'].str.title()
errorDict = addToErrorDict(errorDict,'ALL','ALL','Title','word','Word','Incorrect capitalizations','Capitalize each word')
df['Title'].value_counts()
# Out:
# Paeds (Ot)                                                2
# Assistant Brand Manager Fmcg                              2
# Private Equity, Investment Associate                      2
# Pts Electrician                                           1
# Teacher Of Primary (**** Posts) Kinloss Primary School    1
#                                                          ..
# Microsoft Crm Dynamics  Bristol                           1
# Bdm  Asset Finance / Leasing / Motor Finance              1
# Account Executive  Agency Side                            1
# Media Sales Executive With German                         1
# Health & Social Care Tutor/Assessor  Bristol              1
# Name: Title, Length: 50750, dtype: int64

# %% [markdown]
# From above it can be seen there are only 3 titles that is not unique

# %%
df[df['Title'].isna()]
# Out:
# Empty DataFrame
# Columns: [Id, Title, Location, Company, ContractType, ContractTime, Category, Salary, OpenDate, CloseDate, SourceName]
# Index: []

# %% [markdown]
# It seems like there is no null values in the 'Title' column

# %%
# Get titles that has non alphanumeric characters
df[df['Title'].str.fullmatch('\W+')]
# Out:
#             Id Title Location                  Company   ContractType  \
# 6782  50870368  ****       UK  Rullion Engineering Ltd  non-specified
#
#      ContractTime          Category Salary            OpenDate  \
# 6782    permanent  Engineering Jobs  34500 2013-09-03 12:00:00
#
#                CloseDate        SourceName
# 6782 2013-12-02 12:00:00  cv-library.co.uk

# %% [markdown]
# It seems like there is one data with just "\*"! The title of this data would then be set as 'Non-specified'.

# %%
invalid_title = df['Title'].str.fullmatch('\W+')
ind = df[invalid_title].index[0]

# Record error to Error Dict
errorDict = addToErrorDict(errorDict,ind,df['Id'][ind],'Title',df['Title'][ind],'Non-specified','Missing values','Replace value as Non-specified')

# Set the incorrect title as non-specified
df.loc[invalid_title,'Title'] = 'non-specified'
df[invalid_title]
# Out:
#             Id          Title Location                  Company  \
# 6782  50870368  non-specified       UK  Rullion Engineering Ltd
#
#        ContractType ContractTime          Category Salary            OpenDate  \
# 6782  non-specified    permanent  Engineering Jobs  34500 2013-09-03 12:00:00
#
#                CloseDate        SourceName
# 6782 2013-12-02 12:00:00  cv-library.co.uk

# %% [markdown]
# Now let's check for duplicated values

# %%
df[df[['Title']].duplicated(keep=False)]
# Out:
#              Id                                 Title        Location  \
# 44411  69120030          Assistant Brand Manager Fmcg         Gatwick
# 44438  71295275          Assistant Brand Manager Fmcg         Gatwick
# 44497  72132299  Private Equity, Investment Associate      Birmingham
# 44568  71295288  Private Equity, Investment Associate      Birmingham
# 48044  70141144                            Paeds (Ot)  Cambridgeshire
# 48126  71295314                            Paeds (Ot)  Cambridgeshire
#
#                             Company   ContractType ContractTime  \
# 44411                   London4Jobs      full_time    permanent
# 44438                   London4Jobs      full_time    permanent
# 44497                 CH Associates  non-specified    permanent
# 44568                CH Associates.  non-specified    permanent
# 48044  Castlerock Recruitment Group  non-specified    permanent
# 48126  Castlerock Recruitment Group  non-specified    permanent
#
#                                Category Salary            OpenDate  \
# 44411  PR, Advertising & Marketing Jobs  29500 2012-09-06 12:00:00
# 44438  PR, Advertising & Marketing Jobs  29500 2012-09-06 12:00:00
# 44497         Accounting & Finance Jobs  47000 2012-07-22 12:00:00
# 44568         Accounting & Finance Jobs  47000 2012-07-22 12:00:00
# 48044         Healthcare & Nursing Jobs  28000 2013-11-11 12:00:00
# 48126         Healthcare & Nursing Jobs  28000 2013-11-11 12:00:00
#
#                 CloseDate              SourceName
# 44411 2012-10-06 12:00:00       london4jobs.co.uk
# 44438 2012-10-06 12:00:00       london4jobs.co.uk
# 44497 2012-08-21 12:00:00  accountancyagejobs.com
# 44568 2012-08-21 12:00:00  accountancyagejobs.com
# 48044 2013-12-11 12:00:00           tntjobs.co.uk
# 48126 2013-12-11 12:00:00           tntjobs.co.uk

# %% [markdown]
# There are a total of 3 duplicated values in the dataset. The duplicated row would be removed.

# %%
duplicates = df['Title'].duplicated()
# Record to errorDict
for ind in df.index[duplicates]:
    errorDict = addToErrorDict(errorDict,'ALL',df['Id'][ind],'ALL','ALL','ALL','Duplicated values','Removed duplicated values')
    
# Drop duplicates
df.drop_duplicates(['Title'],inplace=True)
df[duplicates]
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2328\2512627482.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[duplicates]
# Empty DataFrame
# Columns: [Id, Title, Location, Company, ContractType, ContractTime, Category, Salary, OpenDate, CloseDate, SourceName]
# Index: []

# %% [markdown]
# It does seem like there are a lot of information residing in the titles, let's check if we could fill some null values of other columns through the titles

# %%
# Get titles that contains words like Time to find phrases like 'Part time'
df[df['Title'].str.contains(r'\b[tT]ime\b')].head()
# Out:
#            Id                                              Title   Location  \
# 181  68179073     Senior Administrator / Part Time 10Am To 300Pm   Hinckley
# 740  71554929  Part Time Accounts Senior (Practice Background...  Sevenoaks
# 884  69931029              Part Time Credit Controller  Solihull   Solihull
# 918  68999863                   Sales Service Advisor  Part Time         UK
# 994  71750572            Dermatology Specialist Nurse  Part Time   Brighton
#
#                       Company   ContractType   ContractTime  \
# 181             Fusion People  non-specified       contract
# 740  Prospect Recruitment Ltd      part_time       contract
# 884             Office Angels  non-specified       contract
# 918      Osborne Appointments  non-specified      permanent
# 994    Equal Approach Limited      part_time  non-specified
#
#                       Category Salary            OpenDate           CloseDate  \
# 181           Engineering Jobs  15360 2013-09-01 00:00:00 2013-09-15 00:00:00
# 740  Accounting & Finance Jobs  25000 2012-01-13 00:00:00 2012-01-27 00:00:00
# 884  Accounting & Finance Jobs  15360 2013-10-23 15:00:00 2013-11-06 15:00:00
# 918                 Sales Jobs  13843 2012-01-07 00:00:00 2012-03-07 00:00:00
# 994  Healthcare & Nursing Jobs  29000 2013-06-18 00:00:00 2013-08-17 00:00:00
#
#                SourceName
# 181  rengineeringjobs.com
# 740      cv-library.co.uk
# 884      cv-library.co.uk
# 918      cv-library.co.uk
# 994      cv-library.co.uk

# %% [markdown]
# Indeed, some of them has null ContractType but the title says 'Part time'!

# %%
# Get rows of data with Part time or full time phrases and is non-specified in ContractType
no_type = df['ContractType'] == 'non-specified'
has_type = df['Title'].str.contains(r'\b([pP]art|[fF]ull) [tT]ime\b')
indices = list(df[no_type&has_type].index)
for ind in indices:
    # Get matched group (part OR full)
    typ = re.search(r'\b([pP]art|[fF]ull) [tT]ime\b',df['Title'][ind]).groups()[0].lower()
    # join with _time
    new = typ+'_time'
    # Record to errorDict
    errorDict = addToErrorDict(errorDict,ind,df['Id'][ind],'ContractType','non-specified',new,'None but info in Title column','Fill none with found info')
    # Set 'ContractType' to a new value
    df.loc[ind,'ContractType'] = new
df[no_type&has_type].head()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2328\2810980817.py:3: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   has_type = df['Title'].str.contains(r'\b([pP]art|[fF]ull) [tT]ime\b')
#             Id                                              Title  \
# 181   68179073     Senior Administrator / Part Time 10Am To 300Pm
# 884   69931029              Part Time Credit Controller  Solihull
# 918   68999863                   Sales Service Advisor  Part Time
# 1019  71557106  Staff Nurse Rgn/Rmn Nights Yeovil ******** Ph ...
# 1883  70215539      Cad Designer East Sussex  36 Months Full Time
#
#          Location                  Company ContractType ContractTime  \
# 181      Hinckley            Fusion People    part_time     contract
# 884      Solihull            Office Angels    part_time     contract
# 918            UK     Osborne Appointments    part_time    permanent
# 1019       Yeovil          SYK Recruitment    part_time    permanent
# 1883  East Sussex  People4business Limited    full_time     contract
#
#                        Category Salary            OpenDate  \
# 181            Engineering Jobs  15360 2013-09-01 00:00:00
# 884   Accounting & Finance Jobs  15360 2013-10-23 15:00:00
# 918                  Sales Jobs  13843 2012-01-07 00:00:00
# 1019  Healthcare & Nursing Jobs  24912 2012-03-15 00:00:00
# 1883           Engineering Jobs  38400 2013-07-21 15:00:00
#
#                CloseDate            SourceName
# 181  2013-09-15 00:00:00  rengineeringjobs.com
# 884  2013-11-06 15:00:00      cv-library.co.uk
# 918  2012-03-07 00:00:00      cv-library.co.uk
# 1019 2012-05-14 00:00:00      cv-library.co.uk
# 1883 2013-08-20 15:00:00      cv-library.co.uk

# %% [markdown]
# A total of 184 null values are filled! Now let's look at others!

# %%
no_time = df['ContractTime'] == 'non-specified'
has_time = df['Title'].str.contains(r'\b([cC]ontract|[pP]erm\w+)\b')
df[no_time&has_time]
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2328\3119724438.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   has_time = df['Title'].str.contains(r'\b([cC]ontract|[pP]erm\w+)\b')
#              Id                                              Title  \
# 3265   66902133         Part Time Marketing Coordinator (Contract)
# 19441  69600051                              Iro  Permanent  Gwent
# 22710  68834820  Catering Manager – Leading Contract Caterer – ...
# 22752  68832342  Chef Manager – London – Contract Catering – To...
# 22864  70734291  Permanent Junior Sous Chef  ****K  **** Aa Ros...
# ...         ...                                                ...
# 47519  69029679    Marketing Assistant  Fleet  (12 Month Contract)
# 47534  69026153  Mobile Electrical Engineer  Commercial Contrac...
# 47542  67211817   Accounting Lecturer  ****Mth Fixed Term Contract
# 50207  72328226                Internal Auditor (3 Month Contract)
# 50328  67996706  Permanent Trainee, Junior And Senior Broker Po...
#
#                 Location                            Company   ContractType  \
# 3265             Taunton                      Office Angels      part_time
# 19441                 UK                     Eden Brown Ltd      part_time
# 22710                 UK               Rockford Recruitment  non-specified
# 22752  South East London  Collins King & Associates Limited  non-specified
# 22864   Northamptonshire                Brigade Recruitment  non-specified
# ...                  ...                                ...            ...
# 47519              Fleet                                NaN  non-specified
# 47534             Slough                                NaN  non-specified
# 47542        Southampton                                NaN  non-specified
# 50207         Manchester                 The Fragrance Shop  non-specified
# 50328                 UK            West London Brokers Ltd  non-specified
#
#         ContractTime                          Category Salary  \
# 3265   non-specified  PR, Advertising & Marketing Jobs  13000
# 19441  non-specified         Healthcare & Nursing Jobs  35877
# 22710  non-specified       Hospitality & Catering Jobs  22000
# 22752  non-specified       Hospitality & Catering Jobs  35000
# 22864  non-specified       Hospitality & Catering Jobs  22000
# ...              ...                               ...    ...
# 47519  non-specified  PR, Advertising & Marketing Jobs  22000
# 47534  non-specified                  Engineering Jobs  30000
# 47542  non-specified                     Teaching Jobs  31000
# 50207  non-specified                           IT Jobs
# 50328  non-specified         Accounting & Finance Jobs  19200
#
#                  OpenDate           CloseDate            SourceName
# 3265  2013-11-02 00:00:00 2013-12-02 00:00:00      cv-library.co.uk
# 19441 2013-12-02 12:00:00 2014-01-01 12:00:00         totaljobs.com
# 22710 2013-05-26 00:00:00 2013-07-25 00:00:00           caterer.com
# 22752 2012-05-26 15:00:00 2012-07-25 15:00:00           caterer.com
# 22864 2013-12-11 15:00:00 2014-02-09 15:00:00           caterer.com
# ...                   ...                 ...                   ...
# 47519 2012-11-03 00:00:00 2013-01-02 00:00:00  britishjobsonthe.net
# 47534 2013-03-03 00:00:00 2013-04-02 00:00:00  britishjobsonthe.net
# 47542 2012-05-22 12:00:00 2012-06-05 12:00:00  britishjobsonthe.net
# 50207 2012-01-09 12:00:00 2012-02-08 12:00:00      emptylemon.co.uk
# 50328 2012-02-15 00:00:00 2012-02-29 00:00:00      juniorbroker.com
#
# [140 rows x 11 columns]

# %% [markdown]
# Some titles also contains answers to ContractTime!

# %%
# Get rows that does not specify contract time but the title contains either contract or permanent
no_time = df['ContractTime'] == 'non-specified'
has_time = df['Title'].str.contains(r'\b([cC]ontract|[pP]ermanent)\b')
indices = list(df[no_time&has_time].index)
for ind in indices:
    # Get matched group (contract OR permanent)
    typ = re.search(r'\b([cC]ontract|[pP]ermanent)\b',df['Title'][ind]).groups()[0].lower()
    # Record to error dict
    errorDict = addToErrorDict(errorDict,ind,df['Id'][ind],'ContractTime','non-specified',typ,'None but info in Title column','Fill none with found info')
    # Fill na with newly found information
    df.loc[ind,'ContractTime'] = typ
df[no_time&has_time].head()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2328\924239738.py:3: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   has_time = df['Title'].str.contains(r'\b([cC]ontract|[pP]ermanent)\b')
#              Id                                              Title  \
# 3265   66902133         Part Time Marketing Coordinator (Contract)
# 19441  69600051                              Iro  Permanent  Gwent
# 22710  68834820  Catering Manager – Leading Contract Caterer – ...
# 22752  68832342  Chef Manager – London – Contract Catering – To...
# 22864  70734291  Permanent Junior Sous Chef  ****K  **** Aa Ros...
#
#                 Location                            Company   ContractType  \
# 3265             Taunton                      Office Angels      part_time
# 19441                 UK                     Eden Brown Ltd      part_time
# 22710                 UK               Rockford Recruitment  non-specified
# 22752  South East London  Collins King & Associates Limited  non-specified
# 22864   Northamptonshire                Brigade Recruitment  non-specified
#
#       ContractTime                          Category Salary  \
# 3265      contract  PR, Advertising & Marketing Jobs  13000
# 19441    permanent         Healthcare & Nursing Jobs  35877
# 22710     contract       Hospitality & Catering Jobs  22000
# 22752     contract       Hospitality & Catering Jobs  35000
# 22864    permanent       Hospitality & Catering Jobs  22000
#
#                  OpenDate           CloseDate        SourceName
# 3265  2013-11-02 00:00:00 2013-12-02 00:00:00  cv-library.co.uk
# 19441 2013-12-02 12:00:00 2014-01-01 12:00:00     totaljobs.com
# 22710 2013-05-26 00:00:00 2013-07-25 00:00:00       caterer.com
# 22752 2012-05-26 15:00:00 2012-07-25 15:00:00       caterer.com
# 22864 2013-12-11 15:00:00 2014-02-09 15:00:00       caterer.com

# %%
# Add all titles into as there are still possible erorrs in them
errorDict = addToErrorDict(errorDict,'ALL','ALL','Title','No','No','Possible incorrect values','Kept as is')

# %% [markdown]
# No further examinations are done on the Title column as there is too much values to consider, taking into account that there is only limited resources. Thus, here we complete our data cleaning for the column Title

# %% [markdown]
# ### Task 2.8 Examining and Cleaning Location Column

# %%
# Format Location into words with first letter capitalized
errorDict = addToErrorDict(errorDict, 'ALL','ALL','Location','word','Word','Incorrect word format','Captalize each word')
df['Location'] = df['Location'].str.title()

print('Total number of unique locations: ',len(df['Location'].unique()))
df['Location'].unique()[:50]
# Out:
# Total number of unique locations:  488
# array(['Plymouth', 'Southampton', 'Rotherham', 'West London', 'Dartford',
#        'Uk', 'Woking', 'Essex', 'Ipswich', 'The City', 'South Croydon',
#        'London', 'Cambridge', 'Manchester', 'Windsor', 'Redhill',
#        'North East England', 'Chester', 'Fleet', 'Portsmouth',
#        'Gateshead', 'Reigate', 'Maidenhead', 'North Yorkshire',
#        'Blackpool', 'Telford', 'St. Albans', 'Newbury', 'Bournemouth',
#        'Aberdeenshire', 'Peterborough', 'West Sussex', 'Bristol',
#        'Salisbury', 'Midlothian', 'North London', 'Lewisham', 'Maidstone',
#        'Tonbridge', 'Doncaster', 'South West England', 'Coventry', 'Kent',
#        'South West London', 'Bath', 'Huntingdon', 'Crawley', 'Scotland',
#        'Wales', 'Birmingham'], dtype=object)

# %% [markdown]
# From the output above it can be see that there are a total of 488 unique values for location. It looks like all these locations are states and cities of the United Kingdom. Thus, a list of states and cities of United Kingdom are collected and compared against the dataset get invalid locations.

# %%
# england.py contains england states and cities
england_states = [x.lower() for x in england.states]
england_cities = [x.lower() for x in england.cities]

# Check if location exists in the list above
valid_location = df['Location'].str.lower().isin(england_states+england_cities)

print('Number of locations after filtering: ',len(df[~valid_location]['Location'].value_counts()))

# Get 25 least repeated values within the dataset
df[~valid_location]['Location'].value_counts().nsmallest(25)
# Out:
# Number of locations after filtering:  110
# Manchaster               1
# Livepool                 1
# Londn                    1
# Hampshira                1
# Cembridge                1
# Oxfords                  2
# Leads                    2
# Warringtn                2
# Croydan                  2
# North Finchley           5
# Sutton-In-Ashfield       7
# St. Neots                8
# Newcastle-Under-Lyme     9
# Trent                    9
# Canary Wharf             9
# Lutterworth              9
# Llandaff North          10
# Broadfield              10
# Cressington             10
# Thorpe St. Andrew       10
# Brent Cross             10
# St. Ives                11
# Gatwick                 11
# King'S Lynn             11
# Axbridge                11
# Name: Location, dtype: int64

# %% [markdown]
# From the output above, we managed to cut down the locations needed to be evaluated to 110 values. Looking at the locations with least value counts, it can also be seen that when the count gets more than 5 or so, it is more likely to be a valid city. Thus, top 20 locations with the least value count is evaluated

# %%
# Function for finding closes match of a location
def find_closest_match(location,series,cut):
    data = list(series)
    return difflib.get_close_matches(location,set(data).difference([location]), n = 1,cutoff=cut)

# %%
# Find index the 25 least repeated "invalid" locations
least_25_locations = df[~valid_location]['Location'].value_counts().nsmallest(25).index

for location in least_25_locations:
    # Fint closest match
    print(location,find_closest_match(location,df['Location'],0.80))
# Out:
# Manchaster ['Manchester']
# Livepool ['Liverpool']
# Londn ['London']
# Hampshira ['Hampshire']
# Cembridge ['Cambridge']
# Oxfords ['Oxford']
# Leads ['Leeds']
# Warringtn ['Warrington']
# Croydan ['Croydon']
# North Finchley []
# Sutton-In-Ashfield []
# St. Neots []
# Newcastle-Under-Lyme []
# Trent []
# Canary Wharf []
# Lutterworth []
# Llandaff North []
# Broadfield []
# Cressington []
# Thorpe St. Andrew []
# Brent Cross []
# St. Ives []
# Gatwick []
# King'S Lynn []
# Axbridge ['Uxbridge']

# %% [markdown]
# From the output above it can be seen the first 9 values are most likely typos, while 'Axbridge' is a valid location in England. Thus, these values would be replaced by its closest match, which all seem to be accurate.

# %%
# Get 9 least repeated location names
top_9_locations = list(df[~valid_location]['Location'].value_counts().nsmallest(9).index)

df[df['Location'].isin(top_9_locations)]
# Out:
#              Id                                              Title  \
# 3894   72635548    Remediation/Earthworks Site Manager  Warrington
# 3957   70607755                             Design Engineer (Ce I)
# 27576  72187429    Branch Manager  Manchester  1301573  Manchester
# 30794  69851673  Financial Services Sales  Face To Face  Liverpool
# 33023  66434582                     Citrix/System Engineer  Oxford
# 33815  68993982               Senior Credit Risk Modelling Analyst
# 35525  69041514                         Senior Information Analyst
# 38125  68705032  Chef De Partie  Seasonal Short Order Cooking R...
# 40477  66749067                Registered Mental Health Nurses Rmn
# 41703  69568721         Manufacturing Engineer  Injection Moulding
# 42834  69690499         It Storage Engineer/Architect  (Linux Hpc)
# 46181  68385104  Graduate / Associate C++ Software Engineers  L...
# 47438  67210891  Trainee Fire Extinguisher Engineers Wanted In ...
#
#          Location               Company   ContractType   ContractTime  \
# 3894    Warringtn   Penguin Recruitment  non-specified      permanent
# 3957    Warringtn                   BPS  non-specified      permanent
# 27576  Manchaster       Prospect Health      full_time  non-specified
# 30794    Livepool  Select Appointments   non-specified      permanent
# 33023     Oxfords                   NaN  non-specified      permanent
# 33815       Leads                 MERJE  non-specified      permanent
# 35525       Leads     Venn Group Ltd     non-specified  non-specified
# 38125       Londn          Chef Results  non-specified  non-specified
# 40477     Croydan                   NaN      part_time  non-specified
# 41703   Hampshira     Austin Fraser Ltd      full_time      permanent
# 42834     Oxfords     Huxley Associates  non-specified  non-specified
# 46181   Cembridge         ECM Selection  non-specified  non-specified
# 47438     Croydan                   NaN  non-specified  non-specified
#
#                           Category Salary            OpenDate  \
# 3894              Engineering Jobs  37500 2012-10-14 12:00:00
# 3957              Engineering Jobs  36000 2013-08-09 00:00:00
# 27576    Healthcare & Nursing Jobs  32500 2012-08-17 00:00:00
# 30794    Accounting & Finance Jobs  13000 2012-01-14 15:00:00
# 33023                      IT Jobs  37500 2012-11-17 15:00:00
# 33815    Accounting & Finance Jobs  32000 2012-12-05 00:00:00
# 35525                      IT Jobs  48000 2013-01-12 15:00:00
# 38125  Hospitality & Catering Jobs  17000 2012-01-27 12:00:00
# 40477    Healthcare & Nursing Jobs  38400 2013-02-01 00:00:00
# 41703             Engineering Jobs  37500 2013-06-26 00:00:00
# 42834                      IT Jobs  55000 2012-07-09 15:00:00
# 46181             Engineering Jobs  30000 2013-04-13 12:00:00
# 47438             Engineering Jobs  16500 2012-05-14 15:00:00
#
#                 CloseDate                      SourceName
# 3894  2012-12-13 12:00:00                cv-library.co.uk
# 3957  2013-11-07 00:00:00                cv-library.co.uk
# 27576 2012-11-15 00:00:00                  staffnurse.com
# 30794 2012-03-14 15:00:00                   jobsite.co.uk
# 33023 2013-01-16 15:00:00             theitjobboard.co.uk
# 33815 2013-01-04 00:00:00                  jobsinrisk.com
# 35525 2013-03-13 15:00:00                        MyUkJobs
# 38125 2012-02-10 12:00:00  jobs.catererandhotelkeeper.com
# 40477 2013-04-02 00:00:00                  Jobcentre Plus
# 41703 2013-09-24 00:00:00        energygenerationjobs.com
# 42834 2012-08-08 15:00:00               gojobsearch.co.uk
# 46181 2013-04-27 12:00:00      jobs.electronicsweekly.com
# 47438 2012-07-13 15:00:00            britishjobsonthe.net

# %%
# Record to Error Dict before making changes
for ind in df.index[df['Location'].isin(top_9_locations)]:
    
    errorDict = addToErrorDict(errorDict,ind,df['Id'][ind],'Location',df['Location'][ind],find_closest_match(df['Location'][ind],df['Location'].unique(),0.80)[0],'Mispelling','Replace mispelled with the correct word')

# %%
# Dictionary to replace the 9 faulty locations
replace_location = {'Manchaster': 'Manchester',
'Livepool': 'Liverpool',
'Londn': 'London',
'Hampshira': 'Hampshire',
'Cembridge': 'Cambridge',
'Oxfords': 'Oxford',
'Leads': 'Leeds',
'Warringtn': 'Warrington',
'Croydan': 'Croydon'}

df['Location'].replace(replace_location,inplace=True)
df['Location'].value_counts()
# Out:
# Uk                    7698
# London                6564
# South East London     2728
# The City              1165
# Central London         825
#                       ...
# Bourne End               9
# St. Neots                8
# South Brent              7
# Sutton-In-Ashfield       7
# North Finchley           5
# Name: Location, Length: 479, dtype: int64

# %% [markdown]
# Here, we are done formatting the 'Location' column

# %% [markdown]
# ### Task 2.9 Examining and Cleaning Company Column

# %%
df[df['Company'].isna()]
# Out:
#              Id                                              Title  \
# 9397   69215963                  Solar Sales Consultant  Inverness
# 9405   71470861  Cnc Machinist / Cnc Machine Operator / Cnc Ope...
# 9416   70315006                                           P/T Cook
# 9442   71471052                            Funds & Pricing Analyst
# 9471   69228189      Canvasser, Field Marketing And Sales Promotor
# ...         ...                                                ...
# 49959  69931438                            Revenue/Pricing Analyst
# 50559  72121207                   Assistant Support Workers X ****
# 50560  70769728  Magazine Advertising Sales Executive (Sports &...
# 50561  68223651                             Community Care Workers
# 50562  69005978                                  Relations Officer
#
#          Location Company   ContractType ContractTime  \
# 9397    Inverness     NaN      full_time    permanent
# 9405     Keighley     NaN      full_time    permanent
# 9416           Uk     NaN      part_time    permanent
# 9442           Uk     NaN      full_time     contract
# 9471        Leeds     NaN      full_time    permanent
# ...           ...     ...            ...          ...
# 49959  Lancashire     NaN  non-specified    permanent
# 50559   Edinburgh     NaN  non-specified     contract
# 50560          Uk     NaN  non-specified    permanent
# 50561   Edinburgh     NaN  non-specified    permanent
# 50562    Scotland     NaN  non-specified    permanent
#
#                                Category   Salary            OpenDate  \
# 9397                         Sales Jobs    50000 2013-03-03 15:00:00
# 9405                   Engineering Jobs    24960 2013-04-22 15:00:00
# 9416        Hospitality & Catering Jobs    13612 2013-01-02 00:00:00
# 9442          Accounting & Finance Jobs    62000 2013-05-10 12:00:00
# 9471   PR, Advertising & Marketing Jobs    22800 2013-09-23 12:00:00
# ...                                 ...      ...                 ...
# 49959  PR, Advertising & Marketing Jobs  27500.0 2012-07-12 15:00:00
# 50559         Healthcare & Nursing Jobs    16570 2012-03-03 12:00:00
# 50560                        Sales Jobs      NaN 2013-10-29 12:00:00
# 50561         Healthcare & Nursing Jobs    17280 2013-06-23 00:00:00
# 50562         Healthcare & Nursing Jobs    55752 2012-04-14 15:00:00
#
#                 CloseDate                 SourceName
# 9397  2013-06-01 15:00:00                fish4.co.uk
# 9405  2013-06-21 15:00:00                fish4.co.uk
# 9416  2013-04-02 00:00:00                fish4.co.uk
# 9442  2013-06-09 12:00:00                fish4.co.uk
# 9471  2013-11-22 12:00:00                fish4.co.uk
# ...                   ...                        ...
# 49959 2012-08-11 15:00:00  simplymarketingjobs.co.uk
# 50559 2012-04-02 12:00:00               scotsman.com
# 50560 2013-12-28 12:00:00               scotsman.com
# 50561 2013-09-21 00:00:00               scotsman.com
# 50562 2012-06-13 15:00:00               scotsman.com
#
# [2576 rows x 11 columns]

# %% [markdown]
# There are several data with no companies. All these values would be set to non-specified

# %%
missing_company = df['Company'].isna()
indices = list(df[missing_company].index)

# Add to ErroDict
for ind in indices:
    errorDict = addToErrorDict(errorDict,ind,df['Id'][ind],'Company','None','Non-specified','Missing values','Replace value as Non-specified')
    
# Set null values as non-specified
df.loc[missing_company,'Company'] = 'non-specified'
df[missing_company]
# Out:
#              Id                                              Title  \
# 9397   69215963                  Solar Sales Consultant  Inverness
# 9405   71470861  Cnc Machinist / Cnc Machine Operator / Cnc Ope...
# 9416   70315006                                           P/T Cook
# 9442   71471052                            Funds & Pricing Analyst
# 9471   69228189      Canvasser, Field Marketing And Sales Promotor
# ...         ...                                                ...
# 49959  69931438                            Revenue/Pricing Analyst
# 50559  72121207                   Assistant Support Workers X ****
# 50560  70769728  Magazine Advertising Sales Executive (Sports &...
# 50561  68223651                             Community Care Workers
# 50562  69005978                                  Relations Officer
#
#          Location        Company   ContractType ContractTime  \
# 9397    Inverness  non-specified      full_time    permanent
# 9405     Keighley  non-specified      full_time    permanent
# 9416           Uk  non-specified      part_time    permanent
# 9442           Uk  non-specified      full_time     contract
# 9471        Leeds  non-specified      full_time    permanent
# ...           ...            ...            ...          ...
# 49959  Lancashire  non-specified  non-specified    permanent
# 50559   Edinburgh  non-specified  non-specified     contract
# 50560          Uk  non-specified  non-specified    permanent
# 50561   Edinburgh  non-specified  non-specified    permanent
# 50562    Scotland  non-specified  non-specified    permanent
#
#                                Category   Salary            OpenDate  \
# 9397                         Sales Jobs    50000 2013-03-03 15:00:00
# 9405                   Engineering Jobs    24960 2013-04-22 15:00:00
# 9416        Hospitality & Catering Jobs    13612 2013-01-02 00:00:00
# 9442          Accounting & Finance Jobs    62000 2013-05-10 12:00:00
# 9471   PR, Advertising & Marketing Jobs    22800 2013-09-23 12:00:00
# ...                                 ...      ...                 ...
# 49959  PR, Advertising & Marketing Jobs  27500.0 2012-07-12 15:00:00
# 50559         Healthcare & Nursing Jobs    16570 2012-03-03 12:00:00
# 50560                        Sales Jobs      NaN 2013-10-29 12:00:00
# 50561         Healthcare & Nursing Jobs    17280 2013-06-23 00:00:00
# 50562         Healthcare & Nursing Jobs    55752 2012-04-14 15:00:00
#
#                 CloseDate                 SourceName
# 9397  2013-06-01 15:00:00                fish4.co.uk
# 9405  2013-06-21 15:00:00                fish4.co.uk
# 9416  2013-04-02 00:00:00                fish4.co.uk
# 9442  2013-06-09 12:00:00                fish4.co.uk
# 9471  2013-11-22 12:00:00                fish4.co.uk
# ...                   ...                        ...
# 49959 2012-08-11 15:00:00  simplymarketingjobs.co.uk
# 50559 2012-04-02 12:00:00               scotsman.com
# 50560 2013-12-28 12:00:00               scotsman.com
# 50561 2013-09-21 00:00:00               scotsman.com
# 50562 2012-06-13 15:00:00               scotsman.com
#
# [2576 rows x 11 columns]

# %%
# Get companies that does not contain alphanuerical characters
invalid_company = df['Company'].str.fullmatch(r'\W+')
df[invalid_company]
# Out:
#              Id                                              Title  \
# 24798  66425908                        Support Workeraberdeenshire
# 24799  46629065  Registered Manager East Sussex Fostering Services
# 24800  46626555       Consultant Clinical Psychologist Job Norwich
# 24801  56209802                            Staff Nurses Winchester
# 24802  64573309  Rgn Nights Stokeontrent Nights Perm Role Excel...
# ...         ...                                                ...
# 49590  67027226                            Media Relations Manager
# 49591  67027220                           Digital Campaign Manager
# 49592  72425166                      Principal/Managing Consultant
# 49593  71142128                        Pricing Analyst  Telematics
# 49594  69567368                          Desktop Solutions Manager
#
#              Location Company   ContractType   ContractTime  \
# 24798   Aberdeenshire       -  non-specified  non-specified
# 24799     East Sussex       -      full_time  non-specified
# 24800         Norwich       -      full_time  non-specified
# 24801      Winchester       -  non-specified  non-specified
# 24802  Stoke-On-Trent       -      full_time  non-specified
# ...               ...     ...            ...            ...
# 49590  Cambridgeshire       -  non-specified       contract
# 49591  Leicestershire       -  non-specified      permanent
# 49592            Bath       -  non-specified      permanent
# 49593       Guildford       -  non-specified      permanent
# 49594         Swindon       -  non-specified      permanent
#
#                                Category Salary            OpenDate  \
# 24798         Healthcare & Nursing Jobs  15360 2013-04-24 15:00:00
# 24799         Healthcare & Nursing Jobs      - 2012-01-08 12:00:00
# 24800         Healthcare & Nursing Jobs  50000 2012-03-14 00:00:00
# 24801         Healthcare & Nursing Jobs  24333 2013-10-17 15:00:00
# 24802         Healthcare & Nursing Jobs      - 2013-09-02 15:00:00
# ...                                 ...    ...                 ...
# 49590  PR, Advertising & Marketing Jobs  35000 2012-10-11 12:00:00
# 49591  PR, Advertising & Marketing Jobs  38500 2013-07-19 00:00:00
# 49592         Accounting & Finance Jobs  80000 2013-05-15 15:00:00
# 49593         Accounting & Finance Jobs  39000 2012-09-30 15:00:00
# 49594                           IT Jobs  42500 2013-11-11 15:00:00
#
#                 CloseDate         SourceName
# 24798 2013-06-23 15:00:00     careworx.co.uk
# 24799 2012-02-07 12:00:00     careworx.co.uk
# 24800 2012-04-13 00:00:00     careworx.co.uk
# 24801 2013-10-31 15:00:00     careworx.co.uk
# 24802 2013-11-01 15:00:00     careworx.co.uk
# ...                   ...                ...
# 49590 2012-12-10 12:00:00  michaelpage.co.uk
# 49591 2013-10-17 00:00:00  michaelpage.co.uk
# 49592 2013-08-13 15:00:00  michaelpage.co.uk
# 49593 2012-11-29 15:00:00  michaelpage.co.uk
# 49594 2013-12-11 15:00:00  michaelpage.co.uk
#
# [2374 rows x 11 columns]

# %% [markdown]
# From the output above it can be seem that a lot of company names are labeled as "-" and there could be others but they are all non alphanumerical values. Thus, they will all be replaced with non-specified

# %%
indices = df[invalid_company].index
for ind in indices:
    # Record to errorDict
    errorDict = addToErrorDict(errorDict,ind,df['Id'][ind],'Company',df['Company'][ind],'non-specified','Dummy values','Set to non-specified')
# Set to non-specified
df.loc[invalid_company,'Company'] = 'non-specified'
df[invalid_company]
# Out:
#              Id                                              Title  \
# 24798  66425908                        Support Workeraberdeenshire
# 24799  46629065  Registered Manager East Sussex Fostering Services
# 24800  46626555       Consultant Clinical Psychologist Job Norwich
# 24801  56209802                            Staff Nurses Winchester
# 24802  64573309  Rgn Nights Stokeontrent Nights Perm Role Excel...
# ...         ...                                                ...
# 49590  67027226                            Media Relations Manager
# 49591  67027220                           Digital Campaign Manager
# 49592  72425166                      Principal/Managing Consultant
# 49593  71142128                        Pricing Analyst  Telematics
# 49594  69567368                          Desktop Solutions Manager
#
#              Location        Company   ContractType   ContractTime  \
# 24798   Aberdeenshire  non-specified  non-specified  non-specified
# 24799     East Sussex  non-specified      full_time  non-specified
# 24800         Norwich  non-specified      full_time  non-specified
# 24801      Winchester  non-specified  non-specified  non-specified
# 24802  Stoke-On-Trent  non-specified      full_time  non-specified
# ...               ...            ...            ...            ...
# 49590  Cambridgeshire  non-specified  non-specified       contract
# 49591  Leicestershire  non-specified  non-specified      permanent
# 49592            Bath  non-specified  non-specified      permanent
# 49593       Guildford  non-specified  non-specified      permanent
# 49594         Swindon  non-specified  non-specified      permanent
#
#                                Category Salary            OpenDate  \
# 24798         Healthcare & Nursing Jobs  15360 2013-04-24 15:00:00
# 24799         Healthcare & Nursing Jobs      - 2012-01-08 12:00:00
# 24800         Healthcare & Nursing Jobs  50000 2012-03-14 00:00:00
# 24801         Healthcare & Nursing Jobs  24333 2013-10-17 15:00:00
# 24802         Healthcare & Nursing Jobs      - 2013-09-02 15:00:00
# ...                                 ...    ...                 ...
# 49590  PR, Advertising & Marketing Jobs  35000 2012-10-11 12:00:00
# 49591  PR, Advertising & Marketing Jobs  38500 2013-07-19 00:00:00
# 49592         Accounting & Finance Jobs  80000 2013-05-15 15:00:00
# 49593         Accounting & Finance Jobs  39000 2012-09-30 15:00:00
# 49594                           IT Jobs  42500 2013-11-11 15:00:00
#
#                 CloseDate         SourceName
# 24798 2013-06-23 15:00:00     careworx.co.uk
# 24799 2012-02-07 12:00:00     careworx.co.uk
# 24800 2012-04-13 00:00:00     careworx.co.uk
# 24801 2013-10-31 15:00:00     careworx.co.uk
# 24802 2013-11-01 15:00:00     careworx.co.uk
# ...                   ...                ...
# 49590 2012-12-10 12:00:00  michaelpage.co.uk
# 49591 2013-10-17 00:00:00  michaelpage.co.uk
# 49592 2013-08-13 15:00:00  michaelpage.co.uk
# 49593 2012-11-29 15:00:00  michaelpage.co.uk
# 49594 2013-12-11 15:00:00  michaelpage.co.uk
#
# [2374 rows x 11 columns]

# %% [markdown]
# Now that dummy values are being accounted for, it is time to check for invalid values

# %%
# Get companies that has non alphanumeric characters but not non-specified
valid_company = df['Company'].str.fullmatch(r'([a-zA-Z0-9]\s?)+')
non_specified = df['Company'] == 'non-specified'
df[~valid_company & ~non_specified]
# Out:
#              Id                                              Title  \
# 1      67945005        Technical Support Engineer  French Speaking
# 5      67944712                        Theatre Lead/Deputy Manager
# 6      67946379            Technical Director  Strategic Modelling
# 10     66160421                          Structural Cad Technician
# 11     67946033           Offshore Project Manager Of Hvdc Package
# ...         ...                                                ...
# 50709  70768357        Perl Developer Junior / Senior ****K  ****K
# 50714  72118590  Senior Perl Developer Global Dot Com ****K  ****K
# 50730  69815649                           Futures Dma Desk Support
# 50747  68704692                     Graduate Softwareweb Developer
# 50749  72420369              Graduate Operations Technical Analyst
#
#             Location                                Company   ContractType  \
# 1        Southampton                   Matchtech Group plc.  non-specified
# 5                 Uk                   Matchtech Group plc.  non-specified
# 6             Woking                   Matchtech Group plc.  non-specified
# 10     South Croydon                   Matchtech Group plc.  non-specified
# 11            London                   Matchtech Group plc.  non-specified
# ...              ...                                    ...            ...
# 50709             Uk               Orleston Associates Ltd.      full_time
# 50714         London               Orleston Associates Ltd.      full_time
# 50730         London               Agora Search & Selection  non-specified
# 50747         London  UNKNOWN   auto added by vacany import  non-specified
# 50749     Hungerford  UNKNOWN   auto added by vacany import  non-specified
#
#         ContractTime                   Category   Salary            OpenDate  \
# 1      non-specified           Engineering Jobs    24500 2012-06-24 00:00:00
# 5      non-specified           Engineering Jobs      NaN 2012-04-24 00:00:00
# 6      non-specified           Engineering Jobs    61500 2012-12-14 00:00:00
# 10     non-specified           Engineering Jobs    24500 2013-02-21 12:00:00
# 11     non-specified           Engineering Jobs    51000 2012-06-17 00:00:00
# ...              ...                        ...      ...                 ...
# 50709  non-specified                    IT Jobs    32500 2013-05-01 00:00:00
# 50714  non-specified                    IT Jobs    57500 2013-08-24 00:00:00
# 50730      permanent  Accounting & Finance Jobs  90000.0 2013-06-13 15:00:00
# 50747  non-specified                    IT Jobs    25000 2012-01-12 12:00:00
# 50749  non-specified                    IT Jobs      NaN 2013-09-13 15:00:00
#
#                 CloseDate              SourceName
# 1     2012-07-24 00:00:00    rengineeringjobs.com
# 5     2012-05-24 00:00:00    rengineeringjobs.com
# 6     2013-01-13 00:00:00    rengineeringjobs.com
# 10    2013-03-07 12:00:00    rengineeringjobs.com
# 11    2012-07-01 00:00:00    rengineeringjobs.com
# ...                   ...                     ...
# 50709 2013-06-30 00:00:00           jobs.perl.org
# 50714 2013-10-23 00:00:00           jobs.perl.org
# 50730 2013-08-12 15:00:00  frontofficebanking.com
# 50747 2012-03-12 12:00:00              grb.uk.com
# 50749 2013-11-12 15:00:00              grb.uk.com
#
# [3458 rows x 11 columns]

# %% [markdown]
# It seems like some companies ends with a ".". These symbols would be replaced.

# %%
# Get companies ending with a .
company_dot = df['Company'].str.fullmatch('.*\.$',na=False)
indices = df[company_dot].index
for ind in indices:
    # edd to errorDict
    errorDict = addToErrorDict(errorDict,ind,df['Id'][ind],'Company',df['Company'][ind],df['Company'][ind][:-1],'Punctuation at the end','Remove punctuation')
# Remove the ending .
df.loc[company_dot,'Company'] = df['Company'][ind][:-1]
df[company_dot]
# Out:
#              Id                                              Title  \
# 1      67945005        Technical Support Engineer  French Speaking
# 5      67944712                        Theatre Lead/Deputy Manager
# 6      67946379            Technical Director  Strategic Modelling
# 10     66160421                          Structural Cad Technician
# 11     67946033           Offshore Project Manager Of Hvdc Package
# ...         ...                                                ...
# 49920  72609749  Paediatric Neuro Rehab Staff Nurse  Central Lo...
# 49930  72609221                                 Senior Odp  Surrey
# 50674  56281394                        Chinese Speaking Pa Finance
# 50709  70768357        Perl Developer Junior / Senior ****K  ****K
# 50714  72118590  Senior Perl Developer Global Dot Com ****K  ****K
#
#              Location                  Company   ContractType   ContractTime  \
# 1         Southampton  Orleston Associates Ltd  non-specified  non-specified
# 5                  Uk  Orleston Associates Ltd  non-specified  non-specified
# 6              Woking  Orleston Associates Ltd  non-specified  non-specified
# 10      South Croydon  Orleston Associates Ltd  non-specified  non-specified
# 11             London  Orleston Associates Ltd  non-specified  non-specified
# ...               ...                      ...            ...            ...
# 49920  Central London  Orleston Associates Ltd  non-specified      permanent
# 49930          Surrey  Orleston Associates Ltd  non-specified      permanent
# 50674          London  Orleston Associates Ltd      full_time      permanent
# 50709              Uk  Orleston Associates Ltd      full_time  non-specified
# 50714          London  Orleston Associates Ltd      full_time  non-specified
#
#                         Category Salary            OpenDate  \
# 1               Engineering Jobs  24500 2012-06-24 00:00:00
# 5               Engineering Jobs    NaN 2012-04-24 00:00:00
# 6               Engineering Jobs  61500 2012-12-14 00:00:00
# 10              Engineering Jobs  24500 2013-02-21 12:00:00
# 11              Engineering Jobs  51000 2012-06-17 00:00:00
# ...                          ...    ...                 ...
# 49920  Healthcare & Nursing Jobs  33465 2012-09-17 15:00:00
# 49930  Healthcare & Nursing Jobs  34000 2012-11-23 00:00:00
# 50674  Accounting & Finance Jobs  37500 2013-06-21 00:00:00
# 50709                    IT Jobs  32500 2013-05-01 00:00:00
# 50714                    IT Jobs  57500 2013-08-24 00:00:00
#
#                 CloseDate            SourceName
# 1     2012-07-24 00:00:00  rengineeringjobs.com
# 5     2012-05-24 00:00:00  rengineeringjobs.com
# 6     2013-01-13 00:00:00  rengineeringjobs.com
# 10    2013-03-07 12:00:00  rengineeringjobs.com
# 11    2012-07-01 00:00:00  rengineeringjobs.com
# ...                   ...                   ...
# 49920 2012-10-17 15:00:00  nursingtimesjobs.com
# 49930 2013-01-22 00:00:00  nursingtimesjobs.com
# 50674 2013-08-20 00:00:00     jobsfinancial.com
# 50709 2013-06-30 00:00:00         jobs.perl.org
# 50714 2013-10-23 00:00:00         jobs.perl.org
#
# [784 rows x 11 columns]

# %% [markdown]
# After this, let's check for other errors

# %%
# Valid company should contain alphanumerical characters separated by spaces
valid_company = df['Company'].str.fullmatch(r'([a-zA-Z0-9]\s?)+',na=False)
df[~valid_company & ~non_specified]
# Out:
#              Id                                              Title  \
# 117    69669159                   Mechanical Engineer / Fe Analyst
# 230    68544534          Structured Cabling Engineers  M4 Corridor
# 794    69083414                        Multiskilled Shift Engineer
# 877    72540018                  Nursery Nurse  Baby Room  Bristol
# 892    71125509  Hvac Maintenance Engineer Central London ****K...
# ...         ...                                                ...
# 50687  69035743                         Lead Calculations Engineer
# 50699  67383954  Telesales Consultant  Telemarketing / Coldcalling
# 50730  69815649                           Futures Dma Desk Support
# 50747  68704692                     Graduate Softwareweb Developer
# 50749  72420369              Graduate Operations Technical Analyst
#
#                 Location                                          Company  \
# 117            Knutsford                                       Intec  Ltd
# 230               Slough                                       Intec  Ltd
# 794    South East London   Mobile Technical Staff   Technical Engineering
# 877              Bristol  Hays Specialist Recruitment   Further Education
# 892             The City      Randstad Construction, Property Engineering
# ...                  ...                                              ...
# 50687      Wolverhampton                                   Intec  Limited
# 50699                 Uk                                 Eclipse  Limited
# 50730             London                         Agora Search & Selection
# 50747             London            UNKNOWN   auto added by vacany import
# 50749         Hungerford            UNKNOWN   auto added by vacany import
#
#         ContractType   ContractTime                   Category   Salary  \
# 117    non-specified      permanent           Engineering Jobs    42500
# 230    non-specified      permanent           Engineering Jobs    25200
# 794    non-specified      permanent           Engineering Jobs    27500
# 877    non-specified      permanent              Teaching Jobs    16000
# 892    non-specified      permanent           Engineering Jobs    29000
# ...              ...            ...                        ...      ...
# 50687  non-specified      permanent           Engineering Jobs    39000
# 50699  non-specified      permanent                 Sales Jobs    20000
# 50730  non-specified      permanent  Accounting & Finance Jobs  90000.0
# 50747  non-specified  non-specified                    IT Jobs    25000
# 50749  non-specified  non-specified                    IT Jobs      NaN
#
#                  OpenDate           CloseDate              SourceName
# 117   2013-03-23 12:00:00 2013-05-22 12:00:00    rengineeringjobs.com
# 230   2013-05-05 00:00:00 2013-08-03 00:00:00    rengineeringjobs.com
# 794   2013-08-27 12:00:00 2013-11-25 12:00:00        cv-library.co.uk
# 877   2013-03-10 15:00:00 2013-06-08 15:00:00        cv-library.co.uk
# 892   2012-03-18 15:00:00 2012-05-17 15:00:00        cv-library.co.uk
# ...                   ...                 ...                     ...
# 50687 2012-04-15 00:00:00 2012-05-15 00:00:00   renewablescareers.com
# 50699 2013-12-11 15:00:00 2014-03-11 15:00:00      legalprospects.com
# 50730 2013-06-13 15:00:00 2013-08-12 15:00:00  frontofficebanking.com
# 50747 2012-01-12 12:00:00 2012-03-12 12:00:00              grb.uk.com
# 50749 2013-09-13 15:00:00 2013-11-12 15:00:00              grb.uk.com
#
# [2674 rows x 11 columns]

# %% [markdown]
# It is strange that lookin at the values above, it seems like they should pass the regex as they all have alphanumerical characters. Let's check these values individually

# %%
df[~valid_company & ~non_specified]['Company']
# Out:
# 117                                           Intec  Ltd
# 230                                           Intec  Ltd
# 794       Mobile Technical Staff   Technical Engineering
# 877      Hays Specialist Recruitment   Further Education
# 892          Randstad Construction, Property Engineering
#                               ...
# 50687                                     Intec  Limited
# 50699                                   Eclipse  Limited
# 50730                           Agora Search & Selection
# 50747              UNKNOWN   auto added by vacany import
# 50749              UNKNOWN   auto added by vacany import
# Name: Company, Length: 2674, dtype: object

# %% [markdown]
# So some of them has more than just 1 white spaces with the word 'Ltd' or 'Limited' at the end. These values would be further evaluated

# %%
multi_space_ltd = df['Company'].str.contains(r'\s\s+(?:[lL][tT][dD]|[lL]imited)',na=False)
df[multi_space_ltd]
# Out:
#              Id                                              Title  \
# 117    69669159                   Mechanical Engineer / Fe Analyst
# 230    68544534          Structured Cabling Engineers  M4 Corridor
# 1354   69540430               External Sales  Electrical Wholesale
# 1394   69933882          Trade Counter Sales  Electrical Wholesale
# 1477   72539789                  Intervention Progressions Manager
# ...         ...                                                ...
# 50103  71747316                          Engineer Surveyor (Derby)
# 50111  66697323                     Continuous Improvement Manager
# 50466  71070728              Electrician/Building Service Engineer
# 50687  69035743                         Lead Calculations Engineer
# 50699  67383954  Telesales Consultant  Telemarketing / Coldcalling
#
#               Location                           Company   ContractType  \
# 117          Knutsford                        Intec  Ltd  non-specified
# 230             Slough                        Intec  Ltd  non-specified
# 1354         Leicester                          ERS  Ltd  non-specified
# 1394             Leeds                          ERS  Ltd  non-specified
# 1477        Birmingham                     Edustaff  Ltd  non-specified
# ...                ...                               ...            ...
# 50103       Derbyshire  Forces Recruitment Services  Ltd      full_time
# 50111  Buckinghamshire                 MPI Aviation  Ltd      full_time
# 50466       Lancashire  Forces Recruitment Services  Ltd      full_time
# 50687    Wolverhampton                    Intec  Limited  non-specified
# 50699               Uk                  Eclipse  Limited  non-specified
#
#       ContractTime          Category   Salary            OpenDate  \
# 117      permanent  Engineering Jobs    42500 2013-03-23 12:00:00
# 230      permanent  Engineering Jobs    25200 2013-05-05 00:00:00
# 1354     permanent        Sales Jobs    23500 2012-06-13 15:00:00
# 1394     permanent        Sales Jobs    16500 2012-09-11 00:00:00
# 1477     permanent     Teaching Jobs    25294 2013-04-04 00:00:00
# ...            ...               ...      ...                 ...
# 50103    permanent  Engineering Jobs  30500.0 2013-10-29 00:00:00
# 50111    permanent  Engineering Jobs  37500.0 2013-01-01 12:00:00
# 50466    permanent  Engineering Jobs    29000 2013-01-29 00:00:00
# 50687    permanent  Engineering Jobs    39000 2012-04-15 00:00:00
# 50699    permanent        Sales Jobs    20000 2013-12-11 15:00:00
#
#                 CloseDate             SourceName
# 117   2013-05-22 12:00:00   rengineeringjobs.com
# 230   2013-08-03 00:00:00   rengineeringjobs.com
# 1354  2012-09-11 15:00:00       cv-library.co.uk
# 1394  2012-11-10 00:00:00       cv-library.co.uk
# 1477  2013-05-04 00:00:00       cv-library.co.uk
# ...                   ...                    ...
# 50103 2013-11-28 00:00:00  thecareerengineer.com
# 50111 2013-04-01 12:00:00  thecareerengineer.com
# 50466 2013-02-28 00:00:00              JobSearch
# 50687 2012-05-15 00:00:00  renewablescareers.com
# 50699 2014-03-11 15:00:00     legalprospects.com
#
# [475 rows x 11 columns]

# %% [markdown]
# Looking at the values, it seems like there are a lot of companies with the term 'Ltd' and 'Limited'. Since they both mean the same thing, Lets replace all of them into one universal term 'Limited' first

# %%
# Function to replace ltd, limited, Ltd with Ltd
def replace_ltd(company):
    ltds = re.match(r'.*([lL](?:[tT][dD]|imited)\.?).*',company).groups()
    for ltd in ltds:
#         print('Before Altering: ',company)
        company = company.replace(ltd,'Ltd')
#         print('After Altering: ',company)
    return company

# %%
# Get companies with words ltd, Ltd, limited, Limited
limited = df['Company'].str.contains(r'[lL](?:[tT][dD]|imited)\.?',na=False)
indices = df[limited].index
for ind in indices:
    company = df['Company'][ind]
    # Record to errorDict
    errorDict = addToErrorDict(errorDict,ind,df['Id'][ind],'Company',company,replace_ltd(company),'Multiple variations of a term','Set to a global term')

# Replace those values with one global value Ltd
df.loc[limited,'Company'] = df.loc[limited,'Company'].apply(lambda x: replace_ltd(x))
df[limited]
# Out:
#              Id                                              Title  \
# 1      67945005        Technical Support Engineer  French Speaking
# 5      67944712                        Theatre Lead/Deputy Manager
# 6      67946379            Technical Director  Strategic Modelling
# 10     66160421                          Structural Cad Technician
# 11     67946033           Offshore Project Manager Of Hvdc Package
# ...         ...                                                ...
# 50724  68538231                              Treasury Sales Urgent
# 50736  68538230  Junior Corporate Fx Sales (X****)  Immediate S...
# 50742  67142856               Senior Business Analyst  Data Mining
# 50751  66372417                 Graduate Engineer (Water Industry)
# 50752  70139229       Health & Social Care Tutor/Assessor  Bristol
#
#                 Location                               Company   ContractType  \
# 1            Southampton               Orleston Associates Ltd  non-specified
# 5                     Uk               Orleston Associates Ltd  non-specified
# 6                 Woking               Orleston Associates Ltd  non-specified
# 10         South Croydon               Orleston Associates Ltd  non-specified
# 11                London               Orleston Associates Ltd  non-specified
# ...                  ...                                   ...            ...
# 50724             London  City Wharf Financial Recruitment Ltd  non-specified
# 50736             London  City Wharf Financial Recruitment Ltd  non-specified
# 50742                 Uk           Global Payments Network Ltd  non-specified
# 50751  South Lanarkshire                   Carrington West Ltd      full_time
# 50752                 Uk                  Pursuit Training Ltd  non-specified
#
#         ContractTime                   Category   Salary            OpenDate  \
# 1      non-specified           Engineering Jobs    24500 2012-06-24 00:00:00
# 5      non-specified           Engineering Jobs      NaN 2012-04-24 00:00:00
# 6      non-specified           Engineering Jobs    61500 2012-12-14 00:00:00
# 10     non-specified           Engineering Jobs    24500 2013-02-21 12:00:00
# 11     non-specified           Engineering Jobs    51000 2012-06-17 00:00:00
# ...              ...                        ...      ...                 ...
# 50724      permanent  Accounting & Finance Jobs  30000.0 2012-02-20 15:00:00
# 50736      permanent  Accounting & Finance Jobs  20000.0 2013-04-20 12:00:00
# 50742      permanent                    IT Jobs    50000 2012-01-30 12:00:00
# 50751       contract           Engineering Jobs    20000 2013-01-19 00:00:00
# 50752      permanent              Teaching Jobs    18000 2012-08-11 00:00:00
#
#                 CloseDate              SourceName
# 1     2012-07-24 00:00:00    rengineeringjobs.com
# 5     2012-05-24 00:00:00    rengineeringjobs.com
# 6     2013-01-13 00:00:00    rengineeringjobs.com
# 10    2013-03-07 12:00:00    rengineeringjobs.com
# 11    2012-07-01 00:00:00    rengineeringjobs.com
# ...                   ...                     ...
# 50724 2012-04-20 15:00:00  frontofficebanking.com
# 50736 2013-07-19 12:00:00  frontofficebanking.com
# 50742 2012-02-29 12:00:00  cardandpaymentjobs.com
# 50751 2013-04-19 00:00:00       thegraduate.co.uk
# 50752 2012-10-10 00:00:00          cvjobstore.com
#
# [11718 rows x 11 columns]

# %% [markdown]
# Now that every variations of 'Limited' is formatted uniformly, it is time to go back to checking multiple white spaces

# %%
# Get companies with 2 spaces before the word Ltd
multi_space_ltd = df['Company'].str.contains(r'\s\s+(?:[lL][tT][dD]|[lL]imited)',na=False)
df[multi_space_ltd]
# Out:
#              Id                                              Title  \
# 117    69669159                   Mechanical Engineer / Fe Analyst
# 230    68544534          Structured Cabling Engineers  M4 Corridor
# 1354   69540430               External Sales  Electrical Wholesale
# 1394   69933882          Trade Counter Sales  Electrical Wholesale
# 1477   72539789                  Intervention Progressions Manager
# ...         ...                                                ...
# 50103  71747316                          Engineer Surveyor (Derby)
# 50111  66697323                     Continuous Improvement Manager
# 50466  71070728              Electrician/Building Service Engineer
# 50687  69035743                         Lead Calculations Engineer
# 50699  67383954  Telesales Consultant  Telemarketing / Coldcalling
#
#               Location                           Company   ContractType  \
# 117          Knutsford                        Intec  Ltd  non-specified
# 230             Slough                        Intec  Ltd  non-specified
# 1354         Leicester                          ERS  Ltd  non-specified
# 1394             Leeds                          ERS  Ltd  non-specified
# 1477        Birmingham                     Edustaff  Ltd  non-specified
# ...                ...                               ...            ...
# 50103       Derbyshire  Forces Recruitment Services  Ltd      full_time
# 50111  Buckinghamshire                 MPI Aviation  Ltd      full_time
# 50466       Lancashire  Forces Recruitment Services  Ltd      full_time
# 50687    Wolverhampton                        Intec  Ltd  non-specified
# 50699               Uk                      Eclipse  Ltd  non-specified
#
#       ContractTime          Category   Salary            OpenDate  \
# 117      permanent  Engineering Jobs    42500 2013-03-23 12:00:00
# 230      permanent  Engineering Jobs    25200 2013-05-05 00:00:00
# 1354     permanent        Sales Jobs    23500 2012-06-13 15:00:00
# 1394     permanent        Sales Jobs    16500 2012-09-11 00:00:00
# 1477     permanent     Teaching Jobs    25294 2013-04-04 00:00:00
# ...            ...               ...      ...                 ...
# 50103    permanent  Engineering Jobs  30500.0 2013-10-29 00:00:00
# 50111    permanent  Engineering Jobs  37500.0 2013-01-01 12:00:00
# 50466    permanent  Engineering Jobs    29000 2013-01-29 00:00:00
# 50687    permanent  Engineering Jobs    39000 2012-04-15 00:00:00
# 50699    permanent        Sales Jobs    20000 2013-12-11 15:00:00
#
#                 CloseDate             SourceName
# 117   2013-05-22 12:00:00   rengineeringjobs.com
# 230   2013-08-03 00:00:00   rengineeringjobs.com
# 1354  2012-09-11 15:00:00       cv-library.co.uk
# 1394  2012-11-10 00:00:00       cv-library.co.uk
# 1477  2013-05-04 00:00:00       cv-library.co.uk
# ...                   ...                    ...
# 50103 2013-11-28 00:00:00  thecareerengineer.com
# 50111 2013-04-01 12:00:00  thecareerengineer.com
# 50466 2013-02-28 00:00:00              JobSearch
# 50687 2012-05-15 00:00:00  renewablescareers.com
# 50699 2014-03-11 15:00:00     legalprospects.com
#
# [475 rows x 11 columns]

# %% [markdown]
# Those white spaces would all be removed

# %%
# Function to remove the extra whitespace
def remove_whitespace(company):
    ltds = re.match(r'.*(\s\s+)Ltd.*',company).groups()
    for ltd in ltds:
#         print('Before Altering: ',company)
        company = company.replace(ltd,' ')
#         print('After Altering: ',company)
    return company

# %%
# Get companies with 2 white spaces together before Ltd
multispace_ltd = df['Company'].str.contains(r'\s\s+Ltd',na=False)
indices = df[multispace_ltd].index
for ind in indices:
    company = df['Company'][ind]
    new_company = remove_whitespace(company)
    # Record to errorDict
    errorDict = addToErrorDict(errorDict,ind,df['Id'][ind],'Company',company,new_company,'Multiple white spaces before a term','Set to only 1 whitespace')
    
    # Replace the multiple whitespaces as 1 whitespace
    df.loc[ind,'Company'] = new_company
    
df[multispace_ltd]
# Out:
#              Id                                              Title  \
# 117    69669159                   Mechanical Engineer / Fe Analyst
# 230    68544534          Structured Cabling Engineers  M4 Corridor
# 1354   69540430               External Sales  Electrical Wholesale
# 1394   69933882          Trade Counter Sales  Electrical Wholesale
# 1477   72539789                  Intervention Progressions Manager
# ...         ...                                                ...
# 50103  71747316                          Engineer Surveyor (Derby)
# 50111  66697323                     Continuous Improvement Manager
# 50466  71070728              Electrician/Building Service Engineer
# 50687  69035743                         Lead Calculations Engineer
# 50699  67383954  Telesales Consultant  Telemarketing / Coldcalling
#
#               Location                          Company   ContractType  \
# 117          Knutsford                        Intec Ltd  non-specified
# 230             Slough                        Intec Ltd  non-specified
# 1354         Leicester                          ERS Ltd  non-specified
# 1394             Leeds                          ERS Ltd  non-specified
# 1477        Birmingham                     Edustaff Ltd  non-specified
# ...                ...                              ...            ...
# 50103       Derbyshire  Forces Recruitment Services Ltd      full_time
# 50111  Buckinghamshire                 MPI Aviation Ltd      full_time
# 50466       Lancashire  Forces Recruitment Services Ltd      full_time
# 50687    Wolverhampton                        Intec Ltd  non-specified
# 50699               Uk                      Eclipse Ltd  non-specified
#
#       ContractTime          Category   Salary            OpenDate  \
# 117      permanent  Engineering Jobs    42500 2013-03-23 12:00:00
# 230      permanent  Engineering Jobs    25200 2013-05-05 00:00:00
# 1354     permanent        Sales Jobs    23500 2012-06-13 15:00:00
# 1394     permanent        Sales Jobs    16500 2012-09-11 00:00:00
# 1477     permanent     Teaching Jobs    25294 2013-04-04 00:00:00
# ...            ...               ...      ...                 ...
# 50103    permanent  Engineering Jobs  30500.0 2013-10-29 00:00:00
# 50111    permanent  Engineering Jobs  37500.0 2013-01-01 12:00:00
# 50466    permanent  Engineering Jobs    29000 2013-01-29 00:00:00
# 50687    permanent  Engineering Jobs    39000 2012-04-15 00:00:00
# 50699    permanent        Sales Jobs    20000 2013-12-11 15:00:00
#
#                 CloseDate             SourceName
# 117   2013-05-22 12:00:00   rengineeringjobs.com
# 230   2013-08-03 00:00:00   rengineeringjobs.com
# 1354  2012-09-11 15:00:00       cv-library.co.uk
# 1394  2012-11-10 00:00:00       cv-library.co.uk
# 1477  2013-05-04 00:00:00       cv-library.co.uk
# ...                   ...                    ...
# 50103 2013-11-28 00:00:00  thecareerengineer.com
# 50111 2013-04-01 12:00:00  thecareerengineer.com
# 50466 2013-02-28 00:00:00              JobSearch
# 50687 2012-05-15 00:00:00  renewablescareers.com
# 50699 2014-03-11 15:00:00     legalprospects.com
#
# [475 rows x 11 columns]

# %% [markdown]
# Now that extra white spaces are remove, time to check for other errors

# %%
valid_company = df['Company'].str.fullmatch(r'([a-zA-Z0-9]\s?)+',na=False)
df[~valid_company & ~non_specified]['Company']
# Out:
# 794       Mobile Technical Staff   Technical Engineering
# 877      Hays Specialist Recruitment   Further Education
# 892          Randstad Construction, Property Engineering
# 1102                   HPR Consultancy Ltd t/a HPRtalent
# 1152                      Cooper Lomaz   Bury St Edmunds
#                               ...
# 50658                              Net Recruit.co.uk Ltd
# 50684                     Atkins Ltd   Water Environment
# 50730                           Agora Search & Selection
# 50747              UNKNOWN   auto added by vacany import
# 50749              UNKNOWN   auto added by vacany import
# Name: Company, Length: 2212, dtype: object

# %% [markdown]
# It can be seen that one of the values contain the term 't/a'. This term seems to refer to "trading as". For example, "Legal name" t/a "Business name". Let's check if every single company is named the same

# %%
# Get companies with the term t/a
ta_companies = df['Company'].str.contains(r'[tT]/[aA]',na=False)
df[ta_companies]
# Out:
#              Id                                              Title  \
# 1102   66600547              Internal Sales Executive Ppe/Workwear
# 2279   69537392                                 Financial Engineer
# 3035   70410175       Export Development Manager  Equine Nutrition
# 4440   66600480        Business Development Manager  Pet Nutrition
# 5397   70764450       Regulatory Affairs Manager  Animal Nutrition
# 6523   66179102                                  Sales Team Leader
# 6819   66925730               Windows 7 Roll Out Migration Support
# 7340   66600517                Territory Manager  Animal Insurance
# 8909   68628287                         Head Of It And Development
# 21226  69545552                            Cnet Software Developer
# 21650  64830011                       Senior C++ Software Engineer
# 21837  66199353             Business Development Manager  Software
# 22810  69473436               **** X Sous Chef – Indian Restaurant
# 29587  71226699                                  Print Field Sales
# 29645  68346575  Sql  Senior Dba / Database Administrator, Tsql...
# 29904  70677182                        Net Developer  Clientfacing
# 30003  68346805                         Net Developer / Consultant
# 30167  68806400        Javascript Developer  Globalcom New Project
# 30221  69268497                                 Sql Oltp Developer
# 30284  68347580      Graduate Field Sales / New Business Developer
# 30363  68806027  Mobile Product Manager Great Mobile Audience L...
# 30701  71685589           Lead Net Developer  C / Sql Server / Uml
# 31321  69670375  3Rd Line Server Support Linux Consultant Cambr...
# 31431  69250929  Content Assistant / Junior Web Editor  3 Month...
# 31491  68346694       Java Developers X ****  International Agency
# 31522  68346482  Erp Senior Technical Consultant  Sap / Infor *...
# 31566  70676940                      Sales Manager  Software Sales
# 31597  72689765                               Rail Account Manager
# 31792  70689145                    Sales Manager (B2B Field Based)
# 31888  69249799                  Ecommerce Project Manager  London
# 32270  68346617  Project Manager  Pensions, Flexible Benefits, ...
# 32359  71197862  Senior Project Manager / Business Analyst  Ret...
# 32414  69687427  Automated Qa Engineer Selenium Cloud Callabora...
# 32425  68805880      Agile Project Manager Global Ecommerce London
# 32615  69671232                             P / Time Sales Advisor
# 32623  68346869  3Rd Line Windows Systems Administrator Iis/ Se...
# 32808  71856406                  Clinical Data Manager  Sql Server
# 41966  68349226                           Business And Ict Teacher
# 49150  69733603                   Front Office Consultant/ Manager
#
#                 Location                                           Company  \
# 1102          Manchester                 HPR Consultancy Ltd t/a HPRtalent
# 2279            The City    Foremost Recruitment Ltd t/a Pathway Personnel
# 3035                  Uk  RIG Veterinary Ltd T/A RIG Animal Health Recruit
# 4440             Cardiff  RIG Veterinary Ltd T/A RIG Animal Health Recruit
# 5397   South East London  RIG Veterinary Ltd T/A RIG Animal Health Recruit
# 6523                  Uk                 HPR Consultancy Ltd t/a HPRtalent
# 6819           Berkshire                 HPR Consultancy Ltd t/a HPRtalent
# 7340             Newbury  RIG Veterinary Ltd T/A RIG Animal Health Recruit
# 8909               Devon   Summit Computer Recruitment Ltd t/a itecopeople
# 21226                 Uk             PPR Solutions t/a ByBox Tech Resource
# 21650            Reading             PPR Solutions t/a ByBox Tech Resource
# 21837      Milton Keynes             PPR Solutions t/a ByBox Tech Resource
# 22810                 Uk                              PSB 1 Ltd T/A Dhabba
# 29587    Tunbridge Wells           ULO Ltd T/A Capital Strategy Associates
# 29645             London                    NFP Grp Ltd T/A First Point IT
# 29904          Edinburgh                         DawsonHill Ltd T/A BIAARS
# 30003          Edinburgh                         DawsonHill Ltd T/A BIAARS
# 30167             London                    NFP Grp Ltd T/A First Point IT
# 30221             London               Mortimer Spinks Ltd T/A Harvey Nash
# 30284                 Uk                         DawsonHill Ltd T/A BIAARS
# 30363           The City               Mortimer Spinks Ltd T/A Harvey Nash
# 30701                 Uk                    Creativesrus Ltd t/a Chrysalis
# 31321          Cambridge                    NFP Grp Ltd T/A First Point IT
# 31431             London               Mortimer Spinks Ltd T/A Harvey Nash
# 31491             London                    NFP Grp Ltd T/A First Point IT
# 31522             London                    NFP Grp Ltd T/A First Point IT
# 31566                 Uk                         DawsonHill Ltd T/A BIAARS
# 31597              Leeds               Quality Rec Ltd t/a Vital Solutions
# 31792                 Uk                Febrock Ltd T/A Tedbar tinker hire
# 31888           The City                    NFP Grp Ltd T/A First Point IT
# 32270             London           ULO Ltd T/A Capital Strategy Associates
# 32359             London                    NFP Grp Ltd T/A First Point IT
# 32414             London                    NFP Grp Ltd T/A First Point IT
# 32425           The City               Mortimer Spinks Ltd T/A Harvey Nash
# 32615                 Uk           ULO Ltd T/A Capital Strategy Associates
# 32623           The City                    NFP Grp Ltd T/A First Point IT
# 32808             London                         DawsonHill Ltd T/A BIAARS
# 41966               Kent     EP Resourcing Ltd t/a Education Professionals
# 49150             London              Foremost Recruitment Ltd t/a pathway
#
#         ContractType   ContractTime                     Category Salary  \
# 1102   non-specified      permanent                   Sales Jobs  16000
# 2279   non-specified      permanent    Accounting & Finance Jobs  57500
# 3035   non-specified      permanent                   Sales Jobs  57500
# 4440   non-specified      permanent                   Sales Jobs  32000
# 5397   non-specified      permanent    Healthcare & Nursing Jobs  57500
# 6523   non-specified      permanent                   Sales Jobs  22500
# 6819   non-specified       contract                      IT Jobs  27600
# 7340   non-specified      permanent                   Sales Jobs
# 8909   non-specified      permanent                      IT Jobs
# 21226  non-specified      permanent                      IT Jobs  42500
# 21650  non-specified      permanent                      IT Jobs  37500
# 21837  non-specified      permanent                      IT Jobs  52500
# 22810  non-specified  non-specified  Hospitality & Catering Jobs  19500
# 29587  non-specified      permanent                   Sales Jobs  40000
# 29645  non-specified      permanent                      IT Jobs  50000
# 29904  non-specified      permanent                      IT Jobs  30000
# 30003  non-specified      permanent                      IT Jobs  45000
# 30167  non-specified      permanent                      IT Jobs  40000
# 30221  non-specified      permanent                      IT Jobs  40000
# 30284  non-specified      permanent                   Sales Jobs  23000
# 30363  non-specified      permanent                      IT Jobs  55000
# 30701  non-specified      permanent                      IT Jobs  41000
# 31321  non-specified      permanent                      IT Jobs  42500
# 31431  non-specified       contract                      IT Jobs  21600
# 31491  non-specified      permanent                      IT Jobs  45000
# 31522  non-specified      permanent                      IT Jobs  55000
# 31566  non-specified      permanent                   Sales Jobs  42500
# 31597  non-specified      permanent             Engineering Jobs  40000
# 31792      part_time  non-specified                   Sales Jobs  11250
# 31888  non-specified      permanent                      IT Jobs  55000
# 32270  non-specified      permanent    Accounting & Finance Jobs    NaN
# 32359  non-specified      permanent                      IT Jobs  65000
# 32414  non-specified      permanent                      IT Jobs  35000
# 32425  non-specified      permanent                      IT Jobs  62500
# 32615  non-specified      permanent                   Sales Jobs  20000
# 32623  non-specified      permanent                      IT Jobs  42500
# 32808  non-specified      permanent                      IT Jobs  43500
# 41966      full_time       contract                Teaching Jobs  33600
# 49150  non-specified      permanent    Accounting & Finance Jobs  72500
#
#                  OpenDate           CloseDate             SourceName
# 1102  2013-04-14 15:00:00 2013-05-14 15:00:00       cv-library.co.uk
# 2279  2012-05-23 15:00:00 2012-07-22 15:00:00       cv-library.co.uk
# 3035  2012-12-31 15:00:00 2013-03-31 15:00:00       cv-library.co.uk
# 4440  2012-03-27 00:00:00 2012-06-25 00:00:00       cv-library.co.uk
# 5397  2013-02-28 12:00:00 2013-05-29 12:00:00       cv-library.co.uk
# 6523  2012-06-21 00:00:00 2012-09-19 00:00:00       cv-library.co.uk
# 6819  2013-01-31 12:00:00 2013-04-01 12:00:00       cv-library.co.uk
# 7340  2013-09-22 15:00:00 2013-12-21 15:00:00       cv-library.co.uk
# 8909  2012-05-25 15:00:00 2012-08-23 15:00:00           jobserve.com
# 21226 2012-07-30 00:00:00 2012-10-28 00:00:00           cwjobs.co.uk
# 21650 2012-08-30 00:00:00 2012-10-29 00:00:00           cwjobs.co.uk
# 21837 2013-06-15 12:00:00 2013-08-14 12:00:00           cwjobs.co.uk
# 22810 2013-07-17 12:00:00 2013-07-31 12:00:00            caterer.com
# 29587 2013-02-15 12:00:00 2013-04-16 12:00:00          jobsite.co.uk
# 29645 2013-04-29 15:00:00 2013-07-28 15:00:00          jobsite.co.uk
# 29904 2012-11-26 12:00:00 2013-02-24 12:00:00          jobsite.co.uk
# 30003 2012-07-28 00:00:00 2012-08-27 00:00:00          jobsite.co.uk
# 30167 2012-08-12 12:00:00 2012-09-11 12:00:00          jobsite.co.uk
# 30221 2013-12-01 00:00:00 2014-03-01 00:00:00          jobsite.co.uk
# 30284 2012-07-27 00:00:00 2012-08-26 00:00:00          jobsite.co.uk
# 30363 2013-06-18 12:00:00 2013-08-17 12:00:00          jobsite.co.uk
# 30701 2012-11-20 00:00:00 2012-12-20 00:00:00          jobsite.co.uk
# 31321 2013-08-10 00:00:00 2013-10-09 00:00:00          jobsite.co.uk
# 31431 2012-04-21 12:00:00 2012-05-21 12:00:00          jobsite.co.uk
# 31491 2013-06-20 15:00:00 2013-08-19 15:00:00          jobsite.co.uk
# 31522 2012-12-14 12:00:00 2013-01-13 12:00:00          jobsite.co.uk
# 31566 2013-07-29 12:00:00 2013-10-27 12:00:00          jobsite.co.uk
# 31597 2012-02-13 15:00:00 2012-03-14 15:00:00          jobsite.co.uk
# 31792 2013-01-01 12:00:00 2013-01-15 12:00:00          jobsite.co.uk
# 31888 2012-08-06 12:00:00 2012-09-05 12:00:00          jobsite.co.uk
# 32270 2012-01-11 12:00:00 2012-03-11 12:00:00          jobsite.co.uk
# 32359 2012-08-14 00:00:00 2012-09-13 00:00:00          jobsite.co.uk
# 32414 2013-10-12 15:00:00 2013-11-11 15:00:00          jobsite.co.uk
# 32425 2012-12-24 00:00:00 2013-03-24 00:00:00          jobsite.co.uk
# 32615 2013-08-05 15:00:00 2013-09-04 15:00:00          jobsite.co.uk
# 32623 2012-11-15 12:00:00 2012-12-15 12:00:00          jobsite.co.uk
# 32808 2013-01-31 15:00:00 2013-04-01 15:00:00          jobsite.co.uk
# 41966 2012-04-23 12:00:00 2012-06-22 12:00:00  jobsineducation.co.uk
# 49150 2012-07-15 12:00:00 2012-09-13 12:00:00       londonjobs.co.uk

# %% [markdown]
# Let's try the company name "NFP Grp Limited T/A First Point IT"

# %%
it_company = df['Company'].str.contains(r'First Point IT',na=False)
df[it_company][:15]
# Out:
#              Id                                              Title  \
# 8431   68628064  Senior Developer  Ruby, Rails  Top Track **** ...
# 8531   68628114  Sql Datawarehouse Developer  Sql ****/**** Gai...
# 9387   68628127  Senior Business Intelligence (Bi)/Dwh Dataware...
# 11843  68712327       Ppc Manager, Uk No**** Phenom, London, ****K
# 11946  68098589                        Training Manager/Consultant
# 12174  71184872     Web Analyst, Europe No**** Ecom, London, ****K
# 15675  68712409  R****  Oracle Financial Consultant  London, **...
# 15958  68715405  Technical Lead Caspnet Mvc Scrum Tdd Hospitali...
# 16584  71184863  Database Architect  Sql Server  London  ********K
# 18422  68715391  C Winforms Developer Dev Express  Fx/Trading G...
# 18748  69590193  Paid Search (Ppc) Executive, Amazing Agency, L...
# 18861  68098395  Proven Sales Executives Required By Leading It...
# 29645  68346575  Sql  Senior Dba / Database Administrator, Tsql...
# 30167  68806400        Javascript Developer  Globalcom New Project
# 31321  69670375  3Rd Line Server Support Linux Consultant Cambr...
#
#                 Location                         Company   ContractType  \
# 8431              London                  First Point IT  non-specified
# 8531              London                  First Point IT  non-specified
# 9387              London                  First Point IT  non-specified
# 11843  South East London                  First Point IT  non-specified
# 11946  South East London                  First Point IT  non-specified
# 12174  South East London                  First Point IT  non-specified
# 15675  South East London                  First Point IT  non-specified
# 15958  South East London                  First Point IT  non-specified
# 16584  South East London                  First Point IT  non-specified
# 18422  South East London                  First Point IT  non-specified
# 18748  South East London                  First Point IT  non-specified
# 18861            Reading                  First Point IT  non-specified
# 29645             London  NFP Grp Ltd T/A First Point IT  non-specified
# 30167             London  NFP Grp Ltd T/A First Point IT  non-specified
# 31321          Cambridge  NFP Grp Ltd T/A First Point IT  non-specified
#
#       ContractTime                          Category          Salary  \
# 8431     permanent                           IT Jobs           62500
# 8531     permanent                           IT Jobs           40000
# 9387     permanent                           IT Jobs           50000
# 11843    permanent  PR, Advertising & Marketing Jobs  36500 To 38500
# 11946    permanent                           IT Jobs           57500
# 12174    permanent                           IT Jobs           45000
# 15675     contract                           IT Jobs           50000
# 15958    permanent                           IT Jobs           60000
# 16584    permanent                           IT Jobs           67500
# 18422    permanent                           IT Jobs           46000
# 18748    permanent  PR, Advertising & Marketing Jobs           24000
# 18861    permanent                        Sales Jobs           55000
# 29645    permanent                           IT Jobs           50000
# 30167    permanent                           IT Jobs           40000
# 31321    permanent                           IT Jobs           42500
#
#                  OpenDate           CloseDate     SourceName
# 8431  2013-03-28 00:00:00 2013-06-26 00:00:00   jobserve.com
# 8531  2012-07-01 00:00:00 2012-09-29 00:00:00   jobserve.com
# 9387  2013-11-04 00:00:00 2013-12-04 00:00:00   jobserve.com
# 11843 2013-02-17 00:00:00 2013-04-18 00:00:00  totaljobs.com
# 11946 2012-02-06 00:00:00 2012-05-06 00:00:00  totaljobs.com
# 12174 2012-01-12 12:00:00 2012-04-11 12:00:00  totaljobs.com
# 15675 2012-10-23 00:00:00 2012-11-06 00:00:00  totaljobs.com
# 15958 2012-08-24 00:00:00 2012-10-23 00:00:00  totaljobs.com
# 16584 2013-10-02 00:00:00 2013-12-01 00:00:00  totaljobs.com
# 18422 2013-05-11 15:00:00 2013-07-10 15:00:00  totaljobs.com
# 18748 2013-05-10 15:00:00 2013-07-09 15:00:00  totaljobs.com
# 18861 2013-09-17 15:00:00 2013-11-16 15:00:00  totaljobs.com
# 29645 2013-04-29 15:00:00 2013-07-28 15:00:00  jobsite.co.uk
# 30167 2012-08-12 12:00:00 2012-09-11 12:00:00  jobsite.co.uk
# 31321 2013-08-10 00:00:00 2013-10-09 00:00:00  jobsite.co.uk

# %% [markdown]
# It can be seen that some does not have the 't/a's! In this case, phrases before the term 't/a' would be removed

# %%
# Remove phrases before the term t/a
def remove_ta(company):
    ltds = re.match(r'.*\s[tT][\\/][aA]\s(.*)',company).groups()
    # If there are any errors
    if len(ltds)>1:
        print(company,ltds)
        return company
    else:
        for ltd in ltds:
#             print('Before Altering: ',company)
            company = ltd
#             print('After Altering: ',company)
        return company

# %%
# Get data with companies containing the term t/a
ta_company = df['Company'].str.contains(r'\s[tT][\\/][aA]\s',na=False)
indices = df[ta_company].index
for ind in indices:
    company = df['Company'][ind]
    new_company = remove_ta(company)
    # Record to errorDict
    errorDict = addToErrorDict(errorDict,ind,df['Id'][ind],'Company',company,new_company,'Contains extra information t/a','Remove extra information')
    # Remove phrases before t/a
    df.loc[ind,'Company'] = new_company
    
df[ta_company].head()
# Out:
#             Id                                         Title  \
# 1102  66600547         Internal Sales Executive Ppe/Workwear
# 2279  69537392                            Financial Engineer
# 3035  70410175  Export Development Manager  Equine Nutrition
# 4440  66600480   Business Development Manager  Pet Nutrition
# 5397  70764450  Regulatory Affairs Manager  Animal Nutrition
#
#                Location                    Company   ContractType  \
# 1102         Manchester                  HPRtalent  non-specified
# 2279           The City          Pathway Personnel  non-specified
# 3035                 Uk  RIG Animal Health Recruit  non-specified
# 4440            Cardiff  RIG Animal Health Recruit  non-specified
# 5397  South East London  RIG Animal Health Recruit  non-specified
#
#      ContractTime                   Category Salary            OpenDate  \
# 1102    permanent                 Sales Jobs  16000 2013-04-14 15:00:00
# 2279    permanent  Accounting & Finance Jobs  57500 2012-05-23 15:00:00
# 3035    permanent                 Sales Jobs  57500 2012-12-31 15:00:00
# 4440    permanent                 Sales Jobs  32000 2012-03-27 00:00:00
# 5397    permanent  Healthcare & Nursing Jobs  57500 2013-02-28 12:00:00
#
#                CloseDate        SourceName
# 1102 2013-05-14 15:00:00  cv-library.co.uk
# 2279 2012-07-22 15:00:00  cv-library.co.uk
# 3035 2013-03-31 15:00:00  cv-library.co.uk
# 4440 2012-06-25 00:00:00  cv-library.co.uk
# 5397 2013-05-29 12:00:00  cv-library.co.uk

# %% [markdown]
# We continue check for other possible errors

# %%
valid_company = df['Company'].str.fullmatch(r'([a-zA-Z0-9]\s?)+',na=False)
df[~valid_company & ~non_specified]['Company']
# Out:
# 794       Mobile Technical Staff   Technical Engineering
# 877      Hays Specialist Recruitment   Further Education
# 892          Randstad Construction, Property Engineering
# 1152                      Cooper Lomaz   Bury St Edmunds
# 1259      Mobile Technical Staff   Technical Engineering
#                               ...
# 50658                              Net Recruit.co.uk Ltd
# 50684                     Atkins Ltd   Water Environment
# 50730                           Agora Search & Selection
# 50747              UNKNOWN   auto added by vacany import
# 50749              UNKNOWN   auto added by vacany import
# Name: Company, Length: 2173, dtype: object

# %% [markdown]
# Back to the multispace problem. It seems like sentences after the whitespace or commas contains some extra information

# %%
# Get companies with multiple spaces together
multispace_company = df['Company'].str.contains(r'(?:\s\s+|,\s*)',na=False)
df[multispace_company]['Company']
# Out:
# 794       Mobile Technical Staff   Technical Engineering
# 877      Hays Specialist Recruitment   Further Education
# 892          Randstad Construction, Property Engineering
# 1152                      Cooper Lomaz   Bury St Edmunds
# 1259      Mobile Technical Staff   Technical Engineering
#                               ...
# 49812      Sad Business School Ltd, University of Oxford
# 50359           Seashell Trust   Royal School Manchester
# 50684                     Atkins Ltd   Water Environment
# 50747              UNKNOWN   auto added by vacany import
# 50749              UNKNOWN   auto added by vacany import
# Name: Company, Length: 1073, dtype: object

# %% [markdown]
# From above, it does seem like they are all extra information. Thus, values after those would be removed

# %%
# Remove extra information after whitespace
def remove_aft_whitespace(company):
    ltds = re.match(r'(.*)(?:\s\s+|\,\s*).*',company).groups()
    if len(ltds)>1:
        print(company,ltds)
        return company
    else:
        for ltd in ltds:
#             print('Before Altering: ',company)
            company = ltd
#             print('After Altering: ',company)
        return company

# %%
# Get companies with extra white spaces
multispace = df['Company'].str.contains(r'(?:\s\s+|,\s*)',na=False)
indices = df[multispace].index
for ind in indices:
    company = df['Company'][ind]
    new_company = remove_aft_whitespace(company)
    # Record to errorDict
    errorDict = addToErrorDict(errorDict,ind,df['Id'][ind],'Company',company,new_company,'Contains extra information','Remove extra information')
    # Remove phrases after the multiple whitespaces
    df.loc[ind,'Company'] = new_company
    
df[multispace].head()
# Out:
#             Id                                              Title  \
# 794   69083414                        Multiskilled Shift Engineer
# 877   72540018                  Nursery Nurse  Baby Room  Bristol
# 892   71125509  Hvac Maintenance Engineer Central London ****K...
# 1152  68357073                                   Helpdesk Analyst
# 1259  69560338                      Leading Hand (Section Leader)
#
#                Location                       Company   ContractType  \
# 794   South East London       Mobile Technical Staff   non-specified
# 877             Bristol  Hays Specialist Recruitment   non-specified
# 892            The City         Randstad Construction  non-specified
# 1152            Norwich                 Cooper Lomaz   non-specified
# 1259                 Uk       Mobile Technical Staff   non-specified
#
#      ContractTime          Category Salary            OpenDate  \
# 794     permanent  Engineering Jobs  27500 2013-08-27 12:00:00
# 877     permanent     Teaching Jobs  16000 2013-03-10 15:00:00
# 892     permanent  Engineering Jobs  29000 2012-03-18 15:00:00
# 1152    permanent           IT Jobs  17000 2013-07-21 12:00:00
# 1259    permanent  Engineering Jobs  29760 2013-05-22 00:00:00
#
#                CloseDate        SourceName
# 794  2013-11-25 12:00:00  cv-library.co.uk
# 877  2013-06-08 15:00:00  cv-library.co.uk
# 892  2012-05-17 15:00:00  cv-library.co.uk
# 1152 2013-09-19 12:00:00  cv-library.co.uk
# 1259 2013-06-21 00:00:00  cv-library.co.uk

# %% [markdown]
# Now that there are all removed, let's hope that the errors are minimized

# %%
valid_company = df['Company'].str.fullmatch(r'([a-zA-Z0-9]\s?)+',na=False)
df[~valid_company & ~non_specified]['Company']
# Out:
# 1384                     in pact.co.uk
# 1567         RecruitmentRevolution.com
# 2056         Recruitmentconsultant.com
# 2178         RecruitmentRevolution.com
# 2572         RecruitmentRevolution.com
#                      ...
# 50548           EasyWebRecruitment.com
# 50592    Financialadviser careers .Com
# 50608    Financialadviser careers .Com
# 50658            Net Recruit.co.uk Ltd
# 50730         Agora Search & Selection
# Name: Company, Length: 1270, dtype: object

# %% [markdown]
# Those companies with .com seems to be valid. Let's check if there are same company names without the .com

# %%
# Get companies with the name recruitment revolution
names = ['RecruitmentRevolution','Recruitmentconsultant','Recruitment Revolution','Recruitment consultant','Recruitment Consultant','RecruitmentConsultant']
xcom_company = df['Company'].isin(names)
df[xcom_company]
# Out:
#              Id                                              Title  \
# 35555  68609180  Systems Administrator / 1St/2Nd Line Technical...
# 35697  62004478  Business Development Executive  Leading Web/Mo...
# 35713  62004672  Online Sales Executive  Uk'S Fastest Growing J...
# 35731  62004687  Lamp / Php Developer  Work With Clients Like C...
# 35846  68609136  Tax Compliance Accountant  Leading Financial P...
# 35851  62004822  Hosting Technical Support Manager  Top 5 Globa...
# 35864  62003694  Product Sales Executive  Rapid Growing 1 Milli...
# 35867  62003562  Lead Generation / Telesales Executive  Top 5 G...
# 35895  62004106  Digital Graphic Designer  Leading Investment H...
# 35947  62004644  Field Charity Fundraiser  Leading Animal Welfa...
# 35981  66698318  Finance Manager / Accountant  Global Web Hosti...
# 35987  68609186  It Project Manager  Leading Uk Datacentre / Ho...
# 36028  62004493  Customer Service Representative  No**** Satell...
# 36060  67080504  Datacentre Support Engineer – Leading Uk Data ...
# 36105  62270260  Website Technical Support Agent  Html/Css, Jav...
# 36106  62003833       Operations Manager  Business Events Projects
# 36121  62767473  B2B Lead Generator / Telemarketer  Hosted It/D...
# 36143  71745058  Field Sales Executive  Retail Epos Systems  Na...
# 36177  66693867  Project Manager (Managed Hosting / Datacentre)...
# 36193  70754637  B2B Lead Generator / Account Manager For Marke...
# 36286  70755617   Senior Digital Designer  Digital Creative Agency
# 36292  62003952  Front End Web Developer  Top Southwest Digital...
# 36351  62003200  Field Business Development Sales Executive  Br...
# 36405  65297914  Website Content And Marketing Coordinator (Non...
# 36413  68609200  Field Sales Executive  Hosted It/Data Services...
# 36434  62004703  Field Door To Door Charity Fundraiser  Leading...
# 36494  66314433  Field Campaign Manager / Membership Officer  L...
#
#                 Location                 Company   ContractType  \
# 35555            Reading  Recruitment Revolution  non-specified
# 35697             Woking  Recruitment Revolution  non-specified
# 35713              Fleet  Recruitment Revolution  non-specified
# 35731        West London  Recruitment Revolution  non-specified
# 35846           Bradford  Recruitment Revolution  non-specified
# 35851        Southampton  Recruitment Revolution  non-specified
# 35864  South East London  Recruitment Revolution  non-specified
# 35867        Southampton  Recruitment Revolution  non-specified
# 35895             London  Recruitment Revolution  non-specified
# 35947         Darlington  Recruitment Revolution  non-specified
# 35981        Southampton  Recruitment Revolution  non-specified
# 35987            Reading  Recruitment Revolution  non-specified
# 36028  North West London  Recruitment Revolution  non-specified
# 36060            Croydon  Recruitment Revolution  non-specified
# 36105            Newbury  Recruitment Revolution  non-specified
# 36106  North West London  Recruitment Revolution  non-specified
# 36121          Knutsford  Recruitment Revolution  non-specified
# 36143      Hertfordshire  Recruitment Revolution  non-specified
# 36177        Southampton  Recruitment Revolution  non-specified
# 36193         Manchester  Recruitment Revolution  non-specified
# 36286             London  Recruitment Revolution  non-specified
# 36292        Southampton  Recruitment Revolution  non-specified
# 36351        West London  Recruitment Revolution  non-specified
# 36405            Crawley  Recruitment Revolution  non-specified
# 36413          Knutsford  Recruitment Revolution  non-specified
# 36434    South Yorkshire  Recruitment Revolution  non-specified
# 36494        Northampton  Recruitment Revolution  non-specified
#
#         ContractTime                          Category Salary  \
# 35555  non-specified                           IT Jobs  25000
# 35697  non-specified  PR, Advertising & Marketing Jobs  30000
# 35713  non-specified  PR, Advertising & Marketing Jobs  16500
# 35731  non-specified                           IT Jobs  30000
# 35846  non-specified         Accounting & Finance Jobs  33500
# 35851  non-specified                           IT Jobs  42500
# 35864  non-specified         Accounting & Finance Jobs  24000
# 35867  non-specified                           IT Jobs  20000
# 35895  non-specified                  Engineering Jobs  31000
# 35947  non-specified                        Sales Jobs  30000
# 35981  non-specified         Accounting & Finance Jobs  32500
# 35987  non-specified                           IT Jobs  40000
# 36028  non-specified         Accounting & Finance Jobs
# 36060  non-specified                           IT Jobs  18500
# 36105  non-specified                           IT Jobs  25000
# 36106  non-specified  PR, Advertising & Marketing Jobs  40000
# 36121  non-specified                           IT Jobs  20000
# 36143  non-specified                           IT Jobs  42000
# 36177  non-specified                           IT Jobs  50000
# 36193  non-specified                        Sales Jobs  20500
# 36286  non-specified                           IT Jobs  35000
# 36292  non-specified                           IT Jobs  30000
# 36351  non-specified                        Sales Jobs  22000
# 36405  non-specified                           IT Jobs  16250
# 36413  non-specified                           IT Jobs  35000
# 36434  non-specified                        Sales Jobs  26000
# 36494  non-specified  PR, Advertising & Marketing Jobs  27919
#
#                  OpenDate           CloseDate SourceName
# 35555 2012-08-06 15:00:00 2012-10-05 15:00:00   MyUkJobs
# 35697 2012-05-29 00:00:00 2012-07-28 00:00:00   MyUkJobs
# 35713 2012-09-24 00:00:00 2012-10-08 00:00:00   MyUkJobs
# 35731 2013-07-04 12:00:00 2013-09-02 12:00:00   MyUkJobs
# 35846 2012-03-09 00:00:00 2012-03-23 00:00:00   MyUkJobs
# 35851 2012-07-22 12:00:00 2012-08-21 12:00:00   MyUkJobs
# 35864 2012-07-15 00:00:00 2012-07-29 00:00:00   MyUkJobs
# 35867 2012-01-31 00:00:00 2012-03-31 00:00:00   MyUkJobs
# 35895 2012-06-18 15:00:00 2012-08-17 15:00:00   MyUkJobs
# 35947 2013-05-03 00:00:00 2013-07-02 00:00:00   MyUkJobs
# 35981 2012-03-15 00:00:00 2012-05-14 00:00:00   MyUkJobs
# 35987 2012-07-25 12:00:00 2012-09-23 12:00:00   MyUkJobs
# 36028 2013-12-24 00:00:00 2014-02-22 00:00:00   MyUkJobs
# 36060 2012-06-20 00:00:00 2012-08-19 00:00:00   MyUkJobs
# 36105 2013-06-01 12:00:00 2013-06-15 12:00:00   MyUkJobs
# 36106 2013-07-06 00:00:00 2013-08-05 00:00:00   MyUkJobs
# 36121 2013-04-23 15:00:00 2013-05-07 15:00:00   MyUkJobs
# 36143 2013-04-23 15:00:00 2013-05-23 15:00:00   MyUkJobs
# 36177 2012-01-11 12:00:00 2012-01-25 12:00:00   MyUkJobs
# 36193 2012-05-13 12:00:00 2012-07-12 12:00:00   MyUkJobs
# 36286 2012-08-24 12:00:00 2012-09-23 12:00:00   MyUkJobs
# 36292 2012-04-27 15:00:00 2012-06-26 15:00:00   MyUkJobs
# 36351 2012-04-09 12:00:00 2012-05-09 12:00:00   MyUkJobs
# 36405 2013-10-03 15:00:00 2013-12-02 15:00:00   MyUkJobs
# 36413 2012-10-01 12:00:00 2012-10-15 12:00:00   MyUkJobs
# 36434 2012-04-15 12:00:00 2012-05-15 12:00:00   MyUkJobs
# 36494 2012-05-09 00:00:00 2012-07-08 00:00:00   MyUkJobs

# %% [markdown]
# Well, it seems that some of them are.. Thus, those '.com's with company names without would be removed

# %%
# Function to remove .com and .nets
def remove_com(company):
    # Get the word .com OR .net
    domain = re.match(r'.*\s*(\.[cC][oO][mM]|\.[nN][eE][tT]).*',company).groups()
    for names in domain:
        if names != None:
            # Replace the values with ''
            name = company.replace(names,'')
            # Split the word into multiple words by capital letters
            namelist = re.findall('[A-Z][^A-Z]*\s?', name)
            
            # Join them with space to form a new string
            namelist = [x.strip() for x in namelist]
            company_name = " ".join(namelist)
            
            # If no words with capital letters
            if len(namelist) == 0:
                # Use name as the company name
                company_name = name
            
            # Find closest match of the newly split company
            closest_matches = find_closest_match(company_name,df['Company'].unique(),0.85)
            # If the company name exists
            if company_name in df['Company'].unique():
                return company_name
            # If a close match is found
            elif len(closest_matches) != 0 and closest_matches[0] != company:
                print("Found close match for ",company_name," as ",find_closest_match(company_name,closest_matches,0.85))
                return company_name
            else:
                body = name.strip()
                return body

# %%
# Get companies with .com and .net present
com_company = df['Company'].str.contains(r'(\.[cC][oO][mM]|\.[nN][eE][tT])',na=False)
indices = list(df[com_company].index)
for ind in indices:
    company = df['Company'][ind]
    # Get the newly formatted values
    new_company = remove_com(company)
    # Record to errorDict
    errorDict = addToErrorDict(errorDict,ind,df['Id'][ind],'Company',company,new_company,'Name varient','Set to existing names')
    # Replace values with correctly formatted ones
    df.loc[ind,'Company'] = new_company
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2328\1132304127.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   com_company = df['Company'].str.contains(r'(\.[cC][oO][mM]|\.[nN][eE][tT])',na=False)
# Found close match for  Easy Web Recruitment  as  ['Easy Web Recruitment ']
# Found close match for  Recruitment Revolution Ltd  as  ['Recruitment Revolution.Com Ltd']
# Found close match for  Recruitment Consultant  as  ['Recruitmentconsultant']
# Found close match for  Gemploy Ltd  as  ['Remploy Ltd']
# Found close match for  Hunt4 Staff  as  ['Hunt 4 Staff']
# Found close match for  Recruitment Consulatant  as  ['Recruitment Consultant']
# Found close match for  Rental Cars  as  ['Rentalcars']

# %%
df[com_company].head()
# Out:
#             Id                                              Title  \
# 1567  68181706  Software Developer / Software Engineer (Net)  ...
# 2056  69004660                           Contracts Sales Engineer
# 2178  69001494  New Business Sales Executive  Sms Text Messagi...
# 2572  69017271  Net Developer  Aspnet, Sql  Media Solutions Pr...
# 2795  69022557  Front End Developer  Exciting Tech Startup Bac...
#
#            Location                 Company   ContractType ContractTime  \
# 1567        Warwick  Recruitment Revolution  non-specified    permanent
# 2056    Northampton   Recruitmentconsultant  non-specified    permanent
# 2178       Worthing  Recruitment Revolution  non-specified    permanent
# 2572      Sheffield  Recruitment Revolution  non-specified    permanent
# 2795  Covent Garden  Recruitment Revolution  non-specified    permanent
#
#         Category Salary            OpenDate           CloseDate  \
# 1567     IT Jobs  35000 2012-09-08 15:00:00 2012-11-07 15:00:00
# 2056  Sales Jobs  27500 2013-09-16 00:00:00 2013-12-15 00:00:00
# 2178  Sales Jobs  30000 2013-05-14 00:00:00 2013-06-13 00:00:00
# 2572     IT Jobs        2012-09-28 00:00:00 2012-12-27 00:00:00
# 2795     IT Jobs  35000 2012-04-24 15:00:00 2012-07-23 15:00:00
#
#             SourceName
# 1567  cv-library.co.uk
# 2056  cv-library.co.uk
# 2178  cv-library.co.uk
# 2572  cv-library.co.uk
# 2795  cv-library.co.uk

# %% [markdown]
# Now that those values ending with '.com' is being taken care of, we move on to the next values

# %%
valid_company = df['Company'].str.fullmatch(r'([a-zA-Z0-9]\s?)+')
df[~valid_company & ~non_specified]['Company']
# Out:
# 1384                                 in pact.co.uk
# 2937                                 in pact.co.uk
# 3126                                 in pact.co.uk
# 3174                                 in pact.co.uk
# 3279                                 in pact.co.uk
#                            ...
# 50199    Guy's and St Thomas' NHS Foundation Trust
# 50229                                          B&Q
# 50460                   Sotheby's Institute of Art
# 50658                        Net Recruit.co.uk Ltd
# 50730                     Agora Search & Selection
# Name: Company, Length: 1099, dtype: object

# %% [markdown]
# It seems like there are a lot of companies with '.co.uk'

# %%
# Get company with .co.uk
co_uk = df['Company'].str.contains(r'[\.\s][cC][oO][\.\s][uU][kK]')
df[co_uk]
# Out:
#              Id                                              Title  \
# 1384   71554842                          Head Of Resource Planning
# 2937   68994859                     Team Manager  Pension Payments
# 3126   68994403   Team Leader  Award Winning Financial Services Co
# 3174   68994880                           Sales Quality Consultant
# 3279   71554835                Occupational Pensions Administrator
# 3607   71554834        Experienced / Senior Pensions Administrator
# 4186   68994873                          Dc Pensions Administrator
# 4270   68994862          Pensions Team Leader, Leading Consultancy
# 4628   68994870  Experienced Pensions Administrator  Leading Co...
# 4943   71295494               Networking Engineer/ Cabling Manager
# 5531   68994875               Group Risk Benefits / Claims Manager
# 5925   70758215            Projects And Communications Coordinator
# 5990   70757707                        Insurance Report Technician
# 7431   72115218  Debt Advisor/Customer Services Advisor/Client ...
# 8693   71594086  Junior Programmer, Excel, Vba, Sql, Net Traini...
# 12228  69595682                  Senior Lettings Negotiator/Lister
# 12387  68682262               Selfemployed Role  Sales And Trading
# 14297  68683960                          Insurance Account Handler
# 16529  69805440                            Cisco Technical Analyst
# 17792  68677585                                 Team Leader  Iapps
# 20101  66609779                                  Joint Head Of Ict
# 30404  68347173                      Laser Cutting Sales Estimator
# 31195  71686015  Junior Programmer, Vbnet, Sql, Break Into Bank...
# 32406  72481378               1St Line Support Analyst Team Leader
# 33881  67393938  Research, Development And Manufacturing Gradua...
# 33886  71089877                             Sales Executive  Media
# 33989  71885351  Agency Account Manager For The Uk'S No **** Jo...
# 34047  71885317  Business Development Manager  North For The Uk...
# 34521  71885316  Business Development Manager  South For The Uk...
# 35177  66127036                                    Systems Analyst
# 36792  68552625                 Graduate Telesales Executivelondon
# 36842  67754879            Key Account Manager  Automotive Finance
# 37009  66936459                             Account Manager  South
# 39545  67776279                          Workshop Service Engineer
# 39773  69769276                                     Sen Key Worker
# 39866  68239749                Nursery Practitioner L****  Ooc****
# 39974  69554894                           After School Club Worker
# 40127  69769301                             Preschool Practitioner
# 40872  68446046                    Baby Room Practitioner  Col****
# 44208  66766219                                    Sales Collector
# 44248  71737506                              Telesales Coordinator
# 46892  72478038                         Lecturer  Sciences (Fames)
# 46911  68814649        Sales Executive / Sales Advisor / B2B Sales
# 47029  71214068  Client Relationship Manager / Business Associa...
# 47040  72287800       German Or Spanish Speaking Technical Support
# 47073  68814664          Field Sales / B2B Sales / Account Manager
# 47079  72478136               Assessor / Verifier / Iv Early Years
# 47081  71215171          Quality Assurance Assessor  Dental Health
# 47086  71216010                             Awards Project Officer
# 47136  71215979  French, German Or Spanish Speaking European Ac...
# 47160  71700689  Foster Carer : (Admin, Customer Service Any Se...
# 50658  69535123              Collection Advisor, Credit Management
#
#                   Location                      Company   ContractType  \
# 1384           East Sussex                in pact.co.uk  non-specified
# 2937                Surrey                in pact.co.uk  non-specified
# 3126                 Epsom                in pact.co.uk  non-specified
# 3174                    Uk                in pact.co.uk  non-specified
# 3279            Birmingham                in pact.co.uk  non-specified
# 3607             Berkshire                in pact.co.uk  non-specified
# 4186             Berkshire                in pact.co.uk  non-specified
# 4270                Surrey                in pact.co.uk  non-specified
# 4628                    Uk                in pact.co.uk  non-specified
# 4943                Slough            Easyvacancy.co.uk  non-specified
# 5531                Surrey                in pact.co.uk  non-specified
# 5925                Surrey                in pact.co.uk  non-specified
# 5990               Redhill                in pact.co.uk  non-specified
# 7431               Cheadle          Claimfree.co.uk Ltd  non-specified
# 8693                London     NDK Consulting.co.uk Ltd  non-specified
# 12228                   Uk                Hatched.co.uk  non-specified
# 12387            Gravesend                   Be A.co.uk      part_time
# 14297            Worcester            easyvacancy.co.uk  non-specified
# 16529                   Uk            easyvacancy.co.uk  non-specified
# 17792                   Uk            easyvacancy.co.uk  non-specified
# 20101                   Uk                Advanse.co.uk  non-specified
# 30404                   Uk        Net Recruit.co.uk Ltd  non-specified
# 31195               London     NDK Consulting.Co UK Ltd  non-specified
# 32406           Manchester            EasyVacancy.co.uk  non-specified
# 33881                   Uk             TARGETJOBS.CO.UK      full_time
# 33886       Central London                   REED.CO.UK      full_time
# 33989               London                   REED.CO.UK      full_time
# 34047  Newcastle Upon Tyne                   REED.CO.UK      full_time
# 34521               London                   REED.CO.UK      full_time
# 35177             Cheshire        Net Recruit.co.uk Ltd      full_time
# 36792    South West London            Motorecruit.co.uk      full_time
# 36842                   Uk            Motorecruit.co.uk      full_time
# 37009    South East London            Easyvacancy.co.uk  non-specified
# 39545            Normanton  greenlightrecruitment.co.uk      full_time
# 39773           Colchester       www.essex eyjobs.co.uk      part_time
# 39866                  Sea       www.essex eyjobs.co.uk      full_time
# 39974           Chelmsford       www.essex eyjobs.co.uk      part_time
# 40127           Colchester       www.essex eyjobs.co.uk      part_time
# 40872           Colchester       www.essex eyjobs.co.uk      full_time
# 44208                   Uk           THESMARTLIST.co.uk  non-specified
# 44248                   Uk           THESMARTLIST.co.uk  non-specified
# 46892             Coventry         BlueTownOnline.co.uk      full_time
# 46911           Gloucester         BlueTownOnline.co.uk      full_time
# 47029               London         BlueTownOnline.co.uk      full_time
# 47040           Birmingham         BlueTownOnline.co.uk      full_time
# 47073               London         BlueTownOnline.co.uk      full_time
# 47079             Coventry         BlueTownOnline.co.uk      full_time
# 47081               London         BlueTownOnline.co.uk      full_time
# 47086              Bedford         BlueTownOnline.co.uk      full_time
# 47136           Manchester         BlueTownOnline.co.uk      full_time
# 47160              Glasgow         BlueTownOnline.co.uk      full_time
# 50658      Gloucestershire        Net Recruit.co.uk Ltd      full_time
#
#         ContractTime                   Category   Salary            OpenDate  \
# 1384       permanent  Accounting & Finance Jobs    60000 2012-08-30 12:00:00
# 2937       permanent  Accounting & Finance Jobs    28000 2012-11-05 15:00:00
# 3126       permanent  Accounting & Finance Jobs    26500 2012-07-21 00:00:00
# 3174       permanent  Accounting & Finance Jobs    25000 2013-03-14 15:00:00
# 3279       permanent  Accounting & Finance Jobs    20500 2012-11-01 15:00:00
# 3607       permanent  Accounting & Finance Jobs    27000 2013-01-04 00:00:00
# 4186       permanent  Accounting & Finance Jobs    23000 2013-07-22 15:00:00
# 4270       permanent  Accounting & Finance Jobs    29000 2012-05-09 15:00:00
# 4628       permanent  Accounting & Finance Jobs    25500 2012-06-20 12:00:00
# 4943       permanent           Engineering Jobs    25000 2013-01-19 00:00:00
# 5531       permanent  Accounting & Finance Jobs    42500 2013-10-03 12:00:00
# 5925       permanent  Accounting & Finance Jobs    30000 2012-07-29 12:00:00
# 5990       permanent  Accounting & Finance Jobs    25000 2012-05-06 00:00:00
# 7431       permanent  Accounting & Finance Jobs    16500 2012-07-04 15:00:00
# 8693       permanent                    IT Jobs    30000 2012-09-22 00:00:00
# 12228      permanent                 Sales Jobs    28000 2012-09-18 15:00:00
# 12387  non-specified  Accounting & Finance Jobs    35000 2013-08-10 12:00:00
# 14297      permanent  Accounting & Finance Jobs    20500 2013-08-16 12:00:00
# 16529      permanent                    IT Jobs    26500 2013-07-30 12:00:00
# 17792      permanent                    IT Jobs    28500 2013-08-27 12:00:00
# 20101      permanent                    IT Jobs    86000 2012-09-10 12:00:00
# 30404      permanent                 Sales Jobs    30000 2012-03-26 12:00:00
# 31195      permanent                    IT Jobs    30000 2012-06-07 00:00:00
# 32406      permanent                    IT Jobs    20000 2013-11-23 15:00:00
# 33881      permanent              Teaching Jobs    39000 2012-07-01 00:00:00
# 33886      permanent                 Sales Jobs    22500 2012-04-04 00:00:00
# 33989      permanent              Teaching Jobs    35000 2012-09-03 00:00:00
# 34047      permanent              Teaching Jobs    32000 2013-09-14 00:00:00
# 34521      permanent              Teaching Jobs    35500 2012-08-19 00:00:00
# 35177      permanent                    IT Jobs    30000 2012-06-20 12:00:00
# 36792      permanent                 Sales Jobs    18000 2012-03-31 15:00:00
# 36842      permanent  Accounting & Finance Jobs    33000 2013-01-26 12:00:00
# 37009  non-specified                 Sales Jobs    50000 2012-03-06 15:00:00
# 39545  non-specified           Engineering Jobs    20000 2012-08-23 15:00:00
# 39773  non-specified              Teaching Jobs    14016 2012-10-08 15:00:00
# 39866  non-specified              Teaching Jobs    12480 2012-12-02 12:00:00
# 39974  non-specified              Teaching Jobs    12480 2012-07-06 00:00:00
# 40127  non-specified              Teaching Jobs    14400 2013-08-28 00:00:00
# 40872  non-specified              Teaching Jobs    13440 2012-05-03 00:00:00
# 44208      permanent                 Sales Jobs    15600 2013-07-03 00:00:00
# 44248      permanent                 Sales Jobs    16500 2012-07-30 12:00:00
# 46892  non-specified              Teaching Jobs  26112.0 2013-12-31 00:00:00
# 46911  non-specified                 Sales Jobs  16500.0 2012-07-07 15:00:00
# 47029  non-specified                 Sales Jobs  40000.0 2013-02-04 00:00:00
# 47040  non-specified                    IT Jobs  16000.0 2013-02-23 00:00:00
# 47073  non-specified                 Sales Jobs  33000.0 2012-08-28 12:00:00
# 47079  non-specified              Teaching Jobs  11947.0 2012-06-28 00:00:00
# 47081  non-specified  Healthcare & Nursing Jobs  30313.0 2013-11-10 15:00:00
# 47086  non-specified                 Sales Jobs  30000.0 2012-03-07 00:00:00
# 47136  non-specified                 Sales Jobs      NaN 2012-06-28 00:00:00
# 47160  non-specified  Healthcare & Nursing Jobs  29000.0 2013-10-23 15:00:00
# 50658      permanent  Accounting & Finance Jobs    15500 2012-07-10 12:00:00
#
#                 CloseDate           SourceName
# 1384  2012-10-29 12:00:00     cv-library.co.uk
# 2937  2013-01-04 15:00:00     cv-library.co.uk
# 3126  2012-10-19 00:00:00     cv-library.co.uk
# 3174  2013-04-13 15:00:00     cv-library.co.uk
# 3279  2012-12-01 15:00:00     cv-library.co.uk
# 3607  2013-04-04 00:00:00     cv-library.co.uk
# 4186  2013-10-20 15:00:00     cv-library.co.uk
# 4270  2012-08-07 15:00:00     cv-library.co.uk
# 4628  2012-08-19 12:00:00     cv-library.co.uk
# 4943  2013-02-18 00:00:00     cv-library.co.uk
# 5531  2014-01-01 12:00:00     cv-library.co.uk
# 5925  2012-10-27 12:00:00     cv-library.co.uk
# 5990  2012-06-05 00:00:00     cv-library.co.uk
# 7431  2012-09-02 15:00:00     cv-library.co.uk
# 8693  2012-11-21 00:00:00         jobserve.com
# 12228 2012-12-17 15:00:00        totaljobs.com
# 12387 2013-09-09 12:00:00        totaljobs.com
# 14297 2013-11-14 12:00:00        totaljobs.com
# 16529 2013-09-28 12:00:00        totaljobs.com
# 17792 2013-11-25 12:00:00        totaljobs.com
# 20101 2012-12-09 12:00:00         cwjobs.co.uk
# 30404 2012-05-25 12:00:00        jobsite.co.uk
# 31195 2012-09-05 00:00:00        jobsite.co.uk
# 32406 2013-12-23 15:00:00        jobsite.co.uk
# 33881 2012-07-31 00:00:00  jobs.guardian.co.uk
# 33886 2012-07-03 00:00:00  jobs.guardian.co.uk
# 33989 2012-12-02 00:00:00  jobs.guardian.co.uk
# 34047 2013-10-14 00:00:00  jobs.guardian.co.uk
# 34521 2012-11-17 00:00:00  jobs.guardian.co.uk
# 35177 2012-07-20 12:00:00    planetrecruit.com
# 36792 2012-04-30 15:00:00    strike-jobs.co.uk
# 36842 2013-03-27 12:00:00    strike-jobs.co.uk
# 37009 2012-03-20 15:00:00    salestarget.co.uk
# 39545 2012-10-22 15:00:00       Jobcentre Plus
# 39773 2012-10-22 15:00:00       Jobcentre Plus
# 39866 2013-03-02 12:00:00       Jobcentre Plus
# 39974 2012-08-05 00:00:00       Jobcentre Plus
# 40127 2013-09-27 00:00:00       Jobcentre Plus
# 40872 2012-08-01 00:00:00       Jobcentre Plus
# 44208 2013-09-01 00:00:00      jobstoday.co.uk
# 44248 2012-10-28 12:00:00      jobstoday.co.uk
# 46892 2014-03-31 00:00:00    careerbuilder.com
# 46911 2012-09-05 15:00:00    careerbuilder.com
# 47029 2013-03-06 00:00:00    careerbuilder.com
# 47040 2013-05-24 00:00:00    careerbuilder.com
# 47073 2012-10-27 12:00:00    careerbuilder.com
# 47079 2012-09-26 00:00:00    careerbuilder.com
# 47081 2014-02-08 15:00:00    careerbuilder.com
# 47086 2012-06-05 00:00:00    careerbuilder.com
# 47136 2012-08-27 00:00:00    careerbuilder.com
# 47160 2013-11-22 15:00:00    careerbuilder.com
# 50658 2012-08-09 12:00:00    jobsfinancial.com

# %% [markdown]
# The term .co.uk seems to be a domain extension. Let's see if same companies without the .co.uk exists. Let's try out Net Recruit and Advanse

# %%
ntr = df['Company'].str.match(r'[nN]et [rR]ecruit')
df[ntr]
# Out:
#              Id                                  Title         Location  \
# 30404  68347173          Laser Cutting Sales Estimator               Uk
# 35177  66127036                        Systems Analyst         Cheshire
# 50658  69535123  Collection Advisor, Credit Management  Gloucestershire
#
#                      Company   ContractType ContractTime  \
# 30404  Net Recruit.co.uk Ltd  non-specified    permanent
# 35177  Net Recruit.co.uk Ltd      full_time    permanent
# 50658  Net Recruit.co.uk Ltd      full_time    permanent
#
#                         Category Salary            OpenDate  \
# 30404                 Sales Jobs  30000 2012-03-26 12:00:00
# 35177                    IT Jobs  30000 2012-06-20 12:00:00
# 50658  Accounting & Finance Jobs  15500 2012-07-10 12:00:00
#
#                 CloseDate         SourceName
# 30404 2012-05-25 12:00:00      jobsite.co.uk
# 35177 2012-07-20 12:00:00  planetrecruit.com
# 50658 2012-08-09 12:00:00  jobsfinancial.com

# %%
ntr = df['Company'].str.match(r'Advanse')
df[ntr]
# Out:
#              Id                    Title Location        Company  \
# 20101  66609779        Joint Head Of Ict       Uk  Advanse.co.uk
# 44512  67774574  Uk Financial Controller  Bristol       Advanse
#
#         ContractType ContractTime                   Category Salary  \
# 20101  non-specified    permanent                    IT Jobs  86000
# 44512  non-specified    permanent  Accounting & Finance Jobs  47500
#
#                  OpenDate           CloseDate              SourceName
# 20101 2012-09-10 12:00:00 2012-12-09 12:00:00            cwjobs.co.uk
# 44512 2013-01-11 00:00:00 2013-02-10 00:00:00  accountancyagejobs.com

# %% [markdown]
# There are indeed some without the 'co.uk.'!

# %%
# Function similar to remove_com but removes .co.uk
def remove_couk(company):
    domain = re.match(r'.*\s*([\.\s][cC][oO][\.\s][uU][kK]).*',company).groups()[0]
    name = company.replace(domain,'')
    
    # SPlit namelist by capital letters and form a new string
    namelist = re.findall('[A-Z][^A-Z]*\s?', name)
    company_name = " ".join(namelist).strip()
    
    # If no capital letters, use the name without the .co.uk
    if len(namelist) == 0:
        company_name = name
        
    # Get closest match
    closest_match = find_closest_match(company_name,df['Company'].unique(),0.85)
    
    # Return the company name if it exists
    if company_name in df['Company'].unique():
        return company_name
    # If a close match is found
    elif len(closest_match) != 0 and closest_match[0] != company:
        print("Found close match for ",company_name," as ",closest_match)
        return closest_match[0]
    else:
        body = name.strip()
        return body

# %%
indices = list(df[co_uk].index)
for ind in indices:
    company = df['Company'][ind]
    new_company = remove_couk(company)
    # Record to errorDict
    errorDict = addToErrorDict(errorDict,ind,df['Id'][ind],'Company',company,new_company,'Name varient','Set to existing names')
    # Replace values with newly formatted values
    df.loc[ind,'Company'] = new_company
# Out:
# Found close match for  Easyvacancy  as  ['Easy Vacancy']
# Found close match for  Advanse  as  ['Advanse ']
# Found close match for  Net  Recruit  Ltd  as  ['New Recruit Ltd']
# Found close match for  N D K  Consulting  Ltd  as  ['NDK Consulting Ltd']
# Found close match for  Net  Recruit  Ltd  as  ['New Recruit Ltd']
# Found close match for  Motorecruit  as  ['Moto Recruit']
# Found close match for  Motorecruit  as  ['Moto Recruit']
# Found close match for  Easyvacancy  as  ['easyvacancy']
# Found close match for  Blue Town Online  as  ['BlueTown Online']
# Found close match for  Blue Town Online  as  ['BlueTown Online']
# Found close match for  Blue Town Online  as  ['BlueTown Online']
# Found close match for  Blue Town Online  as  ['BlueTown Online']
# Found close match for  Blue Town Online  as  ['BlueTown Online']
# Found close match for  Blue Town Online  as  ['BlueTown Online']
# Found close match for  Blue Town Online  as  ['BlueTown Online']
# Found close match for  Blue Town Online  as  ['BlueTown Online']
# Found close match for  Blue Town Online  as  ['BlueTown Online']
# Found close match for  Blue Town Online  as  ['BlueTown Online']
# Found close match for  Net  Recruit  Ltd  as  ['New Recruit Ltd']

# %% [markdown]
# Other than removing .co.uk, some of them are also replaced as to its closest match

# %%
valid_company = df['Company'].str.fullmatch(r'([a-zA-Z0-9]\s?)+')
df[~valid_company & ~non_specified]['Company']
# Out:
# 6112                                       CVL:LDN
# 7904                       C.O.A.L IT Services Ltd
# 7950            Lawrence Harvey Search & Selection
# 7977                       Canary Wharf & City Ltd
# 8025                       C.O.A.L IT Services Ltd
#                            ...
# 50186    States of Jersey Health & Social Services
# 50199    Guy's and St Thomas' NHS Foundation Trust
# 50229                                          B&Q
# 50460                   Sotheby's Institute of Art
# 50730                     Agora Search & Selection
# Name: Company, Length: 1052, dtype: object

# %% [markdown]
# There seems to be some value with the ":" symbol, let's check them

# %%
# Get companies with symbol :
colon_company = df['Company'].str.contains(r':')
df[colon_company]
# Out:
#              Id                                              Title  \
# 6112   69021870  Senior It Technician (3Rd Line)  Excellent Uk ...
# 10875  68696700                Senior Account Director  Automotive
# 11755  68681772                         Senior Pr Account Director
# 13963  68694672                           Studio Manager  Creative
# 18636  68712256                            Account Manager  Retail
# 30100  69687486                                    Digital Manager
# 41642  69054425                             Mobile Planner / Buyer
# 41671  69055842                         Promotions Account Manager
#
#                 Location            Company   ContractType ContractTime  \
# 6112   North West London            CVL:LDN  non-specified    permanent
# 10875            Warwick     id:recruitment  non-specified    permanent
# 11755                 Uk     id:recruitment  non-specified    permanent
# 13963          Leicester     id:recruitment  non-specified    permanent
# 18636          Rotherham     id:recruitment  non-specified    permanent
# 30100                 Uk       sk:n Clinics  non-specified    permanent
# 41642             London  Section:Media Ltd      full_time    permanent
# 41671     Central London  Section:Media Ltd      full_time    permanent
#
#                                Category Salary            OpenDate  \
# 6112                            IT Jobs  36000 2012-04-06 15:00:00
# 10875  PR, Advertising & Marketing Jobs  45000 2012-05-06 12:00:00
# 11755  PR, Advertising & Marketing Jobs  52500 2013-07-27 00:00:00
# 13963  PR, Advertising & Marketing Jobs  32500 2012-08-26 15:00:00
# 18636  PR, Advertising & Marketing Jobs  28500 2012-09-29 15:00:00
# 30100                           IT Jobs  35000 2013-11-12 00:00:00
# 41642                        Sales Jobs  26000 2012-06-01 12:00:00
# 41671                        Sales Jobs  28500 2012-10-25 12:00:00
#
#                 CloseDate           SourceName
# 6112  2012-07-05 15:00:00     cv-library.co.uk
# 10875 2012-07-05 12:00:00        totaljobs.com
# 11755 2013-10-25 00:00:00        totaljobs.com
# 13963 2012-09-25 15:00:00        totaljobs.com
# 18636 2012-10-29 15:00:00        totaljobs.com
# 30100 2014-01-11 00:00:00        jobsite.co.uk
# 41642 2012-08-30 12:00:00  mediaweekjobs.co.uk
# 41671 2012-12-24 12:00:00  mediaweekjobs.co.uk

# %% [markdown]
# Searching up these values, it seems like 'sk:n Clinics' and 'Section:Media Ltd' are actual companies. Thus, it close matches would be searched, if there are no close matches then we will keep as is

# %%
indices = list(df[colon_company].index)
# Find close matches
for ind in indices:
    print(df['Company'][ind],find_closest_match(df['Company'][ind],df['Company'].unique(),0.85))
# Out:
# CVL:LDN []
# id:recruitment []
# id:recruitment []
# id:recruitment []
# id:recruitment []
# sk:n Clinics []
# Section:Media Ltd []
# Section:Media Ltd []

# %% [markdown]
# Since they are no close matches, they will be kept as is but it will be recorded into the ErrorDict

# %%
indices = list(df[colon_company].index)
for ind in indices:
    # Record to errorDict
    errorDict = addToErrorDict(errorDict,ind,df['Id'][ind],'Company',df['Company'][ind],'','Company contains : character','Kept as is')

# %%
colon_company = df['Company'].str.contains(r':')
valid_company = df['Company'].str.fullmatch(r'([a-zA-Z0-9]\s?)+')
df[~valid_company & ~non_specified & ~colon_company]['Company']
# Out:
# 7904                       C.O.A.L IT Services Ltd
# 7950            Lawrence Harvey Search & Selection
# 7977                       Canary Wharf & City Ltd
# 8025                       C.O.A.L IT Services Ltd
# 8044                    Digital Guru's Recruitment
#                            ...
# 50186    States of Jersey Health & Social Services
# 50199    Guy's and St Thomas' NHS Foundation Trust
# 50229                                          B&Q
# 50460                   Sotheby's Institute of Art
# 50730                     Agora Search & Selection
# Name: Company, Length: 1044, dtype: object

# %% [markdown]
# A lot of the remaining data contains the '&' characters

# %%
# Get companies containing the & character
amp_company = df['Company'].str.contains(r'&')
df[amp_company]
# Out:
#              Id                                              Title  \
# 7950   68627844    Sap Bw Consultant  Birmingham/Manchester  ****K
# 7977   71774937  Biztalk Specialist  Global Corporation, Egham ...
# 8096   72372986                                Qa Automated Tester
# 8324   71336370  Test Analyst, System, Integration, Uat, Siebel...
# 8559   68628231     Oracle Bi Obiee Consultant  London  ****K****K
# ...         ...                                                ...
# 48349  69133890  European Sales And Marketing Administrator – C...
# 49764  70578346                         B**** Fire Safety Engineer
# 50186  71356729                                Senior Staff Nurses
# 50229  72328268                       B&Q Finance Business Partner
# 50730  69815649                           Futures Dma Desk Support
#
#              Location                                    Company  \
# 7950    West Midlands         Lawrence Harvey Search & Selection
# 7977            Egham                    Canary Wharf & City Ltd
# 8096   Central London                   Hudson Banking & Finance
# 8324           London                 Capita Assurance & Testing
# 8559           London         Lawrence Harvey Search & Selection
# ...               ...                                        ...
# 48349              Uk                Veenus Hotels & Experiences
# 49764              Uk                 Health & Safety Laboratory
# 50186              Uk  States of Jersey Health & Social Services
# 50229       Hampshire                                        B&Q
# 50730          London                   Agora Search & Selection
#
#         ContractType   ContractTime                          Category  \
# 7950   non-specified      permanent                           IT Jobs
# 7977   non-specified      permanent                           IT Jobs
# 8096   non-specified      permanent                           IT Jobs
# 8324   non-specified       contract                           IT Jobs
# 8559   non-specified      permanent                           IT Jobs
# ...              ...            ...                               ...
# 48349  non-specified      permanent  PR, Advertising & Marketing Jobs
# 49764  non-specified  non-specified                     Teaching Jobs
# 50186  non-specified  non-specified         Healthcare & Nursing Jobs
# 50229  non-specified      permanent                           IT Jobs
# 50730  non-specified      permanent         Accounting & Finance Jobs
#
#         Salary            OpenDate           CloseDate              SourceName
# 7950     45000 2013-03-13 00:00:00 2013-04-12 00:00:00            jobserve.com
# 7977           2013-12-09 15:00:00 2014-03-09 15:00:00            jobserve.com
# 8096     70000 2012-10-08 15:00:00 2012-11-07 15:00:00            jobserve.com
# 8324     60000 2012-04-30 12:00:00 2012-05-30 12:00:00            jobserve.com
# 8559     75000 2013-10-12 15:00:00 2013-12-11 15:00:00            jobserve.com
# ...        ...                 ...                 ...                     ...
# 48349    18750 2013-06-05 15:00:00 2013-09-03 15:00:00   Multilingualvacancies
# 49764    34635 2012-01-23 12:00:00 2012-02-22 12:00:00                 Jobs Ac
# 50186    35926 2013-08-06 15:00:00 2013-10-05 15:00:00   rcnbulletinjobs.co.uk
# 50229    42500 2013-05-13 00:00:00 2013-06-12 00:00:00        emptylemon.co.uk
# 50730  90000.0 2013-06-13 15:00:00 2013-08-12 15:00:00  frontofficebanking.com
#
# [668 rows x 11 columns]

# %% [markdown]
# Let's dive deeper into some of the values

# %%
# Get companies with the name Lawrence Harvey
df[df['Company'].str.contains('Lawrence Harvey')]
# Out:
#              Id                                              Title  \
# 7950   68627844    Sap Bw Consultant  Birmingham/Manchester  ****K
# 8559   68628231     Oracle Bi Obiee Consultant  London  ****K****K
# 8574   72160555  Principal/Senior Bi Consultant  London  ****K*...
# 17940  71680779     French Corporate Sales Consultant  London City
# 19832  72549672               Sas Consultant  London  **** / ****K
# 20196  71565739  Vdi Desktop Citrix Architect/Presales (Ccia/Cc...
# 20467  70781767  Consultant Sap (Sd / Mm / Hum / Wm)  Conseil  ...
# 20833  69038417                    Oracle Dba  Leeds  ****K  ****K
# 21016  71564994  Sap Data Migration Consultant Bodsmanchesteren...
# 21037  71566372  Principal Microsoft Sccm Desktop Consultant  *...
# 21073  71565021  Epm Finance Analytics Big 4 Consultancy Financ...
# 21143  72126391  Sap Mmp****P Managing Consultant  Top Consultancy
# 21208  71565006  Sap Fico Co Pa End User Manufacturing South Lo...
# 21263  71565013  Sap Fico Lead Insurance Makret City Of London ...
# 21459  69041817  Microsoft (Uc) Consultant  Home Based & Uk  **...
# 21802  71565014  Manufacturing Delivery Directorgrow Your Own P...
# 21960  71565003           Sap Fico Is Retail End User London ****K
# 22186  71565000  Sap Project/Programme Manager Leading Si Deliv...
# 22218  71565001  Sap Fico Consultantmidlands Or Manchester Mini...
# 22411  68361096         Consultant Amoa Banque Finance / Cdi / Idf
# 22444  69038428  Oracle Hyperion Hfm Consultants / London / ***...
# 22529  71565012  Sap Fico Consultant Consulting Company Jva Exp...
# 31706  69687191  Senior Video Conferencing Engineer  Berkshire ...
# 32844  69687038  Presales Architect  Video Conferencing  Surrey...
# 48059  69065208       Pmo/Pmo Lead/Pmo Manager  Financial Services
# 48078  71592036           Pmo Lead/Pmo Manager  Financial Services
#
#                 Location                               Company   ContractType  \
# 7950       West Midlands    Lawrence Harvey Search & Selection  non-specified
# 8559              London    Lawrence Harvey Search & Selection  non-specified
# 8574              London    Lawrence Harvey Search & Selection  non-specified
# 17940             London    Lawrence Harvey Search & Selection  non-specified
# 19832  South East London                       Lawrence Harvey  non-specified
# 20196                 Uk                       Lawrence Harvey  non-specified
# 20467                 Uk                       Lawrence Harvey  non-specified
# 20833              Leeds                       Lawrence Harvey  non-specified
# 21016                 Uk                       Lawrence Harvey  non-specified
# 21037                 Uk                       Lawrence Harvey  non-specified
# 21073  South East London                       Lawrence Harvey  non-specified
# 21143  South East London                       Lawrence Harvey  non-specified
# 21208  South East London                       Lawrence Harvey  non-specified
# 21263  South East London                       Lawrence Harvey  non-specified
# 21459                 Uk                       Lawrence Harvey  non-specified
# 21802  South East London                       Lawrence Harvey  non-specified
# 21960  South East London                       Lawrence Harvey  non-specified
# 22186  South East London                       Lawrence Harvey  non-specified
# 22218                 Uk                       Lawrence Harvey  non-specified
# 22411                 Uk                       Lawrence Harvey  non-specified
# 22444  South East London                       Lawrence Harvey  non-specified
# 22529  South East London                       Lawrence Harvey  non-specified
# 31706          Berkshire  Lawrence Harvey Search Selection Ltd  non-specified
# 32844             Surrey  Lawrence Harvey Search Selection Ltd  non-specified
# 48059          Cambridge      Lawrence Harvey Search Selection  non-specified
# 48078          Cambridge      Lawrence Harvey Search Selection  non-specified
#
#       ContractTime                   Category Salary            OpenDate  \
# 7950     permanent                    IT Jobs  45000 2013-03-13 00:00:00
# 8559     permanent                    IT Jobs  75000 2013-10-12 15:00:00
# 8574     permanent                    IT Jobs  90000 2012-03-27 12:00:00
# 17940    permanent                 Sales Jobs  26500 2013-02-26 15:00:00
# 19832    permanent                    IT Jobs  55000 2012-02-06 15:00:00
# 20196    permanent                    IT Jobs  70000 2012-06-26 15:00:00
# 20467    permanent                    IT Jobs  40055 2013-10-07 00:00:00
# 20833    permanent                    IT Jobs  55000 2012-07-31 15:00:00
# 21016    permanent                    IT Jobs  47500 2012-11-18 00:00:00
# 21037    permanent                    IT Jobs  65000 2013-10-02 15:00:00
# 21073    permanent                    IT Jobs  27825 2012-10-24 12:00:00
# 21143    permanent                    IT Jobs  85000 2013-12-21 00:00:00
# 21208    permanent                    IT Jobs  60000 2012-10-05 12:00:00
# 21263    permanent                    IT Jobs  62500 2013-07-07 00:00:00
# 21459    permanent                    IT Jobs  42500 2013-10-09 15:00:00
# 21802    permanent                    IT Jobs  77500 2013-04-22 12:00:00
# 21960    permanent                    IT Jobs  69000 2013-03-22 15:00:00
# 22186    permanent                    IT Jobs  87500 2012-07-11 12:00:00
# 22218    permanent                    IT Jobs  60000 2012-03-19 15:00:00
# 22411    permanent                    IT Jobs  42057 2013-08-14 12:00:00
# 22444    permanent                    IT Jobs  70000 2012-05-09 15:00:00
# 22529    permanent                    IT Jobs  82500 2012-01-26 00:00:00
# 31706    permanent                    IT Jobs  45000 2012-08-25 12:00:00
# 32844    permanent                    IT Jobs  50000 2012-04-12 12:00:00
# 48059    permanent  Accounting & Finance Jobs  35000 2013-07-06 15:00:00
# 48078    permanent  Accounting & Finance Jobs  37500 2013-04-11 00:00:00
#
#                 CloseDate     SourceName
# 7950  2013-04-12 00:00:00   jobserve.com
# 8559  2013-12-11 15:00:00   jobserve.com
# 8574  2012-06-25 12:00:00   jobserve.com
# 17940 2013-05-27 15:00:00  totaljobs.com
# 19832 2012-03-07 15:00:00   cwjobs.co.uk
# 20196 2012-08-25 15:00:00   cwjobs.co.uk
# 20467 2014-01-05 00:00:00   cwjobs.co.uk
# 20833 2012-09-29 15:00:00   cwjobs.co.uk
# 21016 2012-12-18 00:00:00   cwjobs.co.uk
# 21037 2013-11-01 15:00:00   cwjobs.co.uk
# 21073 2012-11-23 12:00:00   cwjobs.co.uk
# 21143 2014-01-20 00:00:00   cwjobs.co.uk
# 21208 2013-01-03 12:00:00   cwjobs.co.uk
# 21263 2013-08-06 00:00:00   cwjobs.co.uk
# 21459 2014-01-07 15:00:00   cwjobs.co.uk
# 21802 2013-07-21 12:00:00   cwjobs.co.uk
# 21960 2013-04-21 15:00:00   cwjobs.co.uk
# 22186 2012-10-09 12:00:00   cwjobs.co.uk
# 22218 2012-06-17 15:00:00   cwjobs.co.uk
# 22411 2013-10-13 12:00:00   cwjobs.co.uk
# 22444 2012-07-08 15:00:00   cwjobs.co.uk
# 22529 2012-02-25 00:00:00   cwjobs.co.uk
# 31706 2012-11-23 12:00:00  jobsite.co.uk
# 32844 2012-07-11 12:00:00  jobsite.co.uk
# 48059 2013-10-04 15:00:00  tntjobs.co.uk
# 48078 2013-06-10 00:00:00  tntjobs.co.uk

# %% [markdown]
# It looks like companies may or may not contain the 'Search & Selection' term! All these value would be looked up and removed

# %%
# Get companies with the phrase search and selection
ss = df['Company'].str.contains('[sS]earch\s(&|and)?\s?[sS]election.*')
df[ss]
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2328\44381664.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   ss = df['Company'].str.contains('[sS]earch\s(&|and)?\s?[sS]election.*')
#              Id                                              Title  \
# 2724   70770700                              Cisco Network Analyst
# 2889   69081556         Semi Skilled Building Maintenance Engineer
# 3180   70219038                               Bms Support Engineer
# 4255   69012180                                Scientific Director
# 4394   67903619                Agile Java Developer, Online Gaming
# ...         ...                                                ...
# 49462  71375525              Qualified Accountant  Immediate Start
# 49498  67637107                           Finance Business Analyst
# 49694  69133532  Senior Manager  It Project & Program Risk Assu...
# 50014  70574295  Hr Project Manager (6 Months Temporary With St...
# 50730  69815649                           Futures Dma Desk Support
#
#                 Location                              Company   ContractType  \
# 2724      Central London              Bishop Search Selection  non-specified
# 2889              Dundee                 PDA Search Selection  non-specified
# 3180            Scotland                 PDA Search Selection  non-specified
# 4255              London                  ID Search Selection  non-specified
# 4394      Central London              Bishop Search Selection  non-specified
# ...                  ...                                  ...            ...
# 49462            Belfast            Bond Search Selection Ltd      full_time
# 49498            Croydon  Greybridge Search and Selection Ltd  non-specified
# 49694     Central London                 CGS Search Selection      full_time
# 50014  North West London         PDA Search and Selection Ltd      full_time
# 50730             London             Agora Search & Selection  non-specified
#
#       ContractTime                   Category   Salary            OpenDate  \
# 2724      contract                    IT Jobs    90000 2013-03-02 15:00:00
# 2889     permanent           Engineering Jobs    22000 2013-09-20 12:00:00
# 3180     permanent           Engineering Jobs          2013-11-02 00:00:00
# 4255     permanent  Healthcare & Nursing Jobs    55000 2012-09-02 12:00:00
# 4394     permanent                    IT Jobs    53000 2013-05-21 00:00:00
# ...            ...                        ...      ...                 ...
# 49462     contract  Accounting & Finance Jobs    32500 2012-09-30 15:00:00
# 49498    permanent  Accounting & Finance Jobs    55000 2013-09-03 15:00:00
# 49694    permanent  Accounting & Finance Jobs    90000 2013-05-16 15:00:00
# 50014     contract           Engineering Jobs  35000.0 2013-06-17 00:00:00
# 50730    permanent  Accounting & Finance Jobs  90000.0 2013-06-13 15:00:00
#
#                 CloseDate                 SourceName
# 2724  2013-03-16 15:00:00           cv-library.co.uk
# 2889  2013-11-19 12:00:00           cv-library.co.uk
# 3180  2014-01-31 00:00:00           cv-library.co.uk
# 4255  2012-12-01 12:00:00           cv-library.co.uk
# 4394  2013-07-20 00:00:00           cv-library.co.uk
# ...                   ...                        ...
# 49462 2012-11-29 15:00:00                 nijobs.com
# 49498 2013-10-03 15:00:00  onlineinsurancejobs.co.uk
# 49694 2013-08-14 15:00:00         careersinaudit.com
# 50014 2013-09-15 00:00:00      thecareerengineer.com
# 50730 2013-08-12 15:00:00     frontofficebanking.com
#
# [179 rows x 11 columns]

# %%
indices = list(df[ss].index)
for ind in indices:
    # Get the search and selection word
    match = re.search(r'(\s[sS]earch\s(?:&|and)?\s?[sS]election)',df['Company'][ind]).groups()[0]
    # Remove the value
    df.loc[ind,'Company'] = df.loc[ind,'Company'].replace(match,'')
df[ss]
# Out:
#              Id                                              Title  \
# 2724   70770700                              Cisco Network Analyst
# 2889   69081556         Semi Skilled Building Maintenance Engineer
# 3180   70219038                               Bms Support Engineer
# 4255   69012180                                Scientific Director
# 4394   67903619                Agile Java Developer, Online Gaming
# ...         ...                                                ...
# 49462  71375525              Qualified Accountant  Immediate Start
# 49498  67637107                           Finance Business Analyst
# 49694  69133532  Senior Manager  It Project & Program Risk Assu...
# 50014  70574295  Hr Project Manager (6 Months Temporary With St...
# 50730  69815649                           Futures Dma Desk Support
#
#                 Location         Company   ContractType ContractTime  \
# 2724      Central London          Bishop  non-specified     contract
# 2889              Dundee             PDA  non-specified    permanent
# 3180            Scotland             PDA  non-specified    permanent
# 4255              London              ID  non-specified    permanent
# 4394      Central London          Bishop  non-specified    permanent
# ...                  ...             ...            ...          ...
# 49462            Belfast        Bond Ltd      full_time     contract
# 49498            Croydon  Greybridge Ltd  non-specified    permanent
# 49694     Central London             CGS      full_time    permanent
# 50014  North West London         PDA Ltd      full_time     contract
# 50730             London           Agora  non-specified    permanent
#
#                         Category   Salary            OpenDate  \
# 2724                     IT Jobs    90000 2013-03-02 15:00:00
# 2889            Engineering Jobs    22000 2013-09-20 12:00:00
# 3180            Engineering Jobs          2013-11-02 00:00:00
# 4255   Healthcare & Nursing Jobs    55000 2012-09-02 12:00:00
# 4394                     IT Jobs    53000 2013-05-21 00:00:00
# ...                          ...      ...                 ...
# 49462  Accounting & Finance Jobs    32500 2012-09-30 15:00:00
# 49498  Accounting & Finance Jobs    55000 2013-09-03 15:00:00
# 49694  Accounting & Finance Jobs    90000 2013-05-16 15:00:00
# 50014           Engineering Jobs  35000.0 2013-06-17 00:00:00
# 50730  Accounting & Finance Jobs  90000.0 2013-06-13 15:00:00
#
#                 CloseDate                 SourceName
# 2724  2013-03-16 15:00:00           cv-library.co.uk
# 2889  2013-11-19 12:00:00           cv-library.co.uk
# 3180  2014-01-31 00:00:00           cv-library.co.uk
# 4255  2012-12-01 12:00:00           cv-library.co.uk
# 4394  2013-07-20 00:00:00           cv-library.co.uk
# ...                   ...                        ...
# 49462 2012-11-29 15:00:00                 nijobs.com
# 49498 2013-10-03 15:00:00  onlineinsurancejobs.co.uk
# 49694 2013-08-14 15:00:00         careersinaudit.com
# 50014 2013-09-15 00:00:00      thecareerengineer.com
# 50730 2013-08-12 15:00:00     frontofficebanking.com
#
# [179 rows x 11 columns]

# %%
# Get companies containing & character with spaces
symbols = df['Company'].str.contains(r' & ')
df[symbols]
# Out:
#              Id                                              Title  \
# 7977   71774937  Biztalk Specialist  Global Corporation, Egham ...
# 8096   72372986                                Qa Automated Tester
# 8324   71336370  Test Analyst, System, Integration, Uat, Siebel...
# 8666   70249406                     Compliance Solution Specialist
# 8971   71774803  Data Centre Engineer Needed (Citrix, Xenapp, X...
# ...         ...                                                ...
# 46975  71212592                     Assistant Front Office Manager
# 47126  71700819                      Full Time And Part Time Sales
# 48349  69133890  European Sales And Marketing Administrator – C...
# 49764  70578346                         B**** Fire Safety Engineer
# 50186  71356729                                Senior Staff Nurses
#
#              Location                                     Company  \
# 7977            Egham                     Canary Wharf & City Ltd
# 8096   Central London                    Hudson Banking & Finance
# 8324           London                  Capita Assurance & Testing
# 8666           London                        J & C Associates Ltd
# 8971           London                             McCabe & Barton
# ...               ...                                         ...
# 46975         Bristol  Independently Owned & Operated Holiday Inn
# 47126      Trowbridge                    MR I MARR & MISS G HIVES
# 48349              Uk                 Veenus Hotels & Experiences
# 49764              Uk                  Health & Safety Laboratory
# 50186              Uk   States of Jersey Health & Social Services
#
#         ContractType   ContractTime                          Category  \
# 7977   non-specified      permanent                           IT Jobs
# 8096   non-specified      permanent                           IT Jobs
# 8324   non-specified       contract                           IT Jobs
# 8666   non-specified      permanent                           IT Jobs
# 8971   non-specified      permanent                           IT Jobs
# ...              ...            ...                               ...
# 46975      full_time  non-specified       Hospitality & Catering Jobs
# 47126      full_time  non-specified                        Sales Jobs
# 48349  non-specified      permanent  PR, Advertising & Marketing Jobs
# 49764  non-specified  non-specified                     Teaching Jobs
# 50186  non-specified  non-specified         Healthcare & Nursing Jobs
#
#         Salary            OpenDate           CloseDate             SourceName
# 7977           2013-12-09 15:00:00 2014-03-09 15:00:00           jobserve.com
# 8096     70000 2012-10-08 15:00:00 2012-11-07 15:00:00           jobserve.com
# 8324     60000 2012-04-30 12:00:00 2012-05-30 12:00:00           jobserve.com
# 8666     72500 2012-09-20 15:00:00 2012-12-19 15:00:00           jobserve.com
# 8971     65000 2012-12-01 15:00:00 2013-01-30 15:00:00           jobserve.com
# ...        ...                 ...                 ...                    ...
# 46975  15000.0 2012-01-02 12:00:00 2012-04-01 12:00:00      careerbuilder.com
# 47126  20000.0 2013-06-25 12:00:00 2013-09-23 12:00:00      careerbuilder.com
# 48349    18750 2013-06-05 15:00:00 2013-09-03 15:00:00  Multilingualvacancies
# 49764    34635 2012-01-23 12:00:00 2012-02-22 12:00:00                Jobs Ac
# 50186    35926 2013-08-06 15:00:00 2013-10-05 15:00:00  rcnbulletinjobs.co.uk
#
# [581 rows x 11 columns]

# %% [markdown]
# Let's check if these companies has similar names

# %%
indices = list(df[symbols].index)
for ind in indices:
    # Replace & with ' and ' and see if the company exists
    rpr_and = df['Company'][ind].replace(' & ',' and ')
    closest = find_closest_match(rpr_and,df['Company'].unique(),0.85)
    if len(closest) > 0 and closest[0] != df['Company'][ind]:
        print('Found match for ',df['Company'][ind]," as ",closest)
# Out:
# Found match for  Randstad Financial & Professional  as  ['Randstad Financial and Professional Ltd']
# Found match for  Edwards & Pearce  as  ['Edwards and Pearce Ltd']
# Found match for  Randstad Financial & Professional  as  ['Randstad Financial and Professional Ltd']
# Found match for  Randstad Financial & Professional  as  ['Randstad Financial and Professional Ltd']
# Found match for  Badenoch & Clark   as  ['Badenoch and Clark']
# Found match for  Badenoch & Clark   as  ['Badenoch and Clark']
# Found match for  Badenoch & Clark   as  ['Badenoch and Clark']
# Found match for  Badenoch & Clark   as  ['Badenoch and Clark']
# Found match for  Badenoch & Clark   as  ['Badenoch and Clark']
# Found match for  Randstad Financial & Professional  as  ['Randstad Financial and Professional Ltd']
# Found match for  Badenoch & Clark   as  ['Badenoch and Clark']
# Found match for  Badenoch & Clark   as  ['Badenoch and Clark']
# Found match for  Badenoch & Clark   as  ['Badenoch and Clark']
# Found match for  Badenoch & Clark   as  ['Badenoch and Clark']
# Found match for  Randstad Financial & Professional  as  ['Randstad Financial and Professional Ltd']
# Found match for  Badenoch & Clark   as  ['Badenoch and Clark']
# Found match for  Badenoch & Clark   as  ['Badenoch and Clark']
# Found match for  Randstad Financial & Professional  as  ['Randstad Financial and Professional Ltd']
# Found match for  Badenoch & Clark   as  ['Badenoch and Clark']
# Found match for  Badenoch & Clark   as  ['Badenoch and Clark']
# Found match for  Randstad Financial & Professional  as  ['Randstad Financial and Professional Ltd']
# Found match for  Badenoch & Clark   as  ['Badenoch and Clark']
# Found match for  Badenoch & Clark   as  ['Badenoch and Clark']
# Found match for  Edwards & Pearce  as  ['Edwards and Pearce Ltd']
# Found match for  Edwards & Pearce  as  ['Edwards and Pearce Ltd']
# Found match for  Badenoch & Clark   as  ['Badenoch and Clark']
# Found match for  Edwards & Pearce  as  ['Edwards and Pearce Ltd']
# Found match for  Badenoch & Clark   as  ['Badenoch and Clark']
# Found match for  Edwards & Pearce  as  ['Edwards and Pearce Ltd']
# Found match for  Randstad Financial & Professional  as  ['Randstad Financial and Professional Ltd']
# Found match for  Edwards & Pearce  as  ['Edwards and Pearce Ltd']
# Found match for  Edwards & Pearce  as  ['Edwards and Pearce Ltd']
# Found match for  Badenoch & Clark   as  ['Badenoch and Clark']
# Found match for  Randstad Financial & Professional  as  ['Randstad Financial and Professional Ltd']
# Found match for  Randstad Financial & Professional  as  ['Randstad Financial and Professional Ltd']
# Found match for  Randstad Financial & Professional  as  ['Randstad Financial and Professional Ltd']
# Found match for  Badenoch & Clark   as  ['Badenoch and Clark']
# Found match for  Badenoch & Clark   as  ['Badenoch and Clark']
# Found match for  Badenoch & Clark   as  ['Badenoch and Clark']
# Found match for  Badenoch & Clark   as  ['Badenoch and Clark']
# Found match for  Badenoch & Clark   as  ['Badenoch and Clark']
# Found match for  Edwards & Pearce  as  ['Edwards and Pearce Ltd']
# Found match for  Badenoch & Clark   as  ['Badenoch and Clark']
# Found match for  Badenoch & Clark   as  ['Badenoch and Clark']
# Found match for  Badenoch & Clark   as  ['Badenoch and Clark']
# Found match for  Badenoch & Clark   as  ['Badenoch and Clark']
# Found match for  Badenoch & Clark   as  ['Badenoch and Clark']
# Found match for  Randstad Financial & Professional  as  ['Randstad Financial and Professional Ltd']
# Found match for  Randstad Financial & Professional  as  ['Randstad Financial and Professional Ltd']
# Found match for  Badenoch & Clark   as  ['Badenoch and Clark']
# Found match for  Badenoch & Clark   as  ['Badenoch and Clark']
# Found match for  Randstad Financial & Professional  as  ['Randstad Financial and Professional Ltd']
# Found match for  Randstad Financial & Professional  as  ['Randstad Financial and Professional Ltd']
# Found match for  Randstad Financial & Professional  as  ['Randstad Financial and Professional Ltd']
# Found match for  Badenoch & Clark   as  ['Badenoch and Clark']
# Found match for  Badenoch & Clark   as  ['Badenoch and Clark']
# Found match for  Badenoch & Clark   as  ['Badenoch and Clark']
# Found match for  Badenoch & Clark   as  ['Badenoch and Clark']
# Found match for  Badenoch & Clark   as  ['Badenoch and Clark']
# Found match for  Badenoch & Clark   as  ['Badenoch and Clark']
# Found match for  Edwards & Pearce  as  ['Edwards and Pearce Ltd']
# Found match for  Badenoch & Clark   as  ['Badenoch and Clark']
# Found match for  Randstad Financial & Professional  as  ['Randstad Financial and Professional Ltd']
# Found match for  Badenoch & Clark   as  ['Badenoch and Clark']
# Found match for  Badenoch & Clark   as  ['Badenoch and Clark']
# Found match for  Badenoch & Clark   as  ['Badenoch and Clark']
# Found match for  Randstad Financial & Professional  as  ['Randstad Financial and Professional Ltd']
# Found match for  Badenoch & Clark   as  ['Badenoch and Clark']
# Found match for  Badenoch & Clark   as  ['Badenoch and Clark']
# Found match for  Badenoch & Clark   as  ['Badenoch and Clark']
# Found match for  Badenoch & Clark   as  ['Badenoch and Clark']
# Found match for  Badenoch & Clark   as  ['Badenoch and Clark']
# Found match for  Badenoch & Clark   as  ['Badenoch and Clark']
# Found match for  Edwards & Pearce  as  ['Edwards and Pearce Ltd']
# Found match for  Randstad Financial & Professional  as  ['Randstad Financial and Professional Ltd']
# Found match for  Badenoch & Clark   as  ['Badenoch and Clark']
# Found match for  Badenoch & Clark   as  ['Badenoch and Clark']
# Found match for  Badenoch & Clark   as  ['Badenoch and Clark']
# Found match for  Badenoch & Clark   as  ['Badenoch and Clark']
# Found match for  Badenoch & Clark   as  ['Badenoch and Clark']
# Found match for  Elevate Recruitment & Training Consultants  as  ['Elevate Recruitment and Training Consultants Ltd']
# Found match for  Badenoch & Clark   as  ['Badenoch and Clark']
# Found match for  Alpha Labour & Recruitment  as  ['Alpha Labour and Recruitment Ltd']
# Found match for  Randstad Financial & Professional  as  ['Randstad Financial and Professional Ltd']
# Found match for  Randstad Financial & Professional  as  ['Randstad Financial and Professional Ltd']
# Found match for  Randstad Financial & Professional  as  ['Randstad Financial and Professional Ltd']
# Found match for  Randstad Financial & Professional  as  ['Randstad Financial and Professional Ltd']
# Found match for  Randstad Financial & Professional  as  ['Randstad Financial and Professional Ltd']
# Found match for  Randstad Financial & Professional  as  ['Randstad Financial and Professional Ltd']
# Found match for  Randstad Financial & Professional  as  ['Randstad Financial and Professional Ltd']
# Found match for  Randstad Financial & Professional  as  ['Randstad Financial and Professional Ltd']
# Found match for  Randstad Financial & Professional  as  ['Randstad Financial and Professional Ltd']

# %% [markdown]
# As expected, most of them does. Thus, all those symbols would be replaced by 'and'

# %%
indices = list(df[symbols].index)
for ind in indices:
    company = df['Company'][ind].replace(' & ',' and ')
    closest = find_closest_match(company,df['Company'].unique(),0.85)
    if len(closest) > 0 and closest[0] != df['Company'][ind]:
        company = closest[0]
    # Reocrd to errorDict
    errorDict = addToErrorDict(errorDict,ind,df['Id'][ind],'Company',df['Company'][ind],company,'Contains & character','Replace & with and')
    # Replace the values with the closest match
    df.loc[ind,'Company'] = company
df[symbols].head()
# Out:
#             Id                                              Title  \
# 7977  71774937  Biztalk Specialist  Global Corporation, Egham ...
# 8096  72372986                                Qa Automated Tester
# 8324  71336370  Test Analyst, System, Integration, Uat, Siebel...
# 8666  70249406                     Compliance Solution Specialist
# 8971  71774803  Data Centre Engineer Needed (Citrix, Xenapp, X...
#
#             Location                       Company   ContractType  \
# 7977           Egham     Canary Wharf and City Ltd  non-specified
# 8096  Central London    Hudson Banking and Finance  non-specified
# 8324          London  Capita Assurance and Testing  non-specified
# 8666          London        J and C Associates Ltd  non-specified
# 8971          London             McCabe and Barton  non-specified
#
#      ContractTime Category Salary            OpenDate           CloseDate  \
# 7977    permanent  IT Jobs        2013-12-09 15:00:00 2014-03-09 15:00:00
# 8096    permanent  IT Jobs  70000 2012-10-08 15:00:00 2012-11-07 15:00:00
# 8324     contract  IT Jobs  60000 2012-04-30 12:00:00 2012-05-30 12:00:00
# 8666    permanent  IT Jobs  72500 2012-09-20 15:00:00 2012-12-19 15:00:00
# 8971    permanent  IT Jobs  65000 2012-12-01 15:00:00 2013-01-30 15:00:00
#
#         SourceName
# 7977  jobserve.com
# 8096  jobserve.com
# 8324  jobserve.com
# 8666  jobserve.com
# 8971  jobserve.com

# %% [markdown]
# Let's take a last look at those with companies with '&'

# %%
# Get companies containing & but no spaces
amp = df['Company'].str.contains(r'&')
df[amp]
# Out:
#              Id                                              Title  \
# 10348  69209598           Field Service Engineer (Novellus Or Lam)
# 11037  69593023          Assistant Manager For Premier Sports Shop
# 12768  69800316  Retail Events Assistant  Target Driven Individ...
# 13205  68685159      B&Q Insurance And Business Continuity Advisor
# 13990  71431181  Sales Negotiator  Leading Estate Agency  Golde...
# 14371  68711497            Hardware Design Engineer  Sussex  ****K
# 15578  68685326                B&Q Finance Business Partner People
# 19228  72239048                  Fpga Design Engineer  Avon  ****K
# 20656  68360151                           Aspnet Developer Mvc****
# 22043  70781811                    1St/2Nd Line It Support Analyst
# 22927  68591212               Head Pastry Chef  New Opening  Leeds
# 23913  70144132                 Junior Sous Chef  Avenue  West End
# 24079  68591081                               Support Chef Manager
# 24727  68591163                                     Executive Chef
# 34237  71844015              B&Q Customer Insight Analyst  Bespoke
# 34327  68225719           B&Q Finance Business Partner  Tradepoint
# 34920  61280832                   Mechanical Cad Designer Engineer
# 35484  58966479                    Senior Hardware Design Engineer
# 39721  72138502                               Hgv / Van Technician
# 40414  70590602                                Mechanic/Mot Tester
# 40561  72171085                      Appointment Maker & Telesales
# 44140  68393583  Risk Management  Project Managers Consultants ...
# 46954  66945355                                     Bank Assistant
# 50229  72328268                       B&Q Finance Business Partner
#
#                   Location                                Company  \
# 10348              Glasgow                    P&C Recruitment Ltd
# 11037               London                          A&P Resources
# 12768  Newcastle Upon Tyne                             A&R Events
# 13205            Eastleigh                                    B&Q
# 13990               London                          A&P Resources
# 14371                Lewes                                   RE&M
# 15578            Eastleigh                                    B&Q
# 19228       Shepton Mallet                                   RE&M
# 20656               Surrey                             H&R Talent
# 22043                   Uk                             H&R Talent
# 22927                Leeds                             D&D London
# 23913           East Sheen                             D&D London
# 24079    South East London  Charlton House c/o CH&Co Catering Ltd
# 24727              Crawley  Charlton House c/o CH&Co Catering Ltd
# 34237            Hampshire                                B&Q PLC
# 34327            Hampshire                                B&Q PLC
# 34920                   Uk                    P&C Recruitment Ltd
# 35484    South Lanarkshire                    P&C Recruitment Ltd
# 39721              Lincoln                        S&P Garages Ltd
# 40414    Thorpe St. Andrew           budget tyres&garage services
# 40561              Ashford                          P&H Marketing
# 44140               London                     S&H Consulting Ltd
# 46954              Bristol                               M&S Bank
# 50229            Hampshire                                    B&Q
#
#         ContractType   ContractTime                          Category  \
# 10348      full_time      permanent                           IT Jobs
# 11037  non-specified      permanent                        Sales Jobs
# 12768  non-specified      permanent                        Sales Jobs
# 13205  non-specified      permanent         Accounting & Finance Jobs
# 13990  non-specified      permanent                        Sales Jobs
# 14371  non-specified      permanent                  Engineering Jobs
# 15578  non-specified      permanent         Accounting & Finance Jobs
# 19228  non-specified      permanent                  Engineering Jobs
# 20656  non-specified       contract                           IT Jobs
# 22043  non-specified       contract                           IT Jobs
# 22927  non-specified  non-specified       Hospitality & Catering Jobs
# 23913  non-specified  non-specified       Hospitality & Catering Jobs
# 24079  non-specified  non-specified       Hospitality & Catering Jobs
# 24727  non-specified  non-specified       Hospitality & Catering Jobs
# 34237      full_time      permanent  PR, Advertising & Marketing Jobs
# 34327      full_time      permanent         Accounting & Finance Jobs
# 34920      full_time      permanent                           IT Jobs
# 35484      full_time      permanent                           IT Jobs
# 39721      full_time  non-specified                  Engineering Jobs
# 40414      full_time  non-specified                  Engineering Jobs
# 40561      full_time  non-specified                        Sales Jobs
# 44140  non-specified  non-specified         Accounting & Finance Jobs
# 46954      full_time  non-specified         Accounting & Finance Jobs
# 50229  non-specified      permanent                           IT Jobs
#
#         Salary            OpenDate           CloseDate           SourceName
# 10348    33500 2012-12-09 12:00:00 2013-03-09 12:00:00          fish4.co.uk
# 11037    15000 2013-10-28 15:00:00 2013-12-27 15:00:00        totaljobs.com
# 12768    15600 2012-02-04 12:00:00 2012-03-05 12:00:00        totaljobs.com
# 13205    52500 2012-08-04 12:00:00 2012-09-03 12:00:00        totaljobs.com
# 13990    14000 2012-08-04 12:00:00 2012-10-03 12:00:00        totaljobs.com
# 14371    37500 2013-12-21 15:00:00 2014-02-19 15:00:00        totaljobs.com
# 15578    42500 2012-10-20 15:00:00 2012-11-19 15:00:00        totaljobs.com
# 19228    35000 2012-11-12 00:00:00 2013-01-11 00:00:00        totaljobs.com
# 20656    81000 2013-05-22 15:00:00 2013-06-21 15:00:00         cwjobs.co.uk
# 22043    18720 2013-02-24 15:00:00 2013-03-26 15:00:00         cwjobs.co.uk
# 22927    25000 2012-10-21 00:00:00 2012-11-20 00:00:00          caterer.com
# 23913    25000 2012-10-02 15:00:00 2012-12-01 15:00:00          caterer.com
# 24079    25386 2013-12-08 00:00:00 2014-01-07 00:00:00          caterer.com
# 24727    38000 2012-01-27 12:00:00 2012-03-27 12:00:00          caterer.com
# 34237    30000 2012-05-13 00:00:00 2012-06-12 00:00:00  jobs.guardian.co.uk
# 34327    42500 2012-05-02 15:00:00 2012-06-01 15:00:00  jobs.guardian.co.uk
# 34920    37500 2012-04-23 12:00:00 2012-07-22 12:00:00    planetrecruit.com
# 35484    40500 2012-11-30 15:00:00 2012-12-30 15:00:00    planetrecruit.com
# 39721      NaN 2012-08-28 00:00:00 2012-11-26 00:00:00       Jobcentre Plus
# 40414    19200 2012-06-08 12:00:00 2012-09-06 12:00:00       Jobcentre Plus
# 40561    17500 2012-06-05 15:00:00 2012-09-03 15:00:00       Jobcentre Plus
# 44140    80000 2012-09-05 15:00:00 2012-11-04 15:00:00    eFinancialCareers
# 46954  19000.0 2012-02-07 15:00:00 2012-04-07 15:00:00    careerbuilder.com
# 50229    42500 2013-05-13 00:00:00 2013-06-12 00:00:00     emptylemon.co.uk

# %% [markdown]
# From the output above, all remaining companies with '&' seems to be correct. Thus, they are kept as is

# %%
colon_company = df['Company'].str.contains(r':')
valid_company = df['Company'].str.fullmatch(r'([a-zA-Z0-9]\s?)+')
amp_company = df['Company'].str.contains(r'&')
df[~valid_company & ~non_specified & ~colon_company&~amp_company]['Company']
# Out:
# 7904                               C.O.A.L IT Services Ltd
# 8025                               C.O.A.L IT Services Ltd
# 8044                            Digital Guru's Recruitment
# 8075                               C.O.A.L IT Services Ltd
# 8076                               C.O.A.L IT Services Ltd
#                                ...
# 49798                           Queen's University Belfast
# 49804                                King's College London
# 50137    The Chartered Institution of Wastes Management...
# 50199            Guy's and St Thomas' NHS Foundation Trust
# 50460                           Sotheby's Institute of Art
# Name: Company, Length: 380, dtype: object

# %% [markdown]
# Now, let's check the values with "'"s

# %%
apro_company = df['Company'].str.contains("\'")
df[apro_company]
# Out:
#              Id                                              Title  \
# 8044   72161182                         Senior Build Engineer Lead
# 10169  70320456  Advanced Nurse Practitioner Primary & Physical...
# 12298  68061830                      Mortgage & Protection Advisor
# 12685  69168873                             Client Insight Manager
# 12796  68061810  Cemap Protection Consultant  Rushden, Northamp...
# ...         ...                                                ...
# 49727  71743454                          Registry Office Assistant
# 49798  68587485         **** Funded Phd Studentships In Psychology
# 49804  69734998                             Acting Deputy Director
# 50199  69587192        Clinical Nurse Specialist  Fetal Cardiology
# 50460  71842647  Accounts Assistant: Purchase Ledger / Credit C...
#
#                Location                                    Company  \
# 8044     Central London                 Digital Guru's Recruitment
# 10169                Uk                     St Andrew's Healthcare
# 12298            Oxford                         O'Neil Consultancy
# 12685            Oxford                         O'Neil Consultancy
# 12796           Rushden                         O'Neil Consultancy
# ...                 ...                                        ...
# 49727            London                           Regent's College
# 49798  Northern Ireland                 Queen's University Belfast
# 49804            London                      King's College London
# 50199            London  Guy's and St Thomas' NHS Foundation Trust
# 50460            London                 Sotheby's Institute of Art
#
#         ContractType   ContractTime                          Category Salary  \
# 8044   non-specified      permanent                           IT Jobs  55000
# 10169  non-specified      permanent         Healthcare & Nursing Jobs    35K
# 12298  non-specified      permanent         Accounting & Finance Jobs  37000
# 12685  non-specified      permanent  PR, Advertising & Marketing Jobs  31500
# 12796  non-specified      permanent         Accounting & Finance Jobs  37500
# ...              ...            ...                               ...    ...
# 49727  non-specified  non-specified                     Teaching Jobs  21000
# 49798  non-specified  non-specified                     Teaching Jobs  13726
# 49804  non-specified  non-specified                     Teaching Jobs  51070
# 50199  non-specified  non-specified         Healthcare & Nursing Jobs  41463
# 50460      full_time      permanent         Accounting & Finance Jobs  23500
#
#                  OpenDate           CloseDate             SourceName
# 8044  2012-02-29 15:00:00 2012-03-30 15:00:00           jobserve.com
# 10169 2013-12-28 15:00:00 2014-01-27 15:00:00            fish4.co.uk
# 12298 2012-07-30 15:00:00 2012-08-29 15:00:00          totaljobs.com
# 12685 2012-02-21 15:00:00 2012-05-21 15:00:00          totaljobs.com
# 12796 2012-07-04 15:00:00 2012-08-03 15:00:00          totaljobs.com
# ...                   ...                 ...                    ...
# 49727 2013-12-23 15:00:00 2014-01-06 15:00:00                Jobs Ac
# 49798 2013-01-30 12:00:00 2013-03-31 12:00:00                Jobs Ac
# 49804 2012-06-24 00:00:00 2012-08-23 00:00:00                Jobs Ac
# 50199 2013-08-25 12:00:00 2013-09-24 12:00:00  rcnbulletinjobs.co.uk
# 50460 2012-02-22 00:00:00 2012-04-22 00:00:00  myjobs.cimaglobal.com
#
# [73 rows x 11 columns]

# %% [markdown]
# From the output above, it seems like these companies are correct. Thus, they are all kept as is

# %%
colon_company = df['Company'].str.contains(r':')
valid_company = df['Company'].str.fullmatch(r'([a-zA-Z0-9]\s?)+')
amp_company = df['Company'].str.contains(r'&')
apro_company = df['Company'].str.contains("\'")
df[~valid_company & ~non_specified & ~colon_company&~amp_company&~apro_company]['Company']
# Out:
# 7904                               C.O.A.L IT Services Ltd
# 8025                               C.O.A.L IT Services Ltd
# 8075                               C.O.A.L IT Services Ltd
# 8076                               C.O.A.L IT Services Ltd
# 8094                                      24/7 Recruitment
#                                ...
# 49389                                           D.P. Group
# 49413                                           D.P. Group
# 49437                                           D.P. Group
# 49449                                           D.P. Group
# 50137    The Chartered Institution of Wastes Management...
# Name: Company, Length: 307, dtype: object

# %% [markdown]
# The last few values contains "."s

# %%
dot_company = df['Company'].str.contains(r'\.')
df[dot_company]
# Out:
#              Id                                              Title  \
# 7904   71774904  Data Administrator  Knowledge/Exp Of Rims And ...
# 8025   68627800       Murex Support Team Leader  Leading Financial
# 8075   71336234  Java Developer/Spring/Hibernate/Github/Jsp/Vel...
# 8076   72161120  Java Developer  Ecommerce Fx/Money Markets Dev...
# 8107   69788055                                   Security Analyst
# ...         ...                                                ...
# 49302  68847270               **** X Service Maintenance Engineers
# 49389  68014633                        Oracle Financials Developer
# 49413  67385052                    Java Developers  Multiple Roles
# 49437  68014632                              Oracle Technical Lead
# 49449  68014930                              Technology Consultant
#
#                                 Location                         Company  \
# 7904                              London         C.O.A.L IT Services Ltd
# 8025                              London         C.O.A.L IT Services Ltd
# 8075                              London         C.O.A.L IT Services Ltd
# 8076                              London         C.O.A.L IT Services Ltd
# 8107   Southampton International Airport         C.O.A.L IT Services Ltd
# ...                                  ...                             ...
# 49302                        West London  Fasttrack Management Serv. Ltd
# 49389                            Belfast                      D.P. Group
# 49413                            Belfast                      D.P. Group
# 49437                            Belfast                      D.P. Group
# 49449                            Belfast                      D.P. Group
#
#         ContractType ContractTime          Category Salary  \
# 7904   non-specified     contract           IT Jobs  35000
# 8025   non-specified    permanent           IT Jobs  90000
# 8075   non-specified    permanent           IT Jobs  55000
# 8076   non-specified    permanent           IT Jobs  65000
# 8107   non-specified    permanent           IT Jobs  45000
# ...              ...          ...               ...    ...
# 49302  non-specified    permanent  Engineering Jobs  25000
# 49389      full_time    permanent           IT Jobs  40000
# 49413      full_time    permanent           IT Jobs    NaN
# 49437      full_time    permanent           IT Jobs  50000
# 49449      full_time    permanent           IT Jobs  52500
#
#                  OpenDate           CloseDate        SourceName
# 7904  2012-04-13 15:00:00 2012-04-27 15:00:00      jobserve.com
# 8025  2012-01-04 00:00:00 2012-03-04 00:00:00      jobserve.com
# 8075  2013-07-18 00:00:00 2013-10-16 00:00:00      jobserve.com
# 8076  2012-01-06 15:00:00 2012-04-05 15:00:00      jobserve.com
# 8107  2013-09-24 12:00:00 2013-11-23 12:00:00      jobserve.com
# ...                   ...                 ...               ...
# 49302 2012-03-26 15:00:00 2012-05-25 15:00:00  londonjobs.co.uk
# 49389 2013-03-28 12:00:00 2013-05-27 12:00:00        nijobs.com
# 49413 2013-01-19 15:00:00 2013-04-19 15:00:00        nijobs.com
# 49437 2012-04-26 12:00:00 2012-07-25 12:00:00        nijobs.com
# 49449 2013-05-11 15:00:00 2013-07-10 15:00:00        nijobs.com
#
# [127 rows x 11 columns]

# %% [markdown]
# Let's check out some of the values

# %%
coal = df['Company'].str.contains(r'C\.?O\.?A\.?L')
df[coal]
# Out:
#              Id                                              Title  \
# 7904   71774904  Data Administrator  Knowledge/Exp Of Rims And ...
# 8025   68627800       Murex Support Team Leader  Leading Financial
# 8075   71336234  Java Developer/Spring/Hibernate/Github/Jsp/Vel...
# 8076   72161120  Java Developer  Ecommerce Fx/Money Markets Dev...
# 8107   69788055                                   Security Analyst
# 8259   71335526  Java Programmer/Java Developer (Market Data An...
# 8265   72160560                       Business Systems Analyst Uml
# 8280   70622221  Unix Technical Support Engineer  Worldwide Sof...
# 8378   68496467     Senior Ui Developer/Ruby/Html5/Css3/Javascript
# 8630   68628549  Linux/Windows Support Engineer  Cambridge  ***...
# 8701   72161340  Application Packager (Appv Or Landesk Or Sscm ...
# 8756   72160627  Enterprise Applications Solutions Architect  T...
# 8811   71594722  Presales Consultant/Sales Engineer  Hp Server/...
# 8902   72372697  Senior Front End Developer  Javascript/Html5/Css3
# 8938   68627579                        Senior Application Packager
# 8991   72160434      Senior Project Manager  Bristol  **** To ****
# 8997   71335814  Technical Support Engineer  Systems Administra...
# 9065   66979498  Solution Architect/Digital/Ui/Html/Java/Agile/...
# 9276   71774963  Etl Support Specialist  Datastage Etl **** And...
# 9310   68627845  Php Web Developer  Facebook Api  London  ****K...
# 9368   68627870                  Graduate Sql Developer/2Nd Jobber
# 9391   72160542  Intranet/Microsoft Specialist  Net/Sharepoint ...
# 9526   71227558               Application Developer  Web Front End
# 29616  71856468  Ux Designer / Researcher  French / German Spea...
# 29619  71226494                             Project Manager  Kofax
# 29828  71706960                     Tester  Qtp / Selenium / Agile
# 30050  68375420    Linux Support Engineer  Cambridge  ****K  Bonus
# 30118  68805864  Solution Architect / Digital / Ui / Html / Jav...
# 30157  69669743  Scrum Master / Agile / Digital / Product Devel...
# 30182  67947053  Project Manager  Infrastructure / Network / Vi...
# 30188  68346635         Project Manager Implementation Exp / Agile
# 30617  69849223  Linux Engineer / Devops Engineer / Amazon Web ...
# 31001  68806111  Systems Analyst (Workflow  Bpm)  London  **** ...
# 31029  68182060                    2Nd / 3Rd Line Systems Engineer
# 31428  68346791   Php Web Developer London  ****K  Bonus  Benefits
# 31538  67946108     Project Manager  It / Network / Virtualisation
# 31629  71857015             Web Designer  Html / Css / Adobe / Seo
# 31640  71855997  Web Developer  Front End  Cms Development  12 ...
# 31796  69688141           Junior Designer Must Be Russian Speaking
# 31911  69686928              Application Packager 3 Month Contract
# 31964  71685571           Vb Software Developers / Vbnet / C / Sql
# 32242  72695764                    Unix Technical Support Engineer
# 32418  71685838                              Sql Reporting Analyst
# 32438  68805845    Sharepoint 2010 Consultant  ****K  Car  Reading
# 32452  72688669          Voice Recording / Voip Recording Engineer
# 32497  72695677          Business Analyst  / Use Cases / Financial
# 32503  71895322                C / Net Developer  Composition Data
# 32619  71856092     Project Manager  Applications / Web / Software
# 41737  68077000  Administration Officer/Assistant  Financial Se...
# 46290  68028519                   Service Delivery Account Manager
# 46308  66665135     Senior Sharepoint Developer/Analyst Programmer
# 46430  71842674  C Senior Developer  Hedge Fund/Investment Mana...
#
#                                 Location                   Company  \
# 7904                              London   C.O.A.L IT Services Ltd
# 8025                              London   C.O.A.L IT Services Ltd
# 8075                              London   C.O.A.L IT Services Ltd
# 8076                              London   C.O.A.L IT Services Ltd
# 8107   Southampton International Airport   C.O.A.L IT Services Ltd
# 8259                              London   C.O.A.L IT Services Ltd
# 8265                              London   C.O.A.L IT Services Ltd
# 8280                              Calcot   C.O.A.L IT Services Ltd
# 8378                              London   C.O.A.L IT Services Ltd
# 8630                  Little Chesterford   C.O.A.L IT Services Ltd
# 8701                           Weybridge   C.O.A.L IT Services Ltd
# 8756                              London   C.O.A.L IT Services Ltd
# 8811                              London   C.O.A.L IT Services Ltd
# 8902                              London   C.O.A.L IT Services Ltd
# 8938   Southampton International Airport   C.O.A.L IT Services Ltd
# 8991                           West Town   C.O.A.L IT Services Ltd
# 8997                              Calcot   C.O.A.L IT Services Ltd
# 9065                              London   C.O.A.L IT Services Ltd
# 9276             Manchester Science Park   C.O.A.L IT Services Ltd
# 9310                              London   C.O.A.L IT Services Ltd
# 9368                              London   C.O.A.L IT Services Ltd
# 9391            Yorkshire And Humberside   C.O.A.L IT Services Ltd
# 9526                                  Uk   C.O.A.L IT Services Ltd
# 29616                             London  C.O.A.L IT. Services Ltd
# 29619                                 Uk  C.O.A.L IT. Services Ltd
# 29828                                 Uk  C.O.A.L IT. Services Ltd
# 30050                          Cambridge  C.O.A.L IT. Services Ltd
# 30118                             London  C.O.A.L IT. Services Ltd
# 30157                             London  C.O.A.L IT. Services Ltd
# 30182                             London  C.O.A.L IT. Services Ltd
# 30188                             London  C.O.A.L IT. Services Ltd
# 30617                             London  C.O.A.L IT. Services Ltd
# 31001                             London  C.O.A.L IT. Services Ltd
# 31029                          Hampshire  C.O.A.L IT. Services Ltd
# 31428                             London  C.O.A.L IT. Services Ltd
# 31538                             London  C.O.A.L IT. Services Ltd
# 31629                           Worthing  C.O.A.L IT. Services Ltd
# 31640                             London  C.O.A.L IT. Services Ltd
# 31796                             London  C.O.A.L IT. Services Ltd
# 31911                                 Uk  C.O.A.L IT. Services Ltd
# 31964                           Richmond  C.O.A.L IT. Services Ltd
# 32242                                 Uk  C.O.A.L IT. Services Ltd
# 32418                             London  C.O.A.L IT. Services Ltd
# 32438                            Reading  C.O.A.L IT. Services Ltd
# 32452                             London  C.O.A.L IT. Services Ltd
# 32497                                 Uk  C.O.A.L IT. Services Ltd
# 32503                              Luton  C.O.A.L IT. Services Ltd
# 32619                                 Uk  C.O.A.L IT. Services Ltd
# 41737                          Hampshire   C.O.A.L IT Services Ltd
# 46290                       Bedfordshire   C.O.A.L IT Services Ltd
# 46308                     Central London   C.O.A.L IT Services Ltd
# 46430                     Central London   C.O.A.L IT Services Ltd
#
#         ContractType ContractTime                   Category Salary  \
# 7904   non-specified     contract                    IT Jobs  35000
# 8025   non-specified    permanent                    IT Jobs  90000
# 8075   non-specified    permanent                    IT Jobs  55000
# 8076   non-specified    permanent                    IT Jobs  65000
# 8107   non-specified    permanent                    IT Jobs  45000
# 8259   non-specified    permanent                    IT Jobs  40000
# 8265   non-specified    permanent                    IT Jobs  50000
# 8280   non-specified    permanent                    IT Jobs  40000
# 8378   non-specified    permanent                    IT Jobs  57500
# 8630   non-specified    permanent                    IT Jobs  32500
# 8701   non-specified    permanent                    IT Jobs  37500
# 8756   non-specified    permanent                    IT Jobs  72500
# 8811   non-specified    permanent                    IT Jobs  60000
# 8902   non-specified    permanent                    IT Jobs  52500
# 8938   non-specified    permanent                    IT Jobs  40000
# 8991   non-specified    permanent                    IT Jobs  55000
# 8997   non-specified    permanent                    IT Jobs  35000
# 9065   non-specified    permanent                    IT Jobs  67500
# 9276   non-specified    permanent                    IT Jobs  37000
# 9310   non-specified    permanent                    IT Jobs  37500
# 9368   non-specified    permanent                    IT Jobs  27000
# 9391   non-specified    permanent                    IT Jobs  40000
# 9526   non-specified    permanent                    IT Jobs  40000
# 29616  non-specified    permanent                    IT Jobs    NaN
# 29619  non-specified     contract                    IT Jobs  84000
# 29828  non-specified     contract                    IT Jobs  90000
# 30050  non-specified    permanent                    IT Jobs  32500
# 30118  non-specified    permanent                    IT Jobs  67500
# 30157  non-specified    permanent                    IT Jobs  60000
# 30182  non-specified    permanent                    IT Jobs  55000
# 30188  non-specified    permanent                    IT Jobs  50000
# 30617  non-specified    permanent                    IT Jobs  62500
# 31001  non-specified    permanent                    IT Jobs  52500
# 31029  non-specified    permanent                    IT Jobs  27000
# 31428  non-specified    permanent                    IT Jobs  37500
# 31538  non-specified     contract                    IT Jobs  90000
# 31629  non-specified    permanent                    IT Jobs  32500
# 31640  non-specified     contract                    IT Jobs  72000
# 31796  non-specified    permanent                    IT Jobs  24000
# 31911  non-specified     contract                    IT Jobs  62400
# 31964  non-specified    permanent                    IT Jobs  37000
# 32242  non-specified    permanent                    IT Jobs  40000
# 32418  non-specified    permanent                    IT Jobs  30000
# 32438  non-specified    permanent                    IT Jobs    NaN
# 32452  non-specified     contract                    IT Jobs  69000
# 32497  non-specified    permanent                    IT Jobs  50000
# 32503  non-specified    permanent                    IT Jobs  38000
# 32619  non-specified    permanent                    IT Jobs  57500
# 41737      full_time    permanent  Accounting & Finance Jobs  17000
# 46290      full_time    permanent                 Sales Jobs  35000
# 46308      full_time    permanent                    IT Jobs  52500
# 46430      full_time    permanent                    IT Jobs  90000
#
#                  OpenDate           CloseDate                SourceName
# 7904  2012-04-13 15:00:00 2012-04-27 15:00:00              jobserve.com
# 8025  2012-01-04 00:00:00 2012-03-04 00:00:00              jobserve.com
# 8075  2013-07-18 00:00:00 2013-10-16 00:00:00              jobserve.com
# 8076  2012-01-06 15:00:00 2012-04-05 15:00:00              jobserve.com
# 8107  2013-09-24 12:00:00 2013-11-23 12:00:00              jobserve.com
# 8259  2013-03-27 12:00:00 2013-06-25 12:00:00              jobserve.com
# 8265  2012-05-07 12:00:00 2012-07-06 12:00:00              jobserve.com
# 8280  2013-04-16 12:00:00 2013-07-15 12:00:00              jobserve.com
# 8378  2012-09-15 15:00:00 2012-10-15 15:00:00              jobserve.com
# 8630  2013-04-02 00:00:00 2013-06-01 00:00:00              jobserve.com
# 8701  2013-10-14 15:00:00 2013-11-13 15:00:00              jobserve.com
# 8756  2012-09-17 15:00:00 2012-12-16 15:00:00              jobserve.com
# 8811  2013-06-27 00:00:00 2013-07-27 00:00:00              jobserve.com
# 8902  2013-06-22 15:00:00 2013-07-22 15:00:00              jobserve.com
# 8938  2013-02-19 12:00:00 2013-05-20 12:00:00              jobserve.com
# 8991  2013-06-25 15:00:00 2013-08-24 15:00:00              jobserve.com
# 8997  2013-07-27 00:00:00 2013-09-25 00:00:00              jobserve.com
# 9065  2013-07-21 12:00:00 2013-09-19 12:00:00              jobserve.com
# 9276  2013-03-21 00:00:00 2013-04-20 00:00:00              jobserve.com
# 9310  2012-03-07 12:00:00 2012-06-05 12:00:00              jobserve.com
# 9368  2012-10-07 00:00:00 2012-12-06 00:00:00              jobserve.com
# 9391  2013-12-12 00:00:00 2014-03-12 00:00:00              jobserve.com
# 9526  2012-02-16 00:00:00 2012-05-16 00:00:00               fish4.co.uk
# 29616 2013-11-05 00:00:00 2014-01-04 00:00:00             jobsite.co.uk
# 29619 2013-06-07 00:00:00 2013-07-07 00:00:00             jobsite.co.uk
# 29828 2012-01-10 00:00:00 2012-03-10 00:00:00             jobsite.co.uk
# 30050 2013-05-24 12:00:00 2013-07-23 12:00:00             jobsite.co.uk
# 30118 2013-11-14 00:00:00 2014-02-12 00:00:00             jobsite.co.uk
# 30157 2012-05-14 12:00:00 2012-06-13 12:00:00             jobsite.co.uk
# 30182 2013-12-22 12:00:00 2014-03-22 12:00:00             jobsite.co.uk
# 30188 2012-04-10 12:00:00 2012-06-09 12:00:00             jobsite.co.uk
# 30617 2013-08-10 12:00:00 2013-09-09 12:00:00             jobsite.co.uk
# 31001 2012-08-11 12:00:00 2012-10-10 12:00:00             jobsite.co.uk
# 31029 2012-07-17 12:00:00 2012-09-15 12:00:00             jobsite.co.uk
# 31428 2012-11-28 00:00:00 2013-02-26 00:00:00             jobsite.co.uk
# 31538 2012-04-27 15:00:00 2012-05-11 15:00:00             jobsite.co.uk
# 31629 2013-10-21 00:00:00 2013-11-20 00:00:00             jobsite.co.uk
# 31640 2012-08-08 15:00:00 2012-08-22 15:00:00             jobsite.co.uk
# 31796 2013-12-15 15:00:00 2014-01-14 15:00:00             jobsite.co.uk
# 31911 2012-06-15 00:00:00 2012-06-29 00:00:00             jobsite.co.uk
# 31964 2012-05-17 00:00:00 2012-08-15 00:00:00             jobsite.co.uk
# 32242 2013-02-01 15:00:00 2013-05-02 15:00:00             jobsite.co.uk
# 32418 2012-07-25 15:00:00 2012-08-24 15:00:00             jobsite.co.uk
# 32438 2012-02-17 12:00:00 2012-04-17 12:00:00             jobsite.co.uk
# 32452 2013-03-04 15:00:00 2013-03-18 15:00:00             jobsite.co.uk
# 32497 2013-12-28 15:00:00 2014-03-28 15:00:00             jobsite.co.uk
# 32503 2012-04-19 12:00:00 2012-05-19 12:00:00             jobsite.co.uk
# 32619 2013-05-06 15:00:00 2013-07-05 15:00:00             jobsite.co.uk
# 41737 2012-08-08 12:00:00 2012-10-07 12:00:00  energygenerationjobs.com
# 46290 2013-06-28 00:00:00 2013-08-27 00:00:00     jobs.newstatesman.com
# 46308 2013-10-16 15:00:00 2014-01-14 15:00:00     jobs.newstatesman.com
# 46430 2012-05-26 15:00:00 2012-06-25 15:00:00     jobs.newstatesman.com

# %%
dp = df['Company'].str.contains(r'D\.?P\.')
df[dp]
# Out:
#              Id                            Title Location     Company  \
# 49389  68014633      Oracle Financials Developer  Belfast  D.P. Group
# 49413  67385052  Java Developers  Multiple Roles  Belfast  D.P. Group
# 49437  68014632            Oracle Technical Lead  Belfast  D.P. Group
# 49449  68014930            Technology Consultant  Belfast  D.P. Group
#
#       ContractType ContractTime Category Salary            OpenDate  \
# 49389    full_time    permanent  IT Jobs  40000 2013-03-28 12:00:00
# 49413    full_time    permanent  IT Jobs    NaN 2013-01-19 15:00:00
# 49437    full_time    permanent  IT Jobs  50000 2012-04-26 12:00:00
# 49449    full_time    permanent  IT Jobs  52500 2013-05-11 15:00:00
#
#                 CloseDate  SourceName
# 49389 2013-05-27 12:00:00  nijobs.com
# 49413 2013-04-19 15:00:00  nijobs.com
# 49437 2012-07-25 12:00:00  nijobs.com
# 49449 2013-07-10 15:00:00  nijobs.com

# %% [markdown]
# These companies seems to be legitimate. However, there is a 'Serv.' value there.

# %%
serv = df['Company'].str.contains(r'[sS]erv?\.')
df[serv]
# Out:
#              Id                                 Title      Location  \
# 49246  68847157         Installation Service Engineer  North London
# 49302  68847270  **** X Service Maintenance Engineers   West London
#
#                               Company   ContractType ContractTime  \
# 49246  Fasttrack Management Serv. Ltd  non-specified    permanent
# 49302  Fasttrack Management Serv. Ltd  non-specified    permanent
#
#                Category Salary            OpenDate           CloseDate  \
# 49246  Engineering Jobs  28000 2013-03-18 12:00:00 2013-06-16 12:00:00
# 49302  Engineering Jobs  25000 2012-03-26 15:00:00 2012-05-25 15:00:00
#
#              SourceName
# 49246  londonjobs.co.uk
# 49302  londonjobs.co.uk

# %% [markdown]
# Serv seems to be a short form for Services

# %%
services = df['Company'].str.contains(r'[sS]ervices')
df[services]
# Out:
#              Id                                              Title  \
# 78     68544566                          Site Supervisor (M Amp;E)
# 246    71196065  Intermediate Estimator (Rc Frame And Groundworks)
# 281    68805113                      Estimator (Fit Out  Interior)
# 317    67286147                   Project Manager (Pqs Background)
# 344    71196096      Project Manager (Glass Partitioning Projects)
# ...         ...                                                ...
# 50602  70086304         Senior Financial Planner (Private Banking)
# 50613  68511180     Senior Professional Practice Financial Planner
# 50615  68511172                           Junior Financial Planner
# 50621  72169211         E, C Amp; I Maintenance Technician  C****K
# 50689  72162924                       Process Engineer  All Levels
#
#                   Location                            Company   ContractType  \
# 78                    Kent                 Calco Services Ltd  non-specified
# 246           North London                 Calco Services Ltd  non-specified
# 281                 London                 Calco Services Ltd  non-specified
# 317                 London                 Calco Services Ltd  non-specified
# 344        Buckinghamshire                 Calco Services Ltd  non-specified
# ...                    ...                                ...            ...
# 50602               London  Hanover Search Financial Services  non-specified
# 50613            Berkshire  Hanover Search Financial Services  non-specified
# 50615       Central London  Hanover Search Financial Services  non-specified
# 50621  Marton-In-Cleveland            Support Services Group       full_time
# 50689               Surrey     Executive Recruitment Services      full_time
#
#       ContractTime                   Category Salary            OpenDate  \
# 78       permanent           Engineering Jobs  32000 2012-09-02 00:00:00
# 246      permanent           Engineering Jobs  20000 2013-05-21 12:00:00
# 281      permanent           Engineering Jobs  50000 2013-11-22 00:00:00
# 317      permanent           Engineering Jobs  60000 2012-10-13 15:00:00
# 344      permanent           Engineering Jobs  50000 2013-04-12 15:00:00
# ...            ...                        ...    ...                 ...
# 50602    permanent  Accounting & Finance Jobs  70000 2012-03-13 12:00:00
# 50613    permanent  Accounting & Finance Jobs  37500 2013-01-31 00:00:00
# 50615    permanent  Accounting & Finance Jobs  50000 2013-11-05 12:00:00
# 50621    permanent  Accounting & Finance Jobs  27250 2013-08-22 00:00:00
# 50689    permanent           Engineering Jobs  47500 2012-03-09 15:00:00
#
#                 CloseDate            SourceName
# 78    2012-11-01 00:00:00  rengineeringjobs.com
# 246   2013-08-19 12:00:00  rengineeringjobs.com
# 281   2014-01-21 00:00:00  rengineeringjobs.com
# 317   2012-12-12 15:00:00  rengineeringjobs.com
# 344   2013-05-12 15:00:00  rengineeringjobs.com
# ...                   ...                   ...
# 50602 2012-04-12 12:00:00   ifaonlinejobs.co.uk
# 50613 2013-04-01 00:00:00   ifaonlinejobs.co.uk
# 50615 2013-12-05 12:00:00   ifaonlinejobs.co.uk
# 50621 2013-11-20 00:00:00     jobsfinancial.com
# 50689 2012-06-07 15:00:00           TotallyExec
#
# [1090 rows x 11 columns]

# %% [markdown]
# Thus, these 2 values would be converted to Services

# %%
indices = list(df[serv].index)
for ind in indices:
    company = df['Company'][ind].replace('Serv.','Services')
    # Add to error Dict
    errorDict = addToErrorDict(errorDict,ind,df['Id'][ind],'Company',df['Company'][ind],company,'Short form of a word exists','Convert to actual form')
    # Replace the values with Serv. changed to Services
    df.loc[ind,'Company'] = company
df[serv]
# Out:
#              Id                                 Title      Location  \
# 49246  68847157         Installation Service Engineer  North London
# 49302  68847270  **** X Service Maintenance Engineers   West London
#
#                                  Company   ContractType ContractTime  \
# 49246  Fasttrack Management Services Ltd  non-specified    permanent
# 49302  Fasttrack Management Services Ltd  non-specified    permanent
#
#                Category Salary            OpenDate           CloseDate  \
# 49246  Engineering Jobs  28000 2013-03-18 12:00:00 2013-06-16 12:00:00
# 49302  Engineering Jobs  25000 2012-03-26 15:00:00 2012-05-25 15:00:00
#
#              SourceName
# 49246  londonjobs.co.uk
# 49302  londonjobs.co.uk

# %% [markdown]
# Continue our checking for "."

# %%
dot_company = df['Company'].str.contains(r'\.')
df[dot_company&~coal&~dp]
# Out:
#              Id                                              Title  \
# 8128   71593642  Oracle Hr Functional Consultant/Oracle Ebusine...
# 8271   71774481  Database Technical Analyst (Ms Access, Sql, Or...
# 9050   68627684               Oracle Hr Functional Support Analyst
# 9085   69574473  C Net Developer (Python, Scrum, Agile, Ibm Web...
# 9160   68628028  Boxi/Informatica Team Lead  London City  To ****K
# ...         ...                                                ...
# 43315  72627084       Relationship / Sales Executive  Multilingual
# 43328  72394874                      Risk Manager  Consumer Credit
# 43346  68063261             Compliance Monitoring Manager  Banking
# 43386  71356473              Senior Operational Risk Analyst (Avp)
# 43461  69122468                           Client Reporting Analyst
#
#              Location                                            Company  \
# 8128        Wiltshire  Sand Resources. A division of InterQuest Group...
# 8271         Solihull                                 Next Move I.T. Ltd
# 9050        Wiltshire  Sand Resources. A division of InterQuest Group...
# 9085          Coscote  Sand Resources. A division of InterQuest Group...
# 9160   Central London                        Deerfoot I.T. Resources Ltd
# ...               ...                                                ...
# 43315          London                             C.K.R. Recruitment Ltd
# 43328     West Sussex                             C.K.R. Recruitment Ltd
# 43346        The City                             C.K.R. Recruitment Ltd
# 43386          London                             C.K.R. Recruitment Ltd
# 43461        The City                             C.K.R. Recruitment Ltd
#
#         ContractType ContractTime                          Category Salary  \
# 8128   non-specified    permanent                           IT Jobs  45000
# 8271   non-specified    permanent                           IT Jobs  30000
# 9050   non-specified    permanent                           IT Jobs  34000
# 9085   non-specified     contract                           IT Jobs  32500
# 9160   non-specified    permanent                           IT Jobs  75000
# ...              ...          ...                               ...    ...
# 43315  non-specified    permanent  PR, Advertising & Marketing Jobs  30000
# 43328  non-specified    permanent         Accounting & Finance Jobs  57500
# 43346  non-specified    permanent         Accounting & Finance Jobs  75000
# 43386  non-specified    permanent         Accounting & Finance Jobs  45000
# 43461  non-specified    permanent         Accounting & Finance Jobs  42500
#
#                  OpenDate           CloseDate    SourceName
# 8128  2013-07-22 12:00:00 2013-10-20 12:00:00  jobserve.com
# 8271  2013-08-22 00:00:00 2013-11-20 00:00:00  jobserve.com
# 9050  2013-03-26 12:00:00 2013-05-25 12:00:00  jobserve.com
# 9085  2013-05-17 12:00:00 2013-07-16 12:00:00  jobserve.com
# 9160  2012-10-03 12:00:00 2013-01-01 12:00:00  jobserve.com
# ...                   ...                 ...           ...
# 43315 2013-10-03 00:00:00 2014-01-01 00:00:00  cityjobs.com
# 43328 2013-08-24 12:00:00 2013-11-22 12:00:00  cityjobs.com
# 43346 2012-08-29 00:00:00 2012-11-27 00:00:00  cityjobs.com
# 43386 2012-08-24 12:00:00 2012-10-23 12:00:00  cityjobs.com
# 43461 2012-05-14 15:00:00 2012-07-13 15:00:00  cityjobs.com
#
# [69 rows x 11 columns]

# %%
ckr = df['Company'].str.contains(r'C\.?K\.?R\.?')
df[ckr]
# Out:
#              Id                                              Title  \
# 43239  72194600  Senior Manager, Operational Risk (612 Month Co...
# 43315  72627084       Relationship / Sales Executive  Multilingual
# 43328  72394874                      Risk Manager  Consumer Credit
# 43346  68063261             Compliance Monitoring Manager  Banking
# 43386  71356473              Senior Operational Risk Analyst (Avp)
# 43461  69122468                           Client Reporting Analyst
#
#           Location                 Company   ContractType ContractTime  \
# 43239     The City  C.K.R. Recruitment Ltd  non-specified     contract
# 43315       London  C.K.R. Recruitment Ltd  non-specified    permanent
# 43328  West Sussex  C.K.R. Recruitment Ltd  non-specified    permanent
# 43346     The City  C.K.R. Recruitment Ltd  non-specified    permanent
# 43386       London  C.K.R. Recruitment Ltd  non-specified    permanent
# 43461     The City  C.K.R. Recruitment Ltd  non-specified    permanent
#
#                                Category Salary            OpenDate  \
# 43239         Accounting & Finance Jobs  56000 2012-03-17 15:00:00
# 43315  PR, Advertising & Marketing Jobs  30000 2013-10-03 00:00:00
# 43328         Accounting & Finance Jobs  57500 2013-08-24 12:00:00
# 43346         Accounting & Finance Jobs  75000 2012-08-29 00:00:00
# 43386         Accounting & Finance Jobs  45000 2012-08-24 12:00:00
# 43461         Accounting & Finance Jobs  42500 2012-05-14 15:00:00
#
#                 CloseDate    SourceName
# 43239 2012-04-16 15:00:00  cityjobs.com
# 43315 2014-01-01 00:00:00  cityjobs.com
# 43328 2013-11-22 12:00:00  cityjobs.com
# 43346 2012-11-27 00:00:00  cityjobs.com
# 43386 2012-10-23 12:00:00  cityjobs.com
# 43461 2012-07-13 15:00:00  cityjobs.com

# %% [markdown]
# The CKR company seems to be valid as well

# %%
dot_company = df['Company'].str.contains(r'\.')
df[dot_company&~coal&~dp&~ckr]
# Out:
#              Id                                              Title  \
# 8128   71593642  Oracle Hr Functional Consultant/Oracle Ebusine...
# 8271   71774481  Database Technical Analyst (Ms Access, Sql, Or...
# 9050   68627684               Oracle Hr Functional Support Analyst
# 9085   69574473  C Net Developer (Python, Scrum, Agile, Ibm Web...
# 9160   68628028  Boxi/Informatica Team Lead  London City  To ****K
# ...         ...                                                ...
# 40872  68446046                    Baby Room Practitioner  Col****
# 40928  67447764            National Training & Development Manager
# 40929  66750270                            Home Support Assistants
# 40986  69150243  Gas Technical Engineer (Breakdown And Repair) ...
# 41034  69554855                                 Learning Assistant
#
#              Location                                            Company  \
# 8128        Wiltshire  Sand Resources. A division of InterQuest Group...
# 8271         Solihull                                 Next Move I.T. Ltd
# 9050        Wiltshire  Sand Resources. A division of InterQuest Group...
# 9085          Coscote  Sand Resources. A division of InterQuest Group...
# 9160   Central London                        Deerfoot I.T. Resources Ltd
# ...               ...                                                ...
# 40872      Colchester                                   www.essex eyjobs
# 40928   Milton Keynes                        B.S.H. Home Applicances Ltd
# 40929   North Shields                  At Home with...Helen McArdle Care
# 40986      Birmingham                                        E.on UK Plc
# 41034      Birmingham             St. Paul's Community Development Trust
#
#         ContractType   ContractTime                   Category Salary  \
# 8128   non-specified      permanent                    IT Jobs  45000
# 8271   non-specified      permanent                    IT Jobs  30000
# 9050   non-specified      permanent                    IT Jobs  34000
# 9085   non-specified       contract                    IT Jobs  32500
# 9160   non-specified      permanent                    IT Jobs  75000
# ...              ...            ...                        ...    ...
# 40872      full_time  non-specified              Teaching Jobs  13440
# 40928      full_time  non-specified              Teaching Jobs  30000
# 40929      full_time  non-specified  Healthcare & Nursing Jobs  14976
# 40986      full_time  non-specified           Engineering Jobs  34760
# 41034      full_time  non-specified              Teaching Jobs    NaN
#
#                  OpenDate           CloseDate      SourceName
# 8128  2013-07-22 12:00:00 2013-10-20 12:00:00    jobserve.com
# 8271  2013-08-22 00:00:00 2013-11-20 00:00:00    jobserve.com
# 9050  2013-03-26 12:00:00 2013-05-25 12:00:00    jobserve.com
# 9085  2013-05-17 12:00:00 2013-07-16 12:00:00    jobserve.com
# 9160  2012-10-03 12:00:00 2013-01-01 12:00:00    jobserve.com
# ...                   ...                 ...             ...
# 40872 2012-05-03 00:00:00 2012-08-01 00:00:00  Jobcentre Plus
# 40928 2012-12-12 00:00:00 2013-02-10 00:00:00  Jobcentre Plus
# 40929 2013-08-22 15:00:00 2013-09-21 15:00:00  Jobcentre Plus
# 40986 2013-07-16 00:00:00 2013-08-15 00:00:00  Jobcentre Plus
# 41034 2012-01-29 00:00:00 2012-04-28 00:00:00  Jobcentre Plus
#
# [63 rows x 11 columns]

# %% [markdown]
# Let's check for title that contains the word 'I.T.'

# %%
# Get companies containing the word IT, with or without .s
it = df['Company'].str.contains(r'\b[Ii]\.?[Tt]\.?\b')
df[it]
# Out:
#              Id                                              Title  \
# 858    70607960  Overhead Electrical Lineworkervictoria, Austra...
# 895    68356718                              Data Security Analyst
# 948    69541291                        Junior Service Desk Analyst
# 951    72546752  Php Developer / Lamp Developer  Web And Cloud ...
# 1421   69083921  Project Manager  Automation / Dudley / **** **...
# ...         ...                                                ...
# 50690  72579026    French Speaking Regional Sales Manager  Uk Base
# 50717  68538223                  Senior Configuration Manager ****
# 50719  69181411    Senior Business Analystdebt Financereading****K
# 50728  68538232                  Perl Developer  Portsmouth  ****K
# 50731  71802810          Ui Developer Mediawest London****Kpackage
#
#                 Location                    Company   ContractType  \
# 858                   Uk       Ccity IT Recruitment  non-specified
# 895       Cambridgeshire       Pytec IT Recruitment  non-specified
# 948            Cambridge  Deerfoot IT Resources Ltd  non-specified
# 951             Brighton         Arc IT Recruitment  non-specified
# 1421              London                 Concept IT  non-specified
# ...                  ...                        ...            ...
# 50690  South East London   IT Executive Recruitment      full_time
# 50717             London            Rullion IT Plus  non-specified
# 50719                 Uk            Rullion IT Plus  non-specified
# 50728                 Uk            Rullion IT Plus  non-specified
# 50731             London            Rullion IT Plus  non-specified
#
#       ContractTime                   Category   Salary            OpenDate  \
# 858      permanent           Engineering Jobs    57500 2013-01-08 00:00:00
# 895      permanent                    IT Jobs    35000 2013-11-25 00:00:00
# 948      permanent                    IT Jobs    23000 2013-09-10 12:00:00
# 951      permanent                    IT Jobs    30000 2013-09-03 15:00:00
# 1421      contract           Engineering Jobs    52800 2013-03-30 12:00:00
# ...            ...                        ...      ...                 ...
# 50690    permanent                    IT Jobs    60011 2013-04-19 00:00:00
# 50717    permanent  Accounting & Finance Jobs  60000.0 2013-03-27 15:00:00
# 50719    permanent  Accounting & Finance Jobs  65000.0 2013-06-08 15:00:00
# 50728    permanent  Accounting & Finance Jobs  40000.0 2013-04-15 12:00:00
# 50731    permanent  Accounting & Finance Jobs  25000.0 2012-05-20 15:00:00
#
#                 CloseDate              SourceName
# 858   2013-03-09 00:00:00        cv-library.co.uk
# 895   2014-01-24 00:00:00        cv-library.co.uk
# 948   2013-10-10 12:00:00        cv-library.co.uk
# 951   2013-11-02 15:00:00        cv-library.co.uk
# 1421  2013-04-13 12:00:00        cv-library.co.uk
# ...                   ...                     ...
# 50690 2013-05-19 00:00:00             TotallyExec
# 50717 2013-06-25 15:00:00  frontofficebanking.com
# 50719 2013-07-08 15:00:00  frontofficebanking.com
# 50728 2013-06-14 12:00:00  frontofficebanking.com
# 50731 2012-08-18 15:00:00  frontofficebanking.com
#
# [1251 rows x 11 columns]

# %% [markdown]
# It seems like there are multiple variations of IT. All of these would be reformatted to a universal form 'IT'

# %%
it_company = df['Company'].str.contains(r'\b[Ii]\.?[Tt]\.?\b')
indices = list(df[it_company].index)
for ind in indices:
    it_wrd = re.search(r'\s*([Ii]\.*[Tt]\.*)\s*',df['Company'][ind]).groups()[0]
    old = df['Company'][ind]
    # Replace word with IT
    df.loc[ind,'Company'] = df.loc[ind,'Company'].replace(it_wrd,'IT')
    # Add to errorDict
    errorDict = addToErrorDict(errorDict,ind,df['Id'][ind],'Company',old,df['Company'][ind],'Multiple variations of a word','Set to a uniform word')
df[it_company]
# Out:
#              Id                                              Title  \
# 858    70607960  Overhead Electrical Lineworkervictoria, Austra...
# 895    68356718                              Data Security Analyst
# 948    69541291                        Junior Service Desk Analyst
# 951    72546752  Php Developer / Lamp Developer  Web And Cloud ...
# 1421   69083921  Project Manager  Automation / Dudley / **** **...
# ...         ...                                                ...
# 50690  72579026    French Speaking Regional Sales Manager  Uk Base
# 50717  68538223                  Senior Configuration Manager ****
# 50719  69181411    Senior Business Analystdebt Financereading****K
# 50728  68538232                  Perl Developer  Portsmouth  ****K
# 50731  71802810          Ui Developer Mediawest London****Kpackage
#
#                 Location                    Company   ContractType  \
# 858                   Uk       CcITy IT RecruITment  non-specified
# 895       Cambridgeshire       Pytec IT Recruitment  non-specified
# 948            Cambridge  Deerfoot IT Resources Ltd  non-specified
# 951             Brighton         Arc IT Recruitment  non-specified
# 1421              London                 Concept IT  non-specified
# ...                  ...                        ...            ...
# 50690  South East London   IT Executive Recruitment      full_time
# 50717             London            Rullion IT Plus  non-specified
# 50719                 Uk            Rullion IT Plus  non-specified
# 50728                 Uk            Rullion IT Plus  non-specified
# 50731             London            Rullion IT Plus  non-specified
#
#       ContractTime                   Category   Salary            OpenDate  \
# 858      permanent           Engineering Jobs    57500 2013-01-08 00:00:00
# 895      permanent                    IT Jobs    35000 2013-11-25 00:00:00
# 948      permanent                    IT Jobs    23000 2013-09-10 12:00:00
# 951      permanent                    IT Jobs    30000 2013-09-03 15:00:00
# 1421      contract           Engineering Jobs    52800 2013-03-30 12:00:00
# ...            ...                        ...      ...                 ...
# 50690    permanent                    IT Jobs    60011 2013-04-19 00:00:00
# 50717    permanent  Accounting & Finance Jobs  60000.0 2013-03-27 15:00:00
# 50719    permanent  Accounting & Finance Jobs  65000.0 2013-06-08 15:00:00
# 50728    permanent  Accounting & Finance Jobs  40000.0 2013-04-15 12:00:00
# 50731    permanent  Accounting & Finance Jobs  25000.0 2012-05-20 15:00:00
#
#                 CloseDate              SourceName
# 858   2013-03-09 00:00:00        cv-library.co.uk
# 895   2014-01-24 00:00:00        cv-library.co.uk
# 948   2013-10-10 12:00:00        cv-library.co.uk
# 951   2013-11-02 15:00:00        cv-library.co.uk
# 1421  2013-04-13 12:00:00        cv-library.co.uk
# ...                   ...                     ...
# 50690 2013-05-19 00:00:00             TotallyExec
# 50717 2013-06-25 15:00:00  frontofficebanking.com
# 50719 2013-07-08 15:00:00  frontofficebanking.com
# 50728 2013-06-14 12:00:00  frontofficebanking.com
# 50731 2012-08-18 15:00:00  frontofficebanking.com
#
# [1251 rows x 11 columns]

# %% [markdown]
# Now that's done, we continue with our searching

# %%
dot_company = df['Company'].str.contains(r'\.')
df[dot_company&~coal&~dp&~ckr]
# Out:
#              Id                                              Title  \
# 8128   71593642  Oracle Hr Functional Consultant/Oracle Ebusine...
# 9050   68627684               Oracle Hr Functional Support Analyst
# 9085   69574473  C Net Developer (Python, Scrum, Agile, Ibm Web...
# 13231  68693588                           Public Relations Officer
# 15956  72233005     Senior Mechanical Estimator  Building Services
# 23403  68837702                         Bar And Lounge Manager  Br
# 23612  69470872          Group Reservations Executive  Up To ****K
# 23812  71959934    Meeting & Events Sales Manager  Reactive Exeter
# 23862  71276961                      Sous Chef Plus Service Charge
# 27602  66934491  Locum Physiotherapist Required  Central London...
# 27870  71607588      Band 6 Speech And Language Therapists  London
# 28350  71614468                             Surgery Nurse  Norwich
# 29135  72187316   Heath Care Assistant  Immediate Start  Liverpool
# 29285  71093048  Locum Occupational Therapist Required  Gloucester
# 29319  71093010  Locum Band 6 Neuro Speech And Language Therapi...
# 29919  69688264                 Urgently  Requiredtrainee Teachers
# 29998  72479693                                     Safety Advisor
# 30421  69688196                 Trainee Teaching Assistants Needed
# 30682  69688041         Sccd Need Teachers And Teaching Assistants
# 31159  67948117                               Process Metallurgist
# 31860  71685846  Project Manager  Events / Marketing  Macclesfi...
# 31918  69687263                              London Needs Teachers
# 34379  69675549  Hr Manager (Parttime) 3 Days A Week ( Flexi Wo...
# 34780  71885279               Solicitor/ Disciplinary Case Manager
# 35142  68838621                          Software Developer  Devon
# 37242  69188513     No Experience, No Problem New Roles In Bristol
# 38053  68505017     Operations Manager Plus Bonus  Leicester  ****
# 38137  68707250  Assistant Conference And Banqueting Operations...
# 38185  70032108                           Sales Manager  Mice ****
# 38290  69639025                       Restaurant & Bar Manager  Bw
# 38478  69183421                Painter  Ongoing Temp **** Per Hour
# 38654  68505506    Event Operations Manager  **** ****K Plus Bonus
# 39081  68504890      Assistant Director Of Sales  ****K Plus Bonus
# 39249  66537257                                      Kitchen Staff
# 39404  69768265                  Venues & Events Energy Consultant
# 39773  69769276                                     Sen Key Worker
# 39791  69554526                                 Membership Adviser
# 39866  68239749                Nursery Practitioner L****  Ooc****
# 39909  69766368     Software Development Project/Programme Manager
# 39974  69554894                           After School Club Worker
# 40127  69769301                             Preschool Practitioner
# 40420  68450122                      Skilled Senior Care Assistant
# 40620  69554720                            Fitness Service Manager
# 40872  68446046                    Baby Room Practitioner  Col****
# 40928  67447764            National Training & Development Manager
# 40929  66750270                            Home Support Assistants
# 40986  69150243  Gas Technical Engineer (Breakdown And Repair) ...
# 41034  69554855                                 Learning Assistant
#
#                 Location                                            Company  \
# 8128           Wiltshire  Sand Resources. A division of InterQuest Group...
# 9050           Wiltshire  Sand Resources. A division of InterQuest Group...
# 9085             Coscote  Sand Resources. A division of InterQuest Group...
# 13231                 Uk                         St.Marys International Ltd
# 15956   Northamptonshire                                         T.E.D. Ltd
# 23403                 Uk                              K.B.C. Associates Ltd
# 23612  South East London                              K.B.C. Associates Ltd
# 23812             Exeter                              K.B.C. Associates Ltd
# 23862  South East London                              K.B.C. Associates Ltd
# 27602             London                                  D.R.C. Locums Ltd
# 27870             London                                  D.R.C. Locums Ltd
# 28350            Norwich                                  D.R.C. Locums Ltd
# 29135          Liverpool                                  D.R.C. Locums Ltd
# 29285         Gloucester                                  D.R.C. Locums Ltd
# 29319             London                                  D.R.C. Locums Ltd
# 29919             London           Schools Courses Career Development C.I.C
# 29998            Cumbria                                         N.R.L Ltd
# 30421             London           Schools Courses Career Development C.I.C
# 30682             London           Schools Courses Career Development C.I.C
# 31159                 Uk                                 www.dexternicholas
# 31860                 Uk                              C.O.S Recruitment Ltd
# 31918             London           Schools Courses Career Development C.I.C
# 34379             London                            M. ARIA RECRUITMENT Ltd
# 34780             London                            M. ARIA RECRUITMENT Ltd
# 35142              Devon                                         Recruit.UK
# 37242                 Uk                                    HelpMeGo.To Ltd
# 38053          Leicester                              K.B.C. Associates Ltd
# 38137             London                              K.B.C. Associates Ltd
# 38185             London                              K.B.C. Associates Ltd
# 38290          Brentwood                              K.B.C. Associates Ltd
# 38478             London                              K.B.C. Associates Ltd
# 38654             London                              K.B.C. Associates Ltd
# 39081             London                              K.B.C. Associates Ltd
# 39249                 Uk                                   J.D.Wetherspoons
# 39404            Evesham                                        E.on UK Plc
# 39773         Colchester                                   www.essex eyjobs
# 39791        Southampton                                        L.A Fitness
# 39866                Sea                                   www.essex eyjobs
# 39909         Nottingham                                        E.on UK Plc
# 39974         Chelmsford                                   www.essex eyjobs
# 40127         Colchester                                   www.essex eyjobs
# 40420             London  St.marys International Education and Employmen...
# 40620        Southampton                                        L.A Fitness
# 40872         Colchester                                   www.essex eyjobs
# 40928      Milton Keynes                        B.S.H. Home Applicances Ltd
# 40929      North Shields                  At Home with...Helen McArdle Care
# 40986         Birmingham                                        E.on UK Plc
# 41034         Birmingham             St. Paul's Community Development Trust
#
#         ContractType   ContractTime                          Category Salary  \
# 8128   non-specified      permanent                           IT Jobs  45000
# 9050   non-specified      permanent                           IT Jobs  34000
# 9085   non-specified       contract                           IT Jobs  32500
# 13231  non-specified      permanent  PR, Advertising & Marketing Jobs  26000
# 15956  non-specified      permanent                  Engineering Jobs  47500
# 23403  non-specified  non-specified       Hospitality & Catering Jobs  22000
# 23612  non-specified  non-specified       Hospitality & Catering Jobs  17000
# 23812  non-specified  non-specified       Hospitality & Catering Jobs  22000
# 23862  non-specified  non-specified       Hospitality & Catering Jobs  22000
# 27602      full_time  non-specified         Healthcare & Nursing Jobs  48000
# 27870      full_time  non-specified         Healthcare & Nursing Jobs  47040
# 28350      full_time  non-specified         Healthcare & Nursing Jobs      0
# 29135      full_time  non-specified         Healthcare & Nursing Jobs  14400
# 29285      full_time  non-specified         Healthcare & Nursing Jobs  47040
# 29319      full_time  non-specified         Healthcare & Nursing Jobs  45120
# 29919  non-specified      permanent                     Teaching Jobs  21000
# 29998  non-specified       contract                  Engineering Jobs  57600
# 30421  non-specified      permanent                     Teaching Jobs  18250
# 30682  non-specified      permanent                     Teaching Jobs  19500
# 31159  non-specified      permanent                  Engineering Jobs    NaN
# 31860  non-specified      permanent  PR, Advertising & Marketing Jobs  30000
# 31918  non-specified      permanent                     Teaching Jobs  32000
# 34379      part_time      permanent                     Teaching Jobs  13522
# 34780      full_time      permanent                     Teaching Jobs  50000
# 35142      full_time      permanent                           IT Jobs  27500
# 37242  non-specified  non-specified                        Sales Jobs  15600
# 38053  non-specified  non-specified       Hospitality & Catering Jobs  35000
# 38137  non-specified  non-specified       Hospitality & Catering Jobs  25000
# 38185  non-specified  non-specified       Hospitality & Catering Jobs  35000
# 38290  non-specified  non-specified       Hospitality & Catering Jobs  22000
# 38478  non-specified  non-specified       Hospitality & Catering Jobs  15360
# 38654  non-specified  non-specified       Hospitality & Catering Jobs  30000
# 39081  non-specified  non-specified       Hospitality & Catering Jobs  40000
# 39249      part_time  non-specified       Hospitality & Catering Jobs  12480
# 39404      full_time  non-specified                        Sales Jobs  22812
# 39773      part_time  non-specified                     Teaching Jobs  14016
# 39791      full_time  non-specified                        Sales Jobs  14000
# 39866      full_time  non-specified                     Teaching Jobs  12480
# 39909      full_time  non-specified                           IT Jobs  58706
# 39974      part_time  non-specified                     Teaching Jobs  12480
# 40127      part_time  non-specified                     Teaching Jobs  14400
# 40420      full_time  non-specified         Healthcare & Nursing Jobs  14976
# 40620      full_time  non-specified                     Teaching Jobs  16000
# 40872      full_time  non-specified                     Teaching Jobs  13440
# 40928      full_time  non-specified                     Teaching Jobs  30000
# 40929      full_time  non-specified         Healthcare & Nursing Jobs  14976
# 40986      full_time  non-specified                  Engineering Jobs  34760
# 41034      full_time  non-specified                     Teaching Jobs    NaN
#
#                  OpenDate           CloseDate                      SourceName
# 8128  2013-07-22 12:00:00 2013-10-20 12:00:00                    jobserve.com
# 9050  2013-03-26 12:00:00 2013-05-25 12:00:00                    jobserve.com
# 9085  2013-05-17 12:00:00 2013-07-16 12:00:00                    jobserve.com
# 13231 2013-10-06 00:00:00 2013-11-05 00:00:00                   totaljobs.com
# 15956 2013-07-02 00:00:00 2013-08-01 00:00:00                   totaljobs.com
# 23403 2012-08-07 00:00:00 2012-10-06 00:00:00                     caterer.com
# 23612 2013-03-27 12:00:00 2013-04-26 12:00:00                     caterer.com
# 23812 2013-02-13 12:00:00 2013-02-27 12:00:00                     caterer.com
# 23862 2012-04-25 15:00:00 2012-05-09 15:00:00                     caterer.com
# 27602 2013-04-21 12:00:00 2013-06-20 12:00:00                  staffnurse.com
# 27870 2013-10-28 12:00:00 2013-11-27 12:00:00                  staffnurse.com
# 28350 2012-03-11 12:00:00 2012-06-09 12:00:00                  staffnurse.com
# 29135 2012-09-28 00:00:00 2012-11-27 00:00:00                  staffnurse.com
# 29285 2013-05-25 12:00:00 2013-08-23 12:00:00                  staffnurse.com
# 29319 2013-04-04 00:00:00 2013-06-03 00:00:00                  staffnurse.com
# 29919 2013-01-17 00:00:00 2013-03-18 00:00:00                   jobsite.co.uk
# 29998 2013-09-07 00:00:00 2013-10-07 00:00:00                   jobsite.co.uk
# 30421 2012-04-10 15:00:00 2012-07-09 15:00:00                   jobsite.co.uk
# 30682 2012-08-23 15:00:00 2012-11-21 15:00:00                   jobsite.co.uk
# 31159 2012-12-29 15:00:00 2013-01-28 15:00:00                   jobsite.co.uk
# 31860 2013-09-29 15:00:00 2013-12-28 15:00:00                   jobsite.co.uk
# 31918 2013-04-05 15:00:00 2013-07-04 15:00:00                   jobsite.co.uk
# 34379 2013-09-06 12:00:00 2013-11-05 12:00:00             jobs.guardian.co.uk
# 34780 2013-02-18 00:00:00 2013-05-19 00:00:00             jobs.guardian.co.uk
# 35142 2013-05-07 15:00:00 2013-07-06 15:00:00               planetrecruit.com
# 37242 2012-05-09 00:00:00 2012-07-08 00:00:00               salestarget.co.uk
# 38053 2012-06-29 00:00:00 2012-08-28 00:00:00  jobs.catererandhotelkeeper.com
# 38137 2012-12-09 15:00:00 2013-01-08 15:00:00  jobs.catererandhotelkeeper.com
# 38185 2013-12-14 15:00:00 2014-02-12 15:00:00  jobs.catererandhotelkeeper.com
# 38290 2013-01-24 00:00:00 2013-02-07 00:00:00  jobs.catererandhotelkeeper.com
# 38478 2013-11-03 15:00:00 2014-01-02 15:00:00  jobs.catererandhotelkeeper.com
# 38654 2012-06-25 15:00:00 2012-07-09 15:00:00  jobs.catererandhotelkeeper.com
# 39081 2013-08-30 15:00:00 2013-10-29 15:00:00  jobs.catererandhotelkeeper.com
# 39249 2013-09-15 15:00:00 2013-09-29 15:00:00                  Jobcentre Plus
# 39404 2012-01-30 00:00:00 2012-02-29 00:00:00                  Jobcentre Plus
# 39773 2012-10-08 15:00:00 2012-10-22 15:00:00                  Jobcentre Plus
# 39791 2012-06-08 12:00:00 2012-08-07 12:00:00                  Jobcentre Plus
# 39866 2012-12-02 12:00:00 2013-03-02 12:00:00                  Jobcentre Plus
# 39909 2013-11-02 00:00:00 2014-01-01 00:00:00                  Jobcentre Plus
# 39974 2012-07-06 00:00:00 2012-08-05 00:00:00                  Jobcentre Plus
# 40127 2013-08-28 00:00:00 2013-09-27 00:00:00                  Jobcentre Plus
# 40420 2013-08-15 15:00:00 2013-10-14 15:00:00                  Jobcentre Plus
# 40620 2012-09-17 15:00:00 2012-11-16 15:00:00                  Jobcentre Plus
# 40872 2012-05-03 00:00:00 2012-08-01 00:00:00                  Jobcentre Plus
# 40928 2012-12-12 00:00:00 2013-02-10 00:00:00                  Jobcentre Plus
# 40929 2013-08-22 15:00:00 2013-09-21 15:00:00                  Jobcentre Plus
# 40986 2013-07-16 00:00:00 2013-08-15 00:00:00                  Jobcentre Plus
# 41034 2012-01-29 00:00:00 2012-04-28 00:00:00                  Jobcentre Plus

# %%
drc = df['Company'].str.contains(r'[dD]\.?[rR]\.?[cC]\.?')
df[drc]
# Out:
#              Id                                              Title  \
# 4424   69933586                Registered General Nurse (Rgn Bank)
# 5904   69933552                 Physiotherapist  Band 6 Inpatients
# 6327   69933547               Registered Nurse (Rmn/Mental Health)
# 27273  66935105                         Rgn (Bank Shifts)  Preston
# 27602  66934491  Locum Physiotherapist Required  Central London...
# 27870  71607588      Band 6 Speech And Language Therapists  London
# 28350  71614468                             Surgery Nurse  Norwich
# 29112  70016274             Mental Health Support Worker  Barnsley
# 29135  72187316   Heath Care Assistant  Immediate Start  Liverpool
# 29285  71093048  Locum Occupational Therapist Required  Gloucester
# 29319  71093010  Locum Band 6 Neuro Speech And Language Therapi...
# 44630  71224098     Band 6 Occupational Therapist Elderly / Stroke
# 44644  71224014                Physiotherapists Required  Basildon
# 46068  68560108                   Band 6 Speech Therapist Required
# 47702  68808716                  Band 6 Dietician Jobs In Scotland
#
#                  Location            Company   ContractType   ContractTime  \
# 4424                   Uk                DRC  non-specified       contract
# 5904                Essex                DRC  non-specified      permanent
# 6327               Oxford                DRC  non-specified      permanent
# 27273             Preston         DRC Locums  non-specified       contract
# 27602              London  D.R.C. Locums Ltd      full_time  non-specified
# 27870              London  D.R.C. Locums Ltd      full_time  non-specified
# 28350             Norwich  D.R.C. Locums Ltd      full_time  non-specified
# 29112            Barnsley         DRC Locums      full_time  non-specified
# 29135           Liverpool  D.R.C. Locums Ltd      full_time  non-specified
# 29285          Gloucester  D.R.C. Locums Ltd      full_time  non-specified
# 29319              London  D.R.C. Locums Ltd      full_time  non-specified
# 44630  South West England         DRC Locums  non-specified  non-specified
# 44644       Isle Of Wight         DRC Locums  non-specified  non-specified
# 46068              London         DRC Locums  non-specified       contract
# 47702             Glasgow         DRC Locums  non-specified  non-specified
#
#                         Category Salary            OpenDate  \
# 4424   Healthcare & Nursing Jobs        2013-02-19 00:00:00
# 5904   Healthcare & Nursing Jobs  28000 2013-03-16 12:00:00
# 6327   Healthcare & Nursing Jobs  26052 2013-03-31 12:00:00
# 27273  Healthcare & Nursing Jobs  40320 2012-03-15 15:00:00
# 27602  Healthcare & Nursing Jobs  48000 2013-04-21 12:00:00
# 27870  Healthcare & Nursing Jobs  47040 2013-10-28 12:00:00
# 28350  Healthcare & Nursing Jobs      0 2012-03-11 12:00:00
# 29112  Healthcare & Nursing Jobs  13500 2012-09-03 12:00:00
# 29135  Healthcare & Nursing Jobs  14400 2012-09-28 00:00:00
# 29285  Healthcare & Nursing Jobs  47040 2013-05-25 12:00:00
# 29319  Healthcare & Nursing Jobs  45120 2013-04-04 00:00:00
# 44630  Healthcare & Nursing Jobs  47040 2013-08-10 12:00:00
# 44644  Healthcare & Nursing Jobs  48000 2013-07-04 00:00:00
# 46068  Healthcare & Nursing Jobs  50880 2012-02-26 15:00:00
# 47702  Healthcare & Nursing Jobs  55680 2013-07-12 15:00:00
#
#                 CloseDate          SourceName
# 4424  2013-03-21 00:00:00    cv-library.co.uk
# 5904  2013-06-14 12:00:00    cv-library.co.uk
# 6327  2013-06-29 12:00:00    cv-library.co.uk
# 27273 2012-05-14 15:00:00      staffnurse.com
# 27602 2013-06-20 12:00:00      staffnurse.com
# 27870 2013-11-27 12:00:00      staffnurse.com
# 28350 2012-06-09 12:00:00      staffnurse.com
# 29112 2012-10-03 12:00:00      staffnurse.com
# 29135 2012-11-27 00:00:00      staffnurse.com
# 29285 2013-08-23 12:00:00      staffnurse.com
# 29319 2013-06-03 00:00:00      staffnurse.com
# 44630 2013-09-09 12:00:00    contractjobs.com
# 44644 2013-08-03 00:00:00    contractjobs.com
# 46068 2012-03-27 15:00:00           jobg8.com
# 47702 2013-08-11 15:00:00  jobsinscotland.com

# %% [markdown]
# It seems like this 'DRC' company needs to have its values tweaked

# %%
indices = list(df[drc].index)
for ind in indices:
    # Add to errorDict
    errorDict = addToErrorDict(errorDict,ind,df['Id'][ind],'Company',df.loc[ind,'Company'],'DRC Locums Ltd','Multiple namings','Set to a global name')
    # Set to a global name
    df.loc[ind,'Company'] = 'DRC Locums Ltd'
df[drc]
# Out:
#              Id                                              Title  \
# 4424   69933586                Registered General Nurse (Rgn Bank)
# 5904   69933552                 Physiotherapist  Band 6 Inpatients
# 6327   69933547               Registered Nurse (Rmn/Mental Health)
# 27273  66935105                         Rgn (Bank Shifts)  Preston
# 27602  66934491  Locum Physiotherapist Required  Central London...
# 27870  71607588      Band 6 Speech And Language Therapists  London
# 28350  71614468                             Surgery Nurse  Norwich
# 29112  70016274             Mental Health Support Worker  Barnsley
# 29135  72187316   Heath Care Assistant  Immediate Start  Liverpool
# 29285  71093048  Locum Occupational Therapist Required  Gloucester
# 29319  71093010  Locum Band 6 Neuro Speech And Language Therapi...
# 44630  71224098     Band 6 Occupational Therapist Elderly / Stroke
# 44644  71224014                Physiotherapists Required  Basildon
# 46068  68560108                   Band 6 Speech Therapist Required
# 47702  68808716                  Band 6 Dietician Jobs In Scotland
#
#                  Location         Company   ContractType   ContractTime  \
# 4424                   Uk  DRC Locums Ltd  non-specified       contract
# 5904                Essex  DRC Locums Ltd  non-specified      permanent
# 6327               Oxford  DRC Locums Ltd  non-specified      permanent
# 27273             Preston  DRC Locums Ltd  non-specified       contract
# 27602              London  DRC Locums Ltd      full_time  non-specified
# 27870              London  DRC Locums Ltd      full_time  non-specified
# 28350             Norwich  DRC Locums Ltd      full_time  non-specified
# 29112            Barnsley  DRC Locums Ltd      full_time  non-specified
# 29135           Liverpool  DRC Locums Ltd      full_time  non-specified
# 29285          Gloucester  DRC Locums Ltd      full_time  non-specified
# 29319              London  DRC Locums Ltd      full_time  non-specified
# 44630  South West England  DRC Locums Ltd  non-specified  non-specified
# 44644       Isle Of Wight  DRC Locums Ltd  non-specified  non-specified
# 46068              London  DRC Locums Ltd  non-specified       contract
# 47702             Glasgow  DRC Locums Ltd  non-specified  non-specified
#
#                         Category Salary            OpenDate  \
# 4424   Healthcare & Nursing Jobs        2013-02-19 00:00:00
# 5904   Healthcare & Nursing Jobs  28000 2013-03-16 12:00:00
# 6327   Healthcare & Nursing Jobs  26052 2013-03-31 12:00:00
# 27273  Healthcare & Nursing Jobs  40320 2012-03-15 15:00:00
# 27602  Healthcare & Nursing Jobs  48000 2013-04-21 12:00:00
# 27870  Healthcare & Nursing Jobs  47040 2013-10-28 12:00:00
# 28350  Healthcare & Nursing Jobs      0 2012-03-11 12:00:00
# 29112  Healthcare & Nursing Jobs  13500 2012-09-03 12:00:00
# 29135  Healthcare & Nursing Jobs  14400 2012-09-28 00:00:00
# 29285  Healthcare & Nursing Jobs  47040 2013-05-25 12:00:00
# 29319  Healthcare & Nursing Jobs  45120 2013-04-04 00:00:00
# 44630  Healthcare & Nursing Jobs  47040 2013-08-10 12:00:00
# 44644  Healthcare & Nursing Jobs  48000 2013-07-04 00:00:00
# 46068  Healthcare & Nursing Jobs  50880 2012-02-26 15:00:00
# 47702  Healthcare & Nursing Jobs  55680 2013-07-12 15:00:00
#
#                 CloseDate          SourceName
# 4424  2013-03-21 00:00:00    cv-library.co.uk
# 5904  2013-06-14 12:00:00    cv-library.co.uk
# 6327  2013-06-29 12:00:00    cv-library.co.uk
# 27273 2012-05-14 15:00:00      staffnurse.com
# 27602 2013-06-20 12:00:00      staffnurse.com
# 27870 2013-11-27 12:00:00      staffnurse.com
# 28350 2012-06-09 12:00:00      staffnurse.com
# 29112 2012-10-03 12:00:00      staffnurse.com
# 29135 2012-11-27 00:00:00      staffnurse.com
# 29285 2013-08-23 12:00:00      staffnurse.com
# 29319 2013-06-03 00:00:00      staffnurse.com
# 44630 2013-09-09 12:00:00    contractjobs.com
# 44644 2013-08-03 00:00:00    contractjobs.com
# 46068 2012-03-27 15:00:00           jobg8.com
# 47702 2013-08-11 15:00:00  jobsinscotland.com

# %%
dot_company = df['Company'].str.contains(r'\.')
df[dot_company&~coal&~dp&~ckr]
# Out:
#              Id                                              Title  \
# 8128   71593642  Oracle Hr Functional Consultant/Oracle Ebusine...
# 9050   68627684               Oracle Hr Functional Support Analyst
# 9085   69574473  C Net Developer (Python, Scrum, Agile, Ibm Web...
# 13231  68693588                           Public Relations Officer
# 15956  72233005     Senior Mechanical Estimator  Building Services
# 23403  68837702                         Bar And Lounge Manager  Br
# 23612  69470872          Group Reservations Executive  Up To ****K
# 23812  71959934    Meeting & Events Sales Manager  Reactive Exeter
# 23862  71276961                      Sous Chef Plus Service Charge
# 29919  69688264                 Urgently  Requiredtrainee Teachers
# 29998  72479693                                     Safety Advisor
# 30421  69688196                 Trainee Teaching Assistants Needed
# 30682  69688041         Sccd Need Teachers And Teaching Assistants
# 31159  67948117                               Process Metallurgist
# 31860  71685846  Project Manager  Events / Marketing  Macclesfi...
# 31918  69687263                              London Needs Teachers
# 34379  69675549  Hr Manager (Parttime) 3 Days A Week ( Flexi Wo...
# 34780  71885279               Solicitor/ Disciplinary Case Manager
# 35142  68838621                          Software Developer  Devon
# 37242  69188513     No Experience, No Problem New Roles In Bristol
# 38053  68505017     Operations Manager Plus Bonus  Leicester  ****
# 38137  68707250  Assistant Conference And Banqueting Operations...
# 38185  70032108                           Sales Manager  Mice ****
# 38290  69639025                       Restaurant & Bar Manager  Bw
# 38478  69183421                Painter  Ongoing Temp **** Per Hour
# 38654  68505506    Event Operations Manager  **** ****K Plus Bonus
# 39081  68504890      Assistant Director Of Sales  ****K Plus Bonus
# 39249  66537257                                      Kitchen Staff
# 39404  69768265                  Venues & Events Energy Consultant
# 39773  69769276                                     Sen Key Worker
# 39791  69554526                                 Membership Adviser
# 39866  68239749                Nursery Practitioner L****  Ooc****
# 39909  69766368     Software Development Project/Programme Manager
# 39974  69554894                           After School Club Worker
# 40127  69769301                             Preschool Practitioner
# 40420  68450122                      Skilled Senior Care Assistant
# 40620  69554720                            Fitness Service Manager
# 40872  68446046                    Baby Room Practitioner  Col****
# 40928  67447764            National Training & Development Manager
# 40929  66750270                            Home Support Assistants
# 40986  69150243  Gas Technical Engineer (Breakdown And Repair) ...
# 41034  69554855                                 Learning Assistant
#
#                 Location                                            Company  \
# 8128           Wiltshire  Sand Resources. A division of InterQuest Group...
# 9050           Wiltshire  Sand Resources. A division of InterQuest Group...
# 9085             Coscote  Sand Resources. A division of InterQuest Group...
# 13231                 Uk                         St.Marys International Ltd
# 15956   Northamptonshire                                         T.E.D. Ltd
# 23403                 Uk                              K.B.C. Associates Ltd
# 23612  South East London                              K.B.C. Associates Ltd
# 23812             Exeter                              K.B.C. Associates Ltd
# 23862  South East London                              K.B.C. Associates Ltd
# 29919             London           Schools Courses Career Development C.I.C
# 29998            Cumbria                                         N.R.L Ltd
# 30421             London           Schools Courses Career Development C.I.C
# 30682             London           Schools Courses Career Development C.I.C
# 31159                 Uk                                 www.dexternicholas
# 31860                 Uk                              C.O.S Recruitment Ltd
# 31918             London           Schools Courses Career Development C.I.C
# 34379             London                            M. ARIA RECRUITMENT Ltd
# 34780             London                            M. ARIA RECRUITMENT Ltd
# 35142              Devon                                         Recruit.UK
# 37242                 Uk                                    HelpMeGo.To Ltd
# 38053          Leicester                              K.B.C. Associates Ltd
# 38137             London                              K.B.C. Associates Ltd
# 38185             London                              K.B.C. Associates Ltd
# 38290          Brentwood                              K.B.C. Associates Ltd
# 38478             London                              K.B.C. Associates Ltd
# 38654             London                              K.B.C. Associates Ltd
# 39081             London                              K.B.C. Associates Ltd
# 39249                 Uk                                   J.D.Wetherspoons
# 39404            Evesham                                        E.on UK Plc
# 39773         Colchester                                   www.essex eyjobs
# 39791        Southampton                                        L.A Fitness
# 39866                Sea                                   www.essex eyjobs
# 39909         Nottingham                                        E.on UK Plc
# 39974         Chelmsford                                   www.essex eyjobs
# 40127         Colchester                                   www.essex eyjobs
# 40420             London  St.marys International Education and Employmen...
# 40620        Southampton                                        L.A Fitness
# 40872         Colchester                                   www.essex eyjobs
# 40928      Milton Keynes                        B.S.H. Home Applicances Ltd
# 40929      North Shields                  At Home with...Helen McArdle Care
# 40986         Birmingham                                        E.on UK Plc
# 41034         Birmingham             St. Paul's Community Development Trust
#
#         ContractType   ContractTime                          Category Salary  \
# 8128   non-specified      permanent                           IT Jobs  45000
# 9050   non-specified      permanent                           IT Jobs  34000
# 9085   non-specified       contract                           IT Jobs  32500
# 13231  non-specified      permanent  PR, Advertising & Marketing Jobs  26000
# 15956  non-specified      permanent                  Engineering Jobs  47500
# 23403  non-specified  non-specified       Hospitality & Catering Jobs  22000
# 23612  non-specified  non-specified       Hospitality & Catering Jobs  17000
# 23812  non-specified  non-specified       Hospitality & Catering Jobs  22000
# 23862  non-specified  non-specified       Hospitality & Catering Jobs  22000
# 29919  non-specified      permanent                     Teaching Jobs  21000
# 29998  non-specified       contract                  Engineering Jobs  57600
# 30421  non-specified      permanent                     Teaching Jobs  18250
# 30682  non-specified      permanent                     Teaching Jobs  19500
# 31159  non-specified      permanent                  Engineering Jobs    NaN
# 31860  non-specified      permanent  PR, Advertising & Marketing Jobs  30000
# 31918  non-specified      permanent                     Teaching Jobs  32000
# 34379      part_time      permanent                     Teaching Jobs  13522
# 34780      full_time      permanent                     Teaching Jobs  50000
# 35142      full_time      permanent                           IT Jobs  27500
# 37242  non-specified  non-specified                        Sales Jobs  15600
# 38053  non-specified  non-specified       Hospitality & Catering Jobs  35000
# 38137  non-specified  non-specified       Hospitality & Catering Jobs  25000
# 38185  non-specified  non-specified       Hospitality & Catering Jobs  35000
# 38290  non-specified  non-specified       Hospitality & Catering Jobs  22000
# 38478  non-specified  non-specified       Hospitality & Catering Jobs  15360
# 38654  non-specified  non-specified       Hospitality & Catering Jobs  30000
# 39081  non-specified  non-specified       Hospitality & Catering Jobs  40000
# 39249      part_time  non-specified       Hospitality & Catering Jobs  12480
# 39404      full_time  non-specified                        Sales Jobs  22812
# 39773      part_time  non-specified                     Teaching Jobs  14016
# 39791      full_time  non-specified                        Sales Jobs  14000
# 39866      full_time  non-specified                     Teaching Jobs  12480
# 39909      full_time  non-specified                           IT Jobs  58706
# 39974      part_time  non-specified                     Teaching Jobs  12480
# 40127      part_time  non-specified                     Teaching Jobs  14400
# 40420      full_time  non-specified         Healthcare & Nursing Jobs  14976
# 40620      full_time  non-specified                     Teaching Jobs  16000
# 40872      full_time  non-specified                     Teaching Jobs  13440
# 40928      full_time  non-specified                     Teaching Jobs  30000
# 40929      full_time  non-specified         Healthcare & Nursing Jobs  14976
# 40986      full_time  non-specified                  Engineering Jobs  34760
# 41034      full_time  non-specified                     Teaching Jobs    NaN
#
#                  OpenDate           CloseDate                      SourceName
# 8128  2013-07-22 12:00:00 2013-10-20 12:00:00                    jobserve.com
# 9050  2013-03-26 12:00:00 2013-05-25 12:00:00                    jobserve.com
# 9085  2013-05-17 12:00:00 2013-07-16 12:00:00                    jobserve.com
# 13231 2013-10-06 00:00:00 2013-11-05 00:00:00                   totaljobs.com
# 15956 2013-07-02 00:00:00 2013-08-01 00:00:00                   totaljobs.com
# 23403 2012-08-07 00:00:00 2012-10-06 00:00:00                     caterer.com
# 23612 2013-03-27 12:00:00 2013-04-26 12:00:00                     caterer.com
# 23812 2013-02-13 12:00:00 2013-02-27 12:00:00                     caterer.com
# 23862 2012-04-25 15:00:00 2012-05-09 15:00:00                     caterer.com
# 29919 2013-01-17 00:00:00 2013-03-18 00:00:00                   jobsite.co.uk
# 29998 2013-09-07 00:00:00 2013-10-07 00:00:00                   jobsite.co.uk
# 30421 2012-04-10 15:00:00 2012-07-09 15:00:00                   jobsite.co.uk
# 30682 2012-08-23 15:00:00 2012-11-21 15:00:00                   jobsite.co.uk
# 31159 2012-12-29 15:00:00 2013-01-28 15:00:00                   jobsite.co.uk
# 31860 2013-09-29 15:00:00 2013-12-28 15:00:00                   jobsite.co.uk
# 31918 2013-04-05 15:00:00 2013-07-04 15:00:00                   jobsite.co.uk
# 34379 2013-09-06 12:00:00 2013-11-05 12:00:00             jobs.guardian.co.uk
# 34780 2013-02-18 00:00:00 2013-05-19 00:00:00             jobs.guardian.co.uk
# 35142 2013-05-07 15:00:00 2013-07-06 15:00:00               planetrecruit.com
# 37242 2012-05-09 00:00:00 2012-07-08 00:00:00               salestarget.co.uk
# 38053 2012-06-29 00:00:00 2012-08-28 00:00:00  jobs.catererandhotelkeeper.com
# 38137 2012-12-09 15:00:00 2013-01-08 15:00:00  jobs.catererandhotelkeeper.com
# 38185 2013-12-14 15:00:00 2014-02-12 15:00:00  jobs.catererandhotelkeeper.com
# 38290 2013-01-24 00:00:00 2013-02-07 00:00:00  jobs.catererandhotelkeeper.com
# 38478 2013-11-03 15:00:00 2014-01-02 15:00:00  jobs.catererandhotelkeeper.com
# 38654 2012-06-25 15:00:00 2012-07-09 15:00:00  jobs.catererandhotelkeeper.com
# 39081 2013-08-30 15:00:00 2013-10-29 15:00:00  jobs.catererandhotelkeeper.com
# 39249 2013-09-15 15:00:00 2013-09-29 15:00:00                  Jobcentre Plus
# 39404 2012-01-30 00:00:00 2012-02-29 00:00:00                  Jobcentre Plus
# 39773 2012-10-08 15:00:00 2012-10-22 15:00:00                  Jobcentre Plus
# 39791 2012-06-08 12:00:00 2012-08-07 12:00:00                  Jobcentre Plus
# 39866 2012-12-02 12:00:00 2013-03-02 12:00:00                  Jobcentre Plus
# 39909 2013-11-02 00:00:00 2014-01-01 00:00:00                  Jobcentre Plus
# 39974 2012-07-06 00:00:00 2012-08-05 00:00:00                  Jobcentre Plus
# 40127 2013-08-28 00:00:00 2013-09-27 00:00:00                  Jobcentre Plus
# 40420 2013-08-15 15:00:00 2013-10-14 15:00:00                  Jobcentre Plus
# 40620 2012-09-17 15:00:00 2012-11-16 15:00:00                  Jobcentre Plus
# 40872 2012-05-03 00:00:00 2012-08-01 00:00:00                  Jobcentre Plus
# 40928 2012-12-12 00:00:00 2013-02-10 00:00:00                  Jobcentre Plus
# 40929 2013-08-22 15:00:00 2013-09-21 15:00:00                  Jobcentre Plus
# 40986 2013-07-16 00:00:00 2013-08-15 00:00:00                  Jobcentre Plus
# 41034 2012-01-29 00:00:00 2012-04-28 00:00:00                  Jobcentre Plus

# %%
# Get all companies with the short form with or without the .
short_form = df['Company'].str.contains(r'[nN]\.?[rR]\.?[lL]\.?|[cC]\.?[oO]\.?[sS]\.?|[kK]\.?[Bb]\.?[cC]\.?|[bB]\.?[sS]\.?[hH]\.?|[cC]\.?[iI]\.?[cC]\.?')
df[short_form]
# Out:
#              Id                                              Title  \
# 669    67208419               Mechanical Commissioning Engineer(S)
# 2602   69541463                        Applictaion Support Analyst
# 5033   70172134                                 Cluster Hr Manager
# 10730  69803991  Brand Marketing Executivecosmo Restaurant Grou...
# 14545  72447697           Strategic Marketing And Planning Manager
# 15170  71432270                 Senior Marketing Planner  Campaign
# 23139  71956446                   Store Manager  Chichester  Costa
# 23267  71276615             Assistant Manager  Exeter  New Opening
# 23403  68837702                         Bar And Lounge Manager  Br
# 23437  71276619                    Sous Chef – Exeter  New Opening
# 23612  69470872          Group Reservations Executive  Up To ****K
# 23812  71959934    Meeting & Events Sales Manager  Reactive Exeter
# 23862  71276961                      Sous Chef Plus Service Charge
# 24028  65317541  Store Manager  Heathrow (T****) ****Hr Operati...
# 29919  69688264                 Urgently  Requiredtrainee Teachers
# 29998  72479693                                     Safety Advisor
# 30421  69688196                 Trainee Teaching Assistants Needed
# 30682  69688041         Sccd Need Teachers And Teaching Assistants
# 31252  72248522  Business Development Manager  Sales Manager (E...
# 31402  71856699  Business Development Manager  Sales Manager (F...
# 31860  71685846  Project Manager  Events / Marketing  Macclesfi...
# 31918  69687263                              London Needs Teachers
# 32011  66907909                   New Acquisitions Sales Executive
# 32633  72679998                     Marketing Executive (Projects)
# 38053  68505017     Operations Manager Plus Bonus  Leicester  ****
# 38137  68707250  Assistant Conference And Banqueting Operations...
# 38185  70032108                           Sales Manager  Mice ****
# 38290  69639025                       Restaurant & Bar Manager  Bw
# 38478  69183421                Painter  Ongoing Temp **** Per Hour
# 38560  69183454  Deputy Manager  Bath  Package Of Up To **** In...
# 38654  68505506    Event Operations Manager  **** ****K Plus Bonus
# 38782  68706475                Sous Chef  Cosy Club Taunton Ta****
# 38991  72228075               Assistant Manager  Nationwide  Costa
# 39081  68504890      Assistant Director Of Sales  ****K Plus Bonus
# 39101  71660447                Deputy Manager  Exeter  New Opening
# 39156  66537859                             Barista / Coffee Maker
# 39223  66538278                         Customer Service Assistant
# 39460  69145705                         Female Personal Assistants
# 39727  70590667         Barista For Costa Coffee In Gerrards Cross
# 40443  71793689                                 Care Support Staff
# 40928  67447764            National Training & Development Manager
#
#                 Location                                   Company  \
# 669              Cumbria                                   NRL Ltd
# 2602      Leicestershire                                   NRL Ltd
# 5033             Gatwick                            kbc Associates
# 10730                 Uk                         Cosmo Service Ltd
# 14545  South East London                     Decostyle Recruitment
# 15170        Northampton                            Avon Cosmetics
# 23139         Chichester                                     Costa
# 23267             Exeter                                 Cosy Club
# 23403                 Uk                     K.B.C. Associates Ltd
# 23437             Exeter                                 Cosy Club
# 23612  South East London                     K.B.C. Associates Ltd
# 23812             Exeter                     K.B.C. Associates Ltd
# 23862  South East London                     K.B.C. Associates Ltd
# 24028                 Uk                                     Costa
# 29919             London  Schools Courses Career Development C.I.C
# 29998            Cumbria                                N.R.L Ltd
# 30421             London  Schools Courses Career Development C.I.C
# 30682             London  Schools Courses Career Development C.I.C
# 31252                 Uk                                Jobshop UK
# 31402                 Uk                                Jobshop UK
# 31860                 Uk                     C.O.S Recruitment Ltd
# 31918             London  Schools Courses Career Development C.I.C
# 32011        Southampton                        KBC Associates Ltd
# 32633                 Uk                        KBC Associates Ltd
# 38053          Leicester                     K.B.C. Associates Ltd
# 38137             London                     K.B.C. Associates Ltd
# 38185             London                     K.B.C. Associates Ltd
# 38290          Brentwood                     K.B.C. Associates Ltd
# 38478             London                     K.B.C. Associates Ltd
# 38560             London                                 Cosy Club
# 38654             London                     K.B.C. Associates Ltd
# 38782            Taunton                                 Cosy Club
# 38991             London                                     Costa
# 39081             London                     K.B.C. Associates Ltd
# 39101             Exeter                                 Cosy Club
# 39156         Birmingham                              Costa Coffee
# 39223          Rotherham                              Costa Coffee
# 39460          Morecambe             Salvere Social Enterprise Cic
# 39727     Gerrards Cross                              Costa Coffee
# 40443          Stockport                    Salvere CIC Enterprise
# 40928      Milton Keynes               B.S.H. Home Applicances Ltd
#
#         ContractType   ContractTime                          Category Salary  \
# 669    non-specified       contract                  Engineering Jobs  57600
# 2602   non-specified      permanent                           IT Jobs  30000
# 5033   non-specified      permanent       Hospitality & Catering Jobs
# 10730  non-specified      permanent  PR, Advertising & Marketing Jobs  26500
# 14545  non-specified      permanent  PR, Advertising & Marketing Jobs  62500
# 15170  non-specified      permanent  PR, Advertising & Marketing Jobs  34000
# 23139  non-specified  non-specified       Hospitality & Catering Jobs  19500
# 23267  non-specified  non-specified       Hospitality & Catering Jobs  21000
# 23403  non-specified  non-specified       Hospitality & Catering Jobs  22000
# 23437  non-specified  non-specified       Hospitality & Catering Jobs      0
# 23612  non-specified  non-specified       Hospitality & Catering Jobs  17000
# 23812  non-specified  non-specified       Hospitality & Catering Jobs  22000
# 23862  non-specified  non-specified       Hospitality & Catering Jobs  22000
# 24028  non-specified  non-specified       Hospitality & Catering Jobs  28000
# 29919  non-specified      permanent                     Teaching Jobs  21000
# 29998  non-specified       contract                  Engineering Jobs  57600
# 30421  non-specified      permanent                     Teaching Jobs  18250
# 30682  non-specified      permanent                     Teaching Jobs  19500
# 31252  non-specified      permanent                        Sales Jobs  40000
# 31402  non-specified      permanent                        Sales Jobs  35000
# 31860  non-specified      permanent  PR, Advertising & Marketing Jobs  30000
# 31918  non-specified      permanent                     Teaching Jobs  32000
# 32011  non-specified      permanent                           IT Jobs  27500
# 32633  non-specified       contract  PR, Advertising & Marketing Jobs  22000
# 38053  non-specified  non-specified       Hospitality & Catering Jobs  35000
# 38137  non-specified  non-specified       Hospitality & Catering Jobs  25000
# 38185  non-specified  non-specified       Hospitality & Catering Jobs  35000
# 38290  non-specified  non-specified       Hospitality & Catering Jobs  22000
# 38478  non-specified  non-specified       Hospitality & Catering Jobs  15360
# 38560  non-specified  non-specified       Hospitality & Catering Jobs  15000
# 38654  non-specified  non-specified       Hospitality & Catering Jobs  30000
# 38782  non-specified  non-specified       Hospitality & Catering Jobs  12500
# 38991  non-specified  non-specified       Hospitality & Catering Jobs  15745
# 39081  non-specified  non-specified       Hospitality & Catering Jobs  40000
# 39101  non-specified  non-specified       Hospitality & Catering Jobs  25000
# 39156      full_time  non-specified       Hospitality & Catering Jobs  41299
# 39223      part_time  non-specified       Hospitality & Catering Jobs  11884
# 39460      part_time  non-specified         Healthcare & Nursing Jobs  16320
# 39727      part_time  non-specified       Hospitality & Catering Jobs  12249
# 40443      full_time  non-specified         Healthcare & Nursing Jobs  13440
# 40928      full_time  non-specified                     Teaching Jobs  30000
#
#                  OpenDate           CloseDate                      SourceName
# 669   2013-01-22 12:00:00 2013-02-05 12:00:00                cv-library.co.uk
# 2602  2012-02-15 15:00:00 2012-03-16 15:00:00                cv-library.co.uk
# 5033  2012-11-07 00:00:00 2013-02-05 00:00:00                cv-library.co.uk
# 10730 2013-04-13 00:00:00 2013-07-12 00:00:00                   totaljobs.com
# 14545 2012-04-24 00:00:00 2012-05-24 00:00:00                   totaljobs.com
# 15170 2012-05-19 12:00:00 2012-06-18 12:00:00                   totaljobs.com
# 23139 2013-07-15 15:00:00 2013-09-13 15:00:00                     caterer.com
# 23267 2012-10-30 00:00:00 2012-12-29 00:00:00                     caterer.com
# 23403 2012-08-07 00:00:00 2012-10-06 00:00:00                     caterer.com
# 23437 2013-11-06 12:00:00 2014-01-05 12:00:00                     caterer.com
# 23612 2013-03-27 12:00:00 2013-04-26 12:00:00                     caterer.com
# 23812 2013-02-13 12:00:00 2013-02-27 12:00:00                     caterer.com
# 23862 2012-04-25 15:00:00 2012-05-09 15:00:00                     caterer.com
# 24028 2012-05-22 00:00:00 2012-07-21 00:00:00                     caterer.com
# 29919 2013-01-17 00:00:00 2013-03-18 00:00:00                   jobsite.co.uk
# 29998 2013-09-07 00:00:00 2013-10-07 00:00:00                   jobsite.co.uk
# 30421 2012-04-10 15:00:00 2012-07-09 15:00:00                   jobsite.co.uk
# 30682 2012-08-23 15:00:00 2012-11-21 15:00:00                   jobsite.co.uk
# 31252 2013-03-28 12:00:00 2013-06-26 12:00:00                   jobsite.co.uk
# 31402 2013-06-02 00:00:00 2013-08-31 00:00:00                   jobsite.co.uk
# 31860 2013-09-29 15:00:00 2013-12-28 15:00:00                   jobsite.co.uk
# 31918 2013-04-05 15:00:00 2013-07-04 15:00:00                   jobsite.co.uk
# 32011 2012-03-20 00:00:00 2012-04-19 00:00:00                   jobsite.co.uk
# 32633 2013-08-09 12:00:00 2013-10-08 12:00:00                   jobsite.co.uk
# 38053 2012-06-29 00:00:00 2012-08-28 00:00:00  jobs.catererandhotelkeeper.com
# 38137 2012-12-09 15:00:00 2013-01-08 15:00:00  jobs.catererandhotelkeeper.com
# 38185 2013-12-14 15:00:00 2014-02-12 15:00:00  jobs.catererandhotelkeeper.com
# 38290 2013-01-24 00:00:00 2013-02-07 00:00:00  jobs.catererandhotelkeeper.com
# 38478 2013-11-03 15:00:00 2014-01-02 15:00:00  jobs.catererandhotelkeeper.com
# 38560 2012-05-20 15:00:00 2012-06-03 15:00:00  jobs.catererandhotelkeeper.com
# 38654 2012-06-25 15:00:00 2012-07-09 15:00:00  jobs.catererandhotelkeeper.com
# 38782 2013-06-03 00:00:00 2013-07-03 00:00:00  jobs.catererandhotelkeeper.com
# 38991 2012-12-23 12:00:00 2013-01-22 12:00:00  jobs.catererandhotelkeeper.com
# 39081 2013-08-30 15:00:00 2013-10-29 15:00:00  jobs.catererandhotelkeeper.com
# 39101 2012-04-13 00:00:00 2012-05-13 00:00:00  jobs.catererandhotelkeeper.com
# 39156 2012-12-12 00:00:00 2013-03-12 00:00:00                  Jobcentre Plus
# 39223 2012-04-20 15:00:00 2012-05-04 15:00:00                  Jobcentre Plus
# 39460 2012-12-01 00:00:00 2012-12-31 00:00:00                  Jobcentre Plus
# 39727 2012-07-28 00:00:00 2012-08-27 00:00:00                  Jobcentre Plus
# 40443 2013-08-04 00:00:00 2013-10-03 00:00:00                  Jobcentre Plus
# 40928 2012-12-12 00:00:00 2013-02-10 00:00:00                  Jobcentre Plus

# %% [markdown]
# It does look like some of them has it without the dots. Thus, they will all be converted into ones without

# %%
pattern =r'([nN]\.[rR]\.[lL]\.?)|([cC]\.[oO]\.[sS]\.?)|([kK]\.[Bb]\.[cC]\.?)|([bB]\.[sS]\.[hH]\.?)|([cC]\.[iI]\.[cC]\.?)|([tT]\.[eE]\.[dD]\.?)'
dot_form = df['Company'].str.contains(pattern)
indices = list(df[dot_form].index)

for ind in indices:
    old = df['Company'][ind]
    # Remove all dots
    new = old.replace('.','')
    # Record to errorDict
    errorDict = addToErrorDict(errorDict,ind,df['Id'][ind],'Company',old,new,'Word contains .','Remove .s')
    # Replace the values in the dataset
    df.loc[ind,'Company'] = new
df[dot_form]
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2328\2149376107.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   dot_form = df['Company'].str.contains(pattern)
#              Id                                              Title  \
# 15956  72233005     Senior Mechanical Estimator  Building Services
# 23403  68837702                         Bar And Lounge Manager  Br
# 23612  69470872          Group Reservations Executive  Up To ****K
# 23812  71959934    Meeting & Events Sales Manager  Reactive Exeter
# 23862  71276961                      Sous Chef Plus Service Charge
# 29919  69688264                 Urgently  Requiredtrainee Teachers
# 29998  72479693                                     Safety Advisor
# 30421  69688196                 Trainee Teaching Assistants Needed
# 30682  69688041         Sccd Need Teachers And Teaching Assistants
# 31860  71685846  Project Manager  Events / Marketing  Macclesfi...
# 31918  69687263                              London Needs Teachers
# 38053  68505017     Operations Manager Plus Bonus  Leicester  ****
# 38137  68707250  Assistant Conference And Banqueting Operations...
# 38185  70032108                           Sales Manager  Mice ****
# 38290  69639025                       Restaurant & Bar Manager  Bw
# 38478  69183421                Painter  Ongoing Temp **** Per Hour
# 38654  68505506    Event Operations Manager  **** ****K Plus Bonus
# 39081  68504890      Assistant Director Of Sales  ****K Plus Bonus
# 40928  67447764            National Training & Development Manager
#
#                 Location                                 Company  \
# 15956   Northamptonshire                                 TED Ltd
# 23403                 Uk                      KBC Associates Ltd
# 23612  South East London                      KBC Associates Ltd
# 23812             Exeter                      KBC Associates Ltd
# 23862  South East London                      KBC Associates Ltd
# 29919             London  Schools Courses Career Development CIC
# 29998            Cumbria                                NRL Ltd
# 30421             London  Schools Courses Career Development CIC
# 30682             London  Schools Courses Career Development CIC
# 31860                 Uk                     COS Recruitment Ltd
# 31918             London  Schools Courses Career Development CIC
# 38053          Leicester                      KBC Associates Ltd
# 38137             London                      KBC Associates Ltd
# 38185             London                      KBC Associates Ltd
# 38290          Brentwood                      KBC Associates Ltd
# 38478             London                      KBC Associates Ltd
# 38654             London                      KBC Associates Ltd
# 39081             London                      KBC Associates Ltd
# 40928      Milton Keynes                BSH Home Applicances Ltd
#
#         ContractType   ContractTime                          Category Salary  \
# 15956  non-specified      permanent                  Engineering Jobs  47500
# 23403  non-specified  non-specified       Hospitality & Catering Jobs  22000
# 23612  non-specified  non-specified       Hospitality & Catering Jobs  17000
# 23812  non-specified  non-specified       Hospitality & Catering Jobs  22000
# 23862  non-specified  non-specified       Hospitality & Catering Jobs  22000
# 29919  non-specified      permanent                     Teaching Jobs  21000
# 29998  non-specified       contract                  Engineering Jobs  57600
# 30421  non-specified      permanent                     Teaching Jobs  18250
# 30682  non-specified      permanent                     Teaching Jobs  19500
# 31860  non-specified      permanent  PR, Advertising & Marketing Jobs  30000
# 31918  non-specified      permanent                     Teaching Jobs  32000
# 38053  non-specified  non-specified       Hospitality & Catering Jobs  35000
# 38137  non-specified  non-specified       Hospitality & Catering Jobs  25000
# 38185  non-specified  non-specified       Hospitality & Catering Jobs  35000
# 38290  non-specified  non-specified       Hospitality & Catering Jobs  22000
# 38478  non-specified  non-specified       Hospitality & Catering Jobs  15360
# 38654  non-specified  non-specified       Hospitality & Catering Jobs  30000
# 39081  non-specified  non-specified       Hospitality & Catering Jobs  40000
# 40928      full_time  non-specified                     Teaching Jobs  30000
#
#                  OpenDate           CloseDate                      SourceName
# 15956 2013-07-02 00:00:00 2013-08-01 00:00:00                   totaljobs.com
# 23403 2012-08-07 00:00:00 2012-10-06 00:00:00                     caterer.com
# 23612 2013-03-27 12:00:00 2013-04-26 12:00:00                     caterer.com
# 23812 2013-02-13 12:00:00 2013-02-27 12:00:00                     caterer.com
# 23862 2012-04-25 15:00:00 2012-05-09 15:00:00                     caterer.com
# 29919 2013-01-17 00:00:00 2013-03-18 00:00:00                   jobsite.co.uk
# 29998 2013-09-07 00:00:00 2013-10-07 00:00:00                   jobsite.co.uk
# 30421 2012-04-10 15:00:00 2012-07-09 15:00:00                   jobsite.co.uk
# 30682 2012-08-23 15:00:00 2012-11-21 15:00:00                   jobsite.co.uk
# 31860 2013-09-29 15:00:00 2013-12-28 15:00:00                   jobsite.co.uk
# 31918 2013-04-05 15:00:00 2013-07-04 15:00:00                   jobsite.co.uk
# 38053 2012-06-29 00:00:00 2012-08-28 00:00:00  jobs.catererandhotelkeeper.com
# 38137 2012-12-09 15:00:00 2013-01-08 15:00:00  jobs.catererandhotelkeeper.com
# 38185 2013-12-14 15:00:00 2014-02-12 15:00:00  jobs.catererandhotelkeeper.com
# 38290 2013-01-24 00:00:00 2013-02-07 00:00:00  jobs.catererandhotelkeeper.com
# 38478 2013-11-03 15:00:00 2014-01-02 15:00:00  jobs.catererandhotelkeeper.com
# 38654 2012-06-25 15:00:00 2012-07-09 15:00:00  jobs.catererandhotelkeeper.com
# 39081 2013-08-30 15:00:00 2013-10-29 15:00:00  jobs.catererandhotelkeeper.com
# 40928 2012-12-12 00:00:00 2013-02-10 00:00:00                  Jobcentre Plus

# %%
dot_company = df['Company'].str.contains(r'\.')
df[dot_company&~coal&~dp&~ckr]
# Out:
#              Id                                              Title  \
# 8128   71593642  Oracle Hr Functional Consultant/Oracle Ebusine...
# 9050   68627684               Oracle Hr Functional Support Analyst
# 9085   69574473  C Net Developer (Python, Scrum, Agile, Ibm Web...
# 13231  68693588                           Public Relations Officer
# 31159  67948117                               Process Metallurgist
# 34379  69675549  Hr Manager (Parttime) 3 Days A Week ( Flexi Wo...
# 34780  71885279               Solicitor/ Disciplinary Case Manager
# 35142  68838621                          Software Developer  Devon
# 37242  69188513     No Experience, No Problem New Roles In Bristol
# 39249  66537257                                      Kitchen Staff
# 39404  69768265                  Venues & Events Energy Consultant
# 39773  69769276                                     Sen Key Worker
# 39791  69554526                                 Membership Adviser
# 39866  68239749                Nursery Practitioner L****  Ooc****
# 39909  69766368     Software Development Project/Programme Manager
# 39974  69554894                           After School Club Worker
# 40127  69769301                             Preschool Practitioner
# 40420  68450122                      Skilled Senior Care Assistant
# 40620  69554720                            Fitness Service Manager
# 40872  68446046                    Baby Room Practitioner  Col****
# 40929  66750270                            Home Support Assistants
# 40986  69150243  Gas Technical Engineer (Breakdown And Repair) ...
# 41034  69554855                                 Learning Assistant
#
#             Location                                            Company  \
# 8128       Wiltshire  Sand Resources. A division of InterQuest Group...
# 9050       Wiltshire  Sand Resources. A division of InterQuest Group...
# 9085         Coscote  Sand Resources. A division of InterQuest Group...
# 13231             Uk                         St.Marys International Ltd
# 31159             Uk                                 www.dexternicholas
# 34379         London                            M. ARIA RECRUITMENT Ltd
# 34780         London                            M. ARIA RECRUITMENT Ltd
# 35142          Devon                                         Recruit.UK
# 37242             Uk                                    HelpMeGo.To Ltd
# 39249             Uk                                   J.D.Wetherspoons
# 39404        Evesham                                        E.on UK Plc
# 39773     Colchester                                   www.essex eyjobs
# 39791    Southampton                                        L.A Fitness
# 39866            Sea                                   www.essex eyjobs
# 39909     Nottingham                                        E.on UK Plc
# 39974     Chelmsford                                   www.essex eyjobs
# 40127     Colchester                                   www.essex eyjobs
# 40420         London  St.marys International Education and Employmen...
# 40620    Southampton                                        L.A Fitness
# 40872     Colchester                                   www.essex eyjobs
# 40929  North Shields                  At Home with...Helen McArdle Care
# 40986     Birmingham                                        E.on UK Plc
# 41034     Birmingham             St. Paul's Community Development Trust
#
#         ContractType   ContractTime                          Category Salary  \
# 8128   non-specified      permanent                           IT Jobs  45000
# 9050   non-specified      permanent                           IT Jobs  34000
# 9085   non-specified       contract                           IT Jobs  32500
# 13231  non-specified      permanent  PR, Advertising & Marketing Jobs  26000
# 31159  non-specified      permanent                  Engineering Jobs    NaN
# 34379      part_time      permanent                     Teaching Jobs  13522
# 34780      full_time      permanent                     Teaching Jobs  50000
# 35142      full_time      permanent                           IT Jobs  27500
# 37242  non-specified  non-specified                        Sales Jobs  15600
# 39249      part_time  non-specified       Hospitality & Catering Jobs  12480
# 39404      full_time  non-specified                        Sales Jobs  22812
# 39773      part_time  non-specified                     Teaching Jobs  14016
# 39791      full_time  non-specified                        Sales Jobs  14000
# 39866      full_time  non-specified                     Teaching Jobs  12480
# 39909      full_time  non-specified                           IT Jobs  58706
# 39974      part_time  non-specified                     Teaching Jobs  12480
# 40127      part_time  non-specified                     Teaching Jobs  14400
# 40420      full_time  non-specified         Healthcare & Nursing Jobs  14976
# 40620      full_time  non-specified                     Teaching Jobs  16000
# 40872      full_time  non-specified                     Teaching Jobs  13440
# 40929      full_time  non-specified         Healthcare & Nursing Jobs  14976
# 40986      full_time  non-specified                  Engineering Jobs  34760
# 41034      full_time  non-specified                     Teaching Jobs    NaN
#
#                  OpenDate           CloseDate           SourceName
# 8128  2013-07-22 12:00:00 2013-10-20 12:00:00         jobserve.com
# 9050  2013-03-26 12:00:00 2013-05-25 12:00:00         jobserve.com
# 9085  2013-05-17 12:00:00 2013-07-16 12:00:00         jobserve.com
# 13231 2013-10-06 00:00:00 2013-11-05 00:00:00        totaljobs.com
# 31159 2012-12-29 15:00:00 2013-01-28 15:00:00        jobsite.co.uk
# 34379 2013-09-06 12:00:00 2013-11-05 12:00:00  jobs.guardian.co.uk
# 34780 2013-02-18 00:00:00 2013-05-19 00:00:00  jobs.guardian.co.uk
# 35142 2013-05-07 15:00:00 2013-07-06 15:00:00    planetrecruit.com
# 37242 2012-05-09 00:00:00 2012-07-08 00:00:00    salestarget.co.uk
# 39249 2013-09-15 15:00:00 2013-09-29 15:00:00       Jobcentre Plus
# 39404 2012-01-30 00:00:00 2012-02-29 00:00:00       Jobcentre Plus
# 39773 2012-10-08 15:00:00 2012-10-22 15:00:00       Jobcentre Plus
# 39791 2012-06-08 12:00:00 2012-08-07 12:00:00       Jobcentre Plus
# 39866 2012-12-02 12:00:00 2013-03-02 12:00:00       Jobcentre Plus
# 39909 2013-11-02 00:00:00 2014-01-01 00:00:00       Jobcentre Plus
# 39974 2012-07-06 00:00:00 2012-08-05 00:00:00       Jobcentre Plus
# 40127 2013-08-28 00:00:00 2013-09-27 00:00:00       Jobcentre Plus
# 40420 2013-08-15 15:00:00 2013-10-14 15:00:00       Jobcentre Plus
# 40620 2012-09-17 15:00:00 2012-11-16 15:00:00       Jobcentre Plus
# 40872 2012-05-03 00:00:00 2012-08-01 00:00:00       Jobcentre Plus
# 40929 2013-08-22 15:00:00 2013-09-21 15:00:00       Jobcentre Plus
# 40986 2013-07-16 00:00:00 2013-08-15 00:00:00       Jobcentre Plus
# 41034 2012-01-29 00:00:00 2012-04-28 00:00:00       Jobcentre Plus

# %% [markdown]
# It seems like companies such as 'St.Marys..', 'HelpMeGo..', 'St. Paul's..' are correct.

# %%
w_dots_company = df['Company'].str.contains(r'\b([eE]\.?[oO]\.?[nN]|[mM]\.?\s?[aA]\.?[rR]\.?[iI]\.?[aA]\.?|[jJ]\.?[dD]\.?|[lL]\.?[A]\.?)\b')
df[w_dots_company]
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2328\2207887085.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   w_dots_company = df['Company'].str.contains(r'\b([eE]\.?[oO]\.?[nN]|[mM]\.?\s?[aA]\.?[rR]\.?[iI]\.?[aA]\.?|[jJ]\.?[dD]\.?|[lL]\.?[A]\.?)\b')
#              Id                                              Title  \
# 9289   72578110  Senior Oracle Dba/Database Administratornorth ...
# 21122  70783291                  Service Delivery Manager  Reigate
# 21313  72128277                                 Evaluation Analyst
# 21498  71565882           Network Architect  Ccie  The Netherlands
# 21907  72128112      Senior Windows Server Engineernorth Yorkshire
# 22473  72126374  Project Managers / Senior Project Managers  Lo...
# 30531  72688600                           Performance Test Analyst
# 31369  72248327  Document Controller, Systems Controller, Share...
# 32821  68806012  Solutions Architect  Surrey  **** , ****  ****...
# 32837  71856595  Network / Infrastructure Security Analystnorth...
# 34379  69675549  Hr Manager (Parttime) 3 Days A Week ( Flexi Wo...
# 34780  71885279               Solicitor/ Disciplinary Case Manager
# 34923  69472987                        Design Engineer/Unigraphics
# 34975  69895427  Reporting Analyst Data Anlyst Excel  Sc Cleare...
# 34988  55407890                          Software Quality Engineer
# 35038  55408474                                   Business Analyst
# 35174  69472992             F Dt/Stress Engineer/Aerospace/Bristol
# 35223  71740511  Net Software Developer  Aspnet, C, Vbnet  Ches...
# 39249  66537257                                      Kitchen Staff
# 39404  69768265                  Venues & Events Energy Consultant
# 39791  69554526                                 Membership Adviser
# 39909  69766368     Software Development Project/Programme Manager
# 40620  69554720                            Fitness Service Manager
# 40986  69150243  Gas Technical Engineer (Breakdown And Repair) ...
#
#                        Location                                    Company  \
# 9289   Yorkshire And Humberside  LA International Computer Consultants Ltd
# 21122                   Reigate                           LA International
# 21313                    London                           LA International
# 21498                        Uk                           LA International
# 21907           North Yorkshire                           LA International
# 22473                    London                           LA International
# 30531                    London  LA International Computer Consultants Ltd
# 31369                   Newbury  LA International Computer Consultants Ltd
# 32821                        Uk  LA International Computer Consultants Ltd
# 32837           North Yorkshire  LA International Computer Consultants Ltd
# 34379                    London                    M. ARIA RECRUITMENT Ltd
# 34780                    London                    M. ARIA RECRUITMENT Ltd
# 34923                      Avon  LA International Computer Consultants Ltd
# 34975                        Uk  LA International Computer Consultants Ltd
# 34988             Hertfordshire  LA International Computer Consultants Ltd
# 35038                      Avon  LA International Computer Consultants Ltd
# 35174                      Avon  LA International Computer Consultants Ltd
# 35223                  Cheshire  LA International Computer Consultants Ltd
# 39249                        Uk                           J.D.Wetherspoons
# 39404                   Evesham                                E.on UK Plc
# 39791               Southampton                                L.A Fitness
# 39909                Nottingham                                E.on UK Plc
# 40620               Southampton                                L.A Fitness
# 40986                Birmingham                                E.on UK Plc
#
#         ContractType   ContractTime                     Category Salary  \
# 9289   non-specified      permanent                      IT Jobs  42500
# 21122  non-specified      permanent                      IT Jobs  46000
# 21313  non-specified       contract                      IT Jobs  86400
# 21498  non-specified       contract                      IT Jobs  91326
# 21907  non-specified      permanent                      IT Jobs  31000
# 22473  non-specified      permanent                      IT Jobs  57500
# 30531  non-specified       contract                      IT Jobs  75000
# 31369  non-specified       contract                      IT Jobs  54000
# 32821  non-specified      permanent                      IT Jobs  55000
# 32837  non-specified      permanent                      IT Jobs  38500
# 34379      part_time      permanent                Teaching Jobs  13522
# 34780      full_time      permanent                Teaching Jobs  50000
# 34923      full_time       contract                      IT Jobs  60480
# 34975      full_time       contract                      IT Jobs  28800
# 34988      full_time       contract                      IT Jobs  53760
# 35038      full_time       contract                      IT Jobs  62400
# 35174      full_time       contract                      IT Jobs  74880
# 35223      full_time      permanent                      IT Jobs  29000
# 39249      part_time  non-specified  Hospitality & Catering Jobs  12480
# 39404      full_time  non-specified                   Sales Jobs  22812
# 39791      full_time  non-specified                   Sales Jobs  14000
# 39909      full_time  non-specified                      IT Jobs  58706
# 40620      full_time  non-specified                Teaching Jobs  16000
# 40986      full_time  non-specified             Engineering Jobs  34760
#
#                  OpenDate           CloseDate           SourceName
# 9289  2013-01-02 15:00:00 2013-02-01 15:00:00         jobserve.com
# 21122 2013-12-30 15:00:00 2014-01-29 15:00:00         cwjobs.co.uk
# 21313 2012-11-16 12:00:00 2012-11-30 12:00:00         cwjobs.co.uk
# 21498 2013-10-25 15:00:00 2013-11-24 15:00:00         cwjobs.co.uk
# 21907 2012-08-19 12:00:00 2012-11-17 12:00:00         cwjobs.co.uk
# 22473 2012-07-29 15:00:00 2012-10-27 15:00:00         cwjobs.co.uk
# 30531 2013-08-21 15:00:00 2013-10-20 15:00:00        jobsite.co.uk
# 31369 2013-03-17 15:00:00 2013-03-31 15:00:00        jobsite.co.uk
# 32821 2013-10-04 00:00:00 2013-11-03 00:00:00        jobsite.co.uk
# 32837 2012-02-07 12:00:00 2012-05-07 12:00:00        jobsite.co.uk
# 34379 2013-09-06 12:00:00 2013-11-05 12:00:00  jobs.guardian.co.uk
# 34780 2013-02-18 00:00:00 2013-05-19 00:00:00  jobs.guardian.co.uk
# 34923 2012-04-04 15:00:00 2012-07-03 15:00:00    planetrecruit.com
# 34975 2012-12-18 12:00:00 2013-03-18 12:00:00    planetrecruit.com
# 34988 2012-07-26 00:00:00 2012-09-24 00:00:00    planetrecruit.com
# 35038 2012-11-17 12:00:00 2013-02-15 12:00:00    planetrecruit.com
# 35174 2012-01-14 15:00:00 2012-04-13 15:00:00    planetrecruit.com
# 35223 2012-08-03 00:00:00 2012-09-02 00:00:00    planetrecruit.com
# 39249 2013-09-15 15:00:00 2013-09-29 15:00:00       Jobcentre Plus
# 39404 2012-01-30 00:00:00 2012-02-29 00:00:00       Jobcentre Plus
# 39791 2012-06-08 12:00:00 2012-08-07 12:00:00       Jobcentre Plus
# 39909 2013-11-02 00:00:00 2014-01-01 00:00:00       Jobcentre Plus
# 40620 2012-09-17 15:00:00 2012-11-16 15:00:00       Jobcentre Plus
# 40986 2013-07-16 00:00:00 2013-08-15 00:00:00       Jobcentre Plus

# %% [markdown]
# Looking at the values above, it seems like copanies with the above short forms are all unique. Thus, they are all kept as is

# %%
dot_company = df['Company'].str.contains(r'\.')
df[dot_company&~coal&~dp&~ckr&~w_dots_company]
# Out:
#              Id                                              Title  \
# 8128   71593642  Oracle Hr Functional Consultant/Oracle Ebusine...
# 9050   68627684               Oracle Hr Functional Support Analyst
# 9085   69574473  C Net Developer (Python, Scrum, Agile, Ibm Web...
# 13231  68693588                           Public Relations Officer
# 31159  67948117                               Process Metallurgist
# 35142  68838621                          Software Developer  Devon
# 37242  69188513     No Experience, No Problem New Roles In Bristol
# 39773  69769276                                     Sen Key Worker
# 39866  68239749                Nursery Practitioner L****  Ooc****
# 39974  69554894                           After School Club Worker
# 40127  69769301                             Preschool Practitioner
# 40420  68450122                      Skilled Senior Care Assistant
# 40872  68446046                    Baby Room Practitioner  Col****
# 40929  66750270                            Home Support Assistants
# 41034  69554855                                 Learning Assistant
#
#             Location                                            Company  \
# 8128       Wiltshire  Sand Resources. A division of InterQuest Group...
# 9050       Wiltshire  Sand Resources. A division of InterQuest Group...
# 9085         Coscote  Sand Resources. A division of InterQuest Group...
# 13231             Uk                         St.Marys International Ltd
# 31159             Uk                                 www.dexternicholas
# 35142          Devon                                         Recruit.UK
# 37242             Uk                                    HelpMeGo.To Ltd
# 39773     Colchester                                   www.essex eyjobs
# 39866            Sea                                   www.essex eyjobs
# 39974     Chelmsford                                   www.essex eyjobs
# 40127     Colchester                                   www.essex eyjobs
# 40420         London  St.marys International Education and Employmen...
# 40872     Colchester                                   www.essex eyjobs
# 40929  North Shields                  At Home with...Helen McArdle Care
# 41034     Birmingham             St. Paul's Community Development Trust
#
#         ContractType   ContractTime                          Category Salary  \
# 8128   non-specified      permanent                           IT Jobs  45000
# 9050   non-specified      permanent                           IT Jobs  34000
# 9085   non-specified       contract                           IT Jobs  32500
# 13231  non-specified      permanent  PR, Advertising & Marketing Jobs  26000
# 31159  non-specified      permanent                  Engineering Jobs    NaN
# 35142      full_time      permanent                           IT Jobs  27500
# 37242  non-specified  non-specified                        Sales Jobs  15600
# 39773      part_time  non-specified                     Teaching Jobs  14016
# 39866      full_time  non-specified                     Teaching Jobs  12480
# 39974      part_time  non-specified                     Teaching Jobs  12480
# 40127      part_time  non-specified                     Teaching Jobs  14400
# 40420      full_time  non-specified         Healthcare & Nursing Jobs  14976
# 40872      full_time  non-specified                     Teaching Jobs  13440
# 40929      full_time  non-specified         Healthcare & Nursing Jobs  14976
# 41034      full_time  non-specified                     Teaching Jobs    NaN
#
#                  OpenDate           CloseDate         SourceName
# 8128  2013-07-22 12:00:00 2013-10-20 12:00:00       jobserve.com
# 9050  2013-03-26 12:00:00 2013-05-25 12:00:00       jobserve.com
# 9085  2013-05-17 12:00:00 2013-07-16 12:00:00       jobserve.com
# 13231 2013-10-06 00:00:00 2013-11-05 00:00:00      totaljobs.com
# 31159 2012-12-29 15:00:00 2013-01-28 15:00:00      jobsite.co.uk
# 35142 2013-05-07 15:00:00 2013-07-06 15:00:00  planetrecruit.com
# 37242 2012-05-09 00:00:00 2012-07-08 00:00:00  salestarget.co.uk
# 39773 2012-10-08 15:00:00 2012-10-22 15:00:00     Jobcentre Plus
# 39866 2012-12-02 12:00:00 2013-03-02 12:00:00     Jobcentre Plus
# 39974 2012-07-06 00:00:00 2012-08-05 00:00:00     Jobcentre Plus
# 40127 2013-08-28 00:00:00 2013-09-27 00:00:00     Jobcentre Plus
# 40420 2013-08-15 15:00:00 2013-10-14 15:00:00     Jobcentre Plus
# 40872 2012-05-03 00:00:00 2012-08-01 00:00:00     Jobcentre Plus
# 40929 2013-08-22 15:00:00 2013-09-21 15:00:00     Jobcentre Plus
# 41034 2012-01-29 00:00:00 2012-04-28 00:00:00     Jobcentre Plus

# %% [markdown]
# Continuing on our search, it seems like some of the companies start with www.. Since .com and .net is removed, these would be removed as well

# %%
www_company = df['Company'].str.contains(r'^[wW]{3}\.?')
df[www_company]
# Out:
#              Id                                Title    Location  \
# 31159  67948117                 Process Metallurgist          Uk
# 39773  69769276                       Sen Key Worker  Colchester
# 39866  68239749  Nursery Practitioner L****  Ooc****         Sea
# 39974  69554894             After School Club Worker  Chelmsford
# 40127  69769301               Preschool Practitioner  Colchester
# 40872  68446046      Baby Room Practitioner  Col****  Colchester
#
#                   Company   ContractType   ContractTime          Category  \
# 31159  www.dexternicholas  non-specified      permanent  Engineering Jobs
# 39773    www.essex eyjobs      part_time  non-specified     Teaching Jobs
# 39866    www.essex eyjobs      full_time  non-specified     Teaching Jobs
# 39974    www.essex eyjobs      part_time  non-specified     Teaching Jobs
# 40127    www.essex eyjobs      part_time  non-specified     Teaching Jobs
# 40872    www.essex eyjobs      full_time  non-specified     Teaching Jobs
#
#       Salary            OpenDate           CloseDate      SourceName
# 31159    NaN 2012-12-29 15:00:00 2013-01-28 15:00:00   jobsite.co.uk
# 39773  14016 2012-10-08 15:00:00 2012-10-22 15:00:00  Jobcentre Plus
# 39866  12480 2012-12-02 12:00:00 2013-03-02 12:00:00  Jobcentre Plus
# 39974  12480 2012-07-06 00:00:00 2012-08-05 00:00:00  Jobcentre Plus
# 40127  14400 2013-08-28 00:00:00 2013-09-27 00:00:00  Jobcentre Plus
# 40872  13440 2012-05-03 00:00:00 2012-08-01 00:00:00  Jobcentre Plus

# %%
indices = list(df[www_company].index)
for ind in indices:
    old = df['Company'][ind]
    # Get the www.
    www = re.search(r'^([wW]{3}\.?)',old).groups()[0]
    # Replace with none
    new = old.replace(www,'')
    # Record to errorDict
    errorDict = addToErrorDict(errorDict,ind,df['Id'][ind],'Company',old,new,'Starts with www','Remove the www')
    # Replace old value with the new value
    df.loc[ind,'Company'] = new
df[www_company]
# Out:
#              Id                                Title    Location  \
# 31159  67948117                 Process Metallurgist          Uk
# 39773  69769276                       Sen Key Worker  Colchester
# 39866  68239749  Nursery Practitioner L****  Ooc****         Sea
# 39974  69554894             After School Club Worker  Chelmsford
# 40127  69769301               Preschool Practitioner  Colchester
# 40872  68446046      Baby Room Practitioner  Col****  Colchester
#
#               Company   ContractType   ContractTime          Category Salary  \
# 31159  dexternicholas  non-specified      permanent  Engineering Jobs    NaN
# 39773    essex eyjobs      part_time  non-specified     Teaching Jobs  14016
# 39866    essex eyjobs      full_time  non-specified     Teaching Jobs  12480
# 39974    essex eyjobs      part_time  non-specified     Teaching Jobs  12480
# 40127    essex eyjobs      part_time  non-specified     Teaching Jobs  14400
# 40872    essex eyjobs      full_time  non-specified     Teaching Jobs  13440
#
#                  OpenDate           CloseDate      SourceName
# 31159 2012-12-29 15:00:00 2013-01-28 15:00:00   jobsite.co.uk
# 39773 2012-10-08 15:00:00 2012-10-22 15:00:00  Jobcentre Plus
# 39866 2012-12-02 12:00:00 2013-03-02 12:00:00  Jobcentre Plus
# 39974 2012-07-06 00:00:00 2012-08-05 00:00:00  Jobcentre Plus
# 40127 2013-08-28 00:00:00 2013-09-27 00:00:00  Jobcentre Plus
# 40872 2012-05-03 00:00:00 2012-08-01 00:00:00  Jobcentre Plus

# %%
dot_company = df['Company'].str.contains(r'\.')
df[dot_company&~coal&~dp&~ckr]
# Out:
#              Id                                              Title  \
# 8128   71593642  Oracle Hr Functional Consultant/Oracle Ebusine...
# 9050   68627684               Oracle Hr Functional Support Analyst
# 9085   69574473  C Net Developer (Python, Scrum, Agile, Ibm Web...
# 13231  68693588                           Public Relations Officer
# 34379  69675549  Hr Manager (Parttime) 3 Days A Week ( Flexi Wo...
# 34780  71885279               Solicitor/ Disciplinary Case Manager
# 35142  68838621                          Software Developer  Devon
# 37242  69188513     No Experience, No Problem New Roles In Bristol
# 39249  66537257                                      Kitchen Staff
# 39404  69768265                  Venues & Events Energy Consultant
# 39791  69554526                                 Membership Adviser
# 39909  69766368     Software Development Project/Programme Manager
# 40420  68450122                      Skilled Senior Care Assistant
# 40620  69554720                            Fitness Service Manager
# 40929  66750270                            Home Support Assistants
# 40986  69150243  Gas Technical Engineer (Breakdown And Repair) ...
# 41034  69554855                                 Learning Assistant
#
#             Location                                            Company  \
# 8128       Wiltshire  Sand Resources. A division of InterQuest Group...
# 9050       Wiltshire  Sand Resources. A division of InterQuest Group...
# 9085         Coscote  Sand Resources. A division of InterQuest Group...
# 13231             Uk                         St.Marys International Ltd
# 34379         London                            M. ARIA RECRUITMENT Ltd
# 34780         London                            M. ARIA RECRUITMENT Ltd
# 35142          Devon                                         Recruit.UK
# 37242             Uk                                    HelpMeGo.To Ltd
# 39249             Uk                                   J.D.Wetherspoons
# 39404        Evesham                                        E.on UK Plc
# 39791    Southampton                                        L.A Fitness
# 39909     Nottingham                                        E.on UK Plc
# 40420         London  St.marys International Education and Employmen...
# 40620    Southampton                                        L.A Fitness
# 40929  North Shields                  At Home with...Helen McArdle Care
# 40986     Birmingham                                        E.on UK Plc
# 41034     Birmingham             St. Paul's Community Development Trust
#
#         ContractType   ContractTime                          Category Salary  \
# 8128   non-specified      permanent                           IT Jobs  45000
# 9050   non-specified      permanent                           IT Jobs  34000
# 9085   non-specified       contract                           IT Jobs  32500
# 13231  non-specified      permanent  PR, Advertising & Marketing Jobs  26000
# 34379      part_time      permanent                     Teaching Jobs  13522
# 34780      full_time      permanent                     Teaching Jobs  50000
# 35142      full_time      permanent                           IT Jobs  27500
# 37242  non-specified  non-specified                        Sales Jobs  15600
# 39249      part_time  non-specified       Hospitality & Catering Jobs  12480
# 39404      full_time  non-specified                        Sales Jobs  22812
# 39791      full_time  non-specified                        Sales Jobs  14000
# 39909      full_time  non-specified                           IT Jobs  58706
# 40420      full_time  non-specified         Healthcare & Nursing Jobs  14976
# 40620      full_time  non-specified                     Teaching Jobs  16000
# 40929      full_time  non-specified         Healthcare & Nursing Jobs  14976
# 40986      full_time  non-specified                  Engineering Jobs  34760
# 41034      full_time  non-specified                     Teaching Jobs    NaN
#
#                  OpenDate           CloseDate           SourceName
# 8128  2013-07-22 12:00:00 2013-10-20 12:00:00         jobserve.com
# 9050  2013-03-26 12:00:00 2013-05-25 12:00:00         jobserve.com
# 9085  2013-05-17 12:00:00 2013-07-16 12:00:00         jobserve.com
# 13231 2013-10-06 00:00:00 2013-11-05 00:00:00        totaljobs.com
# 34379 2013-09-06 12:00:00 2013-11-05 12:00:00  jobs.guardian.co.uk
# 34780 2013-02-18 00:00:00 2013-05-19 00:00:00  jobs.guardian.co.uk
# 35142 2013-05-07 15:00:00 2013-07-06 15:00:00    planetrecruit.com
# 37242 2012-05-09 00:00:00 2012-07-08 00:00:00    salestarget.co.uk
# 39249 2013-09-15 15:00:00 2013-09-29 15:00:00       Jobcentre Plus
# 39404 2012-01-30 00:00:00 2012-02-29 00:00:00       Jobcentre Plus
# 39791 2012-06-08 12:00:00 2012-08-07 12:00:00       Jobcentre Plus
# 39909 2013-11-02 00:00:00 2014-01-01 00:00:00       Jobcentre Plus
# 40420 2013-08-15 15:00:00 2013-10-14 15:00:00       Jobcentre Plus
# 40620 2012-09-17 15:00:00 2012-11-16 15:00:00       Jobcentre Plus
# 40929 2013-08-22 15:00:00 2013-09-21 15:00:00       Jobcentre Plus
# 40986 2013-07-16 00:00:00 2013-08-15 00:00:00       Jobcentre Plus
# 41034 2012-01-29 00:00:00 2012-04-28 00:00:00       Jobcentre Plus

# %% [markdown]
# It looks like there is this Sand Resource company with a lot of information at the back

# %%
sand = df['Company'].str.contains(r'[sS]and\s[rR]esource')
df[sand]
# Out:
#             Id                                              Title   Location  \
# 8128  71593642  Oracle Hr Functional Consultant/Oracle Ebusine...  Wiltshire
# 9050  68627684               Oracle Hr Functional Support Analyst  Wiltshire
# 9085  69574473  C Net Developer (Python, Scrum, Agile, Ibm Web...    Coscote
#
#                                                 Company   ContractType  \
# 8128  Sand Resources. A division of InterQuest Group...  non-specified
# 9050  Sand Resources. A division of InterQuest Group...  non-specified
# 9085  Sand Resources. A division of InterQuest Group...  non-specified
#
#      ContractTime Category Salary            OpenDate           CloseDate  \
# 8128    permanent  IT Jobs  45000 2013-07-22 12:00:00 2013-10-20 12:00:00
# 9050    permanent  IT Jobs  34000 2013-03-26 12:00:00 2013-05-25 12:00:00
# 9085     contract  IT Jobs  32500 2013-05-17 12:00:00 2013-07-16 12:00:00
#
#         SourceName
# 8128  jobserve.com
# 9050  jobserve.com
# 9085  jobserve.com

# %% [markdown]
# It seems like these 'Sand Resources..' could be written as 'Sand Resources'

# %%
indices = list(df[sand].index)
for ind in indices:
    # Record to errorDict
    errorDict = addToErrorDict(errorDict,ind,df['Id'][ind],'Company',df['Company'][ind],'Sand Resources','Extra information','Removed extra information')
    # Replace company name with only Sand Resources
    df.loc[ind,'Company'] = 'Sand Resources'
df[sand]
# Out:
#             Id                                              Title   Location  \
# 8128  71593642  Oracle Hr Functional Consultant/Oracle Ebusine...  Wiltshire
# 9050  68627684               Oracle Hr Functional Support Analyst  Wiltshire
# 9085  69574473  C Net Developer (Python, Scrum, Agile, Ibm Web...    Coscote
#
#              Company   ContractType ContractTime Category Salary  \
# 8128  Sand Resources  non-specified    permanent  IT Jobs  45000
# 9050  Sand Resources  non-specified    permanent  IT Jobs  34000
# 9085  Sand Resources  non-specified     contract  IT Jobs  32500
#
#                 OpenDate           CloseDate    SourceName
# 8128 2013-07-22 12:00:00 2013-10-20 12:00:00  jobserve.com
# 9050 2013-03-26 12:00:00 2013-05-25 12:00:00  jobserve.com
# 9085 2013-05-17 12:00:00 2013-07-16 12:00:00  jobserve.com

# %%
df[sand]
# Out:
#             Id                                              Title   Location  \
# 8128  71593642  Oracle Hr Functional Consultant/Oracle Ebusine...  Wiltshire
# 9050  68627684               Oracle Hr Functional Support Analyst  Wiltshire
# 9085  69574473  C Net Developer (Python, Scrum, Agile, Ibm Web...    Coscote
#
#              Company   ContractType ContractTime Category Salary  \
# 8128  Sand Resources  non-specified    permanent  IT Jobs  45000
# 9050  Sand Resources  non-specified    permanent  IT Jobs  34000
# 9085  Sand Resources  non-specified     contract  IT Jobs  32500
#
#                 OpenDate           CloseDate    SourceName
# 8128 2013-07-22 12:00:00 2013-10-20 12:00:00  jobserve.com
# 9050 2013-03-26 12:00:00 2013-05-25 12:00:00  jobserve.com
# 9085 2013-05-17 12:00:00 2013-07-16 12:00:00  jobserve.com

# %%
dot_company = df['Company'].str.contains(r'\.')
df[dot_company&~coal&~dp&~ckr]
# Out:
#              Id                                              Title  \
# 13231  68693588                           Public Relations Officer
# 34379  69675549  Hr Manager (Parttime) 3 Days A Week ( Flexi Wo...
# 34780  71885279               Solicitor/ Disciplinary Case Manager
# 35142  68838621                          Software Developer  Devon
# 37242  69188513     No Experience, No Problem New Roles In Bristol
# 39249  66537257                                      Kitchen Staff
# 39404  69768265                  Venues & Events Energy Consultant
# 39791  69554526                                 Membership Adviser
# 39909  69766368     Software Development Project/Programme Manager
# 40420  68450122                      Skilled Senior Care Assistant
# 40620  69554720                            Fitness Service Manager
# 40929  66750270                            Home Support Assistants
# 40986  69150243  Gas Technical Engineer (Breakdown And Repair) ...
# 41034  69554855                                 Learning Assistant
#
#             Location                                            Company  \
# 13231             Uk                         St.Marys International Ltd
# 34379         London                            M. ARIA RECRUITMENT Ltd
# 34780         London                            M. ARIA RECRUITMENT Ltd
# 35142          Devon                                         Recruit.UK
# 37242             Uk                                    HelpMeGo.To Ltd
# 39249             Uk                                   J.D.Wetherspoons
# 39404        Evesham                                        E.on UK Plc
# 39791    Southampton                                        L.A Fitness
# 39909     Nottingham                                        E.on UK Plc
# 40420         London  St.marys International Education and Employmen...
# 40620    Southampton                                        L.A Fitness
# 40929  North Shields                  At Home with...Helen McArdle Care
# 40986     Birmingham                                        E.on UK Plc
# 41034     Birmingham             St. Paul's Community Development Trust
#
#         ContractType   ContractTime                          Category Salary  \
# 13231  non-specified      permanent  PR, Advertising & Marketing Jobs  26000
# 34379      part_time      permanent                     Teaching Jobs  13522
# 34780      full_time      permanent                     Teaching Jobs  50000
# 35142      full_time      permanent                           IT Jobs  27500
# 37242  non-specified  non-specified                        Sales Jobs  15600
# 39249      part_time  non-specified       Hospitality & Catering Jobs  12480
# 39404      full_time  non-specified                        Sales Jobs  22812
# 39791      full_time  non-specified                        Sales Jobs  14000
# 39909      full_time  non-specified                           IT Jobs  58706
# 40420      full_time  non-specified         Healthcare & Nursing Jobs  14976
# 40620      full_time  non-specified                     Teaching Jobs  16000
# 40929      full_time  non-specified         Healthcare & Nursing Jobs  14976
# 40986      full_time  non-specified                  Engineering Jobs  34760
# 41034      full_time  non-specified                     Teaching Jobs    NaN
#
#                  OpenDate           CloseDate           SourceName
# 13231 2013-10-06 00:00:00 2013-11-05 00:00:00        totaljobs.com
# 34379 2013-09-06 12:00:00 2013-11-05 12:00:00  jobs.guardian.co.uk
# 34780 2013-02-18 00:00:00 2013-05-19 00:00:00  jobs.guardian.co.uk
# 35142 2013-05-07 15:00:00 2013-07-06 15:00:00    planetrecruit.com
# 37242 2012-05-09 00:00:00 2012-07-08 00:00:00    salestarget.co.uk
# 39249 2013-09-15 15:00:00 2013-09-29 15:00:00       Jobcentre Plus
# 39404 2012-01-30 00:00:00 2012-02-29 00:00:00       Jobcentre Plus
# 39791 2012-06-08 12:00:00 2012-08-07 12:00:00       Jobcentre Plus
# 39909 2013-11-02 00:00:00 2014-01-01 00:00:00       Jobcentre Plus
# 40420 2013-08-15 15:00:00 2013-10-14 15:00:00       Jobcentre Plus
# 40620 2012-09-17 15:00:00 2012-11-16 15:00:00       Jobcentre Plus
# 40929 2013-08-22 15:00:00 2013-09-21 15:00:00       Jobcentre Plus
# 40986 2013-07-16 00:00:00 2013-08-15 00:00:00       Jobcentre Plus
# 41034 2012-01-29 00:00:00 2012-04-28 00:00:00       Jobcentre Plus

# %% [markdown]
# Seems like we are done with the Company Column!

# %% [markdown]
# Do some last formatting

# %%
# Record to errorDict for capitalizing each word except for the value 'non-specified'
errorDict = addToErrorDict(errorDict,'ALL','ALL','Company','word','Word','Messy capitalization and white spaces','Capitalize each word and trim white spaces')
df['Company'] = df['Company'].apply(lambda x: x.title().strip() if (x != 'non-specified') else 'non-specified')
df['Company']
# Out:
# 0           Resourcing Solutions
# 1        Orleston Associates Ltd
# 2                       Randstad
# 3                       Randstad
# 4                       Randstad
#                   ...
# 50748                       Gchq
# 50749                    Unknown
# 50750                   Barclays
# 50751        Carrington West Ltd
# 50752       Pursuit Training Ltd
# Name: Company, Length: 50750, dtype: object

# %% [markdown]
# There is still one company labelled as unknown

# %%
unknown = df['Company'] == 'Unknown'
indices = list(df[unknown].index)
for ind in indices:
    # Record to errorDict
    errorDict = addToErrorDict(errorDict,ind,df['Id'][ind],'Company','Unknown','non-specified','Name labeled as unknown','Set to non-specified')
    df.loc[ind,'Company'] = 'non-specified'
df['Company']
# Out:
# 0           Resourcing Solutions
# 1        Orleston Associates Ltd
# 2                       Randstad
# 3                       Randstad
# 4                       Randstad
#                   ...
# 50748                       Gchq
# 50749              non-specified
# 50750                   Barclays
# 50751        Carrington West Ltd
# 50752       Pursuit Training Ltd
# Name: Company, Length: 50750, dtype: object

# %% [markdown]
# Here, we are done with cleaning and formatting Company column.

# %% [markdown]
# Now, it is time to check the data for the Salary column.

# %% [markdown]
# ### Task 2.10 Examining and Cleaning Salary Column

# %%
df['Salary'].describe()
# Out:
# count     50113
# unique     3466
# top       35000
# freq       1706
# Name: Salary, dtype: object

# %% [markdown]
# From the output above, it seems that in the dataset, Salary column has nominal values! The column would be converted into numeric.

# %%
try:
    # Try converting to numeric to see if it's possible
    df['Salary'] = pd.to_numeric(df['Salary'])
except Exception as e:
    print(e)
# Out:
# Unable to parse string "36K" at position 12

# %% [markdown]
# It seems like there are some non-digit values within the column. Thus, some cleaning is done before evaluating the values

# %%
null_salary = df['Salary'].isna()
df[null_salary]
# Out:
#              Id                                              Title  \
# 5      67944712                        Theatre Lead/Deputy Manager
# 7      68346203  Test Analyst  Join A Leading Fund Manager  Ess...
# 17     70519783                  Water Quality Engineer  Middlesex
# 69     67945892                 Senior Structural Engineer  London
# 131    66905220                   Business Development Manager  Fm
# ...         ...                                                ...
# 50705  70417262  Coventure Graduate Scheme  Asset Management, H...
# 50722  72179080          Business Intelligence Solutions Architect
# 50726  68718953                        Trainee Broker Ote Uncapped
# 50727  71802817                              Tax Reporting Manager
# 50749  72420369              Graduate Operations Technical Analyst
#
#              Location                  Company   ContractType   ContractTime  \
# 5                  Uk  Orleston Associates Ltd  non-specified  non-specified
# 7               Essex                 Randstad  non-specified      permanent
# 17                 Uk                 Randstad  non-specified      permanent
# 69             London                 Randstad  non-specified      permanent
# 131    Leicestershire            Fusion People  non-specified      permanent
# ...               ...                      ...            ...            ...
# 50705              Uk               Co Venture  non-specified  non-specified
# 50722          London         Selecture Global  non-specified      permanent
# 50726          London            One Two Trade  non-specified      permanent
# 50727          London          Integral Search  non-specified      permanent
# 50749      Hungerford            non-specified  non-specified  non-specified
#
#                         Category Salary            OpenDate  \
# 5               Engineering Jobs    NaN 2012-04-24 00:00:00
# 7               Engineering Jobs    NaN 2013-04-12 00:00:00
# 17              Engineering Jobs    NaN 2013-12-14 00:00:00
# 69              Engineering Jobs    NaN 2013-04-04 15:00:00
# 131             Engineering Jobs    NaN 2013-07-31 12:00:00
# ...                          ...    ...                 ...
# 50705                 Sales Jobs    NaN 2013-03-01 00:00:00
# 50722  Accounting & Finance Jobs    NaN 2013-09-19 00:00:00
# 50726  Accounting & Finance Jobs    NaN 2013-09-22 12:00:00
# 50727  Accounting & Finance Jobs    NaN 2013-02-22 12:00:00
# 50749                    IT Jobs    NaN 2013-09-13 15:00:00
#
#                 CloseDate              SourceName
# 5     2012-05-24 00:00:00    rengineeringjobs.com
# 7     2013-06-11 00:00:00    rengineeringjobs.com
# 17    2014-01-13 00:00:00    rengineeringjobs.com
# 69    2013-06-03 15:00:00    rengineeringjobs.com
# 131   2013-08-30 12:00:00    rengineeringjobs.com
# ...                   ...                     ...
# 50705 2013-03-15 00:00:00           wikijob.co.uk
# 50722 2013-12-18 00:00:00  frontofficebanking.com
# 50726 2013-10-22 12:00:00  frontofficebanking.com
# 50727 2013-04-23 12:00:00  frontofficebanking.com
# 50749 2013-11-12 15:00:00              grb.uk.com
#
# [637 rows x 11 columns]

# %% [markdown]
# From the output above it can be seen that there are null values for Salary. These values would be kept for further evaluation

# %%
# Get salaries that does not contain digits
salary_w_digit = df[~null_salary]['Salary'].str.match('\d+',na=False)
df[~null_salary][~salary_w_digit]
# Out:
#              Id                                              Title  \
# 719    66921939     Systems Support Engineer  Derby, East Midlands
# 741    69012173         Staff Nurse, Elderly Nursing Home, Taunton
# 772    71296009          Research Development Manager  Hosiery Exp
# 788    65880148                  Internal Sales Director Elearning
# 820    69079710               Civil / Structural Maritime Engineer
# ...         ...                                                ...
# 50452  71109346            **** Month Ap/Treasury Manager Contract
# 50482  71073530           Engineering Quality Auditor  Calibration
# 50491  72579991  Finance Analyst  ****K Pa  Central Bristol  Pe...
# 50551  71041572                                     Metals Analyst
# 50710  68390860            Cto/It Director/Cio/ Technical Director
#
#                  Location                          Company   ContractType  \
# 719                 Derby          V Selective Recruitment  non-specified
# 741               Taunton            White Recruitment Ltd  non-specified
# 772         West Midlands          Interaction Recruitment  non-specified
# 788    South West England          Aarca Sales Recruitment  non-specified
# 820                London  Energi Recruitment Services Ltd  non-specified
# ...                   ...                              ...            ...
# 50452         West London                    Investigo Ltd      full_time
# 50482      West Yorkshire            Informatiq Consulting      full_time
# 50491                Avon                  Morgan Mckinley      full_time
# 50551              London                            Jobg8      full_time
# 50710             Reading                Eligo Recruitment      full_time
#
#         ContractTime                   Category Salary            OpenDate  \
# 719        permanent                    IT Jobs        2013-07-09 00:00:00
# 741        permanent  Healthcare & Nursing Jobs        2013-01-14 00:00:00
# 772        permanent  Healthcare & Nursing Jobs        2013-07-27 15:00:00
# 788        permanent                 Sales Jobs        2012-06-29 00:00:00
# 820        permanent           Engineering Jobs        2013-12-21 15:00:00
# ...              ...                        ...    ...                 ...
# 50452       contract  Accounting & Finance Jobs        2013-08-16 00:00:00
# 50482      permanent           Engineering Jobs        2013-11-23 15:00:00
# 50491      permanent  Accounting & Finance Jobs        2013-05-09 00:00:00
# 50551      permanent  Accounting & Finance Jobs      - 2012-05-19 00:00:00
# 50710  non-specified                    IT Jobs        2012-05-01 00:00:00
#
#                 CloseDate             SourceName
# 719   2013-08-08 00:00:00       cv-library.co.uk
# 741   2013-04-14 00:00:00       cv-library.co.uk
# 772   2013-09-25 15:00:00       cv-library.co.uk
# 788   2012-07-29 00:00:00       cv-library.co.uk
# 820   2014-03-21 15:00:00       cv-library.co.uk
# ...                   ...                    ...
# 50452 2013-11-14 00:00:00  myjobs.cimaglobal.com
# 50482 2014-01-22 15:00:00              JobSearch
# 50491 2013-08-07 00:00:00              JobSearch
# 50551 2012-06-18 00:00:00         JustLondonJobs
# 50710 2012-06-30 00:00:00          jobs.perl.org
#
# [847 rows x 11 columns]

# %% [markdown]
# From above it can be seen that other than missing values, there are also some other values that only contains values like "-" and " ". All these values would be set to none as well

# %%
for ind in list(df[~null_salary][~salary_w_digit].index):
    # Record to errorDict
    errorDict = addToErrorDict(errorDict,ind,df['Id'][ind],'Salary','Not digit values','None','Missing Value','Convert dummy values to None')

# Replace nan and non-digit salaries with None
df.loc[null_salary,'Salary'] = None
df.loc[~null_salary&~salary_w_digit,'Salary'] = None
df[df['Salary'].isna()]
# Out:
#              Id                                              Title  \
# 5      67944712                        Theatre Lead/Deputy Manager
# 7      68346203  Test Analyst  Join A Leading Fund Manager  Ess...
# 17     70519783                  Water Quality Engineer  Middlesex
# 69     67945892                 Senior Structural Engineer  London
# 131    66905220                   Business Development Manager  Fm
# ...         ...                                                ...
# 50710  68390860            Cto/It Director/Cio/ Technical Director
# 50722  72179080          Business Intelligence Solutions Architect
# 50726  68718953                        Trainee Broker Ote Uncapped
# 50727  71802817                              Tax Reporting Manager
# 50749  72420369              Graduate Operations Technical Analyst
#
#              Location                  Company   ContractType   ContractTime  \
# 5                  Uk  Orleston Associates Ltd  non-specified  non-specified
# 7               Essex                 Randstad  non-specified      permanent
# 17                 Uk                 Randstad  non-specified      permanent
# 69             London                 Randstad  non-specified      permanent
# 131    Leicestershire            Fusion People  non-specified      permanent
# ...               ...                      ...            ...            ...
# 50710         Reading        Eligo Recruitment      full_time  non-specified
# 50722          London         Selecture Global  non-specified      permanent
# 50726          London            One Two Trade  non-specified      permanent
# 50727          London          Integral Search  non-specified      permanent
# 50749      Hungerford            non-specified  non-specified  non-specified
#
#                         Category Salary            OpenDate  \
# 5               Engineering Jobs   None 2012-04-24 00:00:00
# 7               Engineering Jobs   None 2013-04-12 00:00:00
# 17              Engineering Jobs   None 2013-12-14 00:00:00
# 69              Engineering Jobs   None 2013-04-04 15:00:00
# 131             Engineering Jobs   None 2013-07-31 12:00:00
# ...                          ...    ...                 ...
# 50710                    IT Jobs   None 2012-05-01 00:00:00
# 50722  Accounting & Finance Jobs   None 2013-09-19 00:00:00
# 50726  Accounting & Finance Jobs   None 2013-09-22 12:00:00
# 50727  Accounting & Finance Jobs   None 2013-02-22 12:00:00
# 50749                    IT Jobs   None 2013-09-13 15:00:00
#
#                 CloseDate              SourceName
# 5     2012-05-24 00:00:00    rengineeringjobs.com
# 7     2013-06-11 00:00:00    rengineeringjobs.com
# 17    2014-01-13 00:00:00    rengineeringjobs.com
# 69    2013-06-03 15:00:00    rengineeringjobs.com
# 131   2013-08-30 12:00:00    rengineeringjobs.com
# ...                   ...                     ...
# 50710 2012-06-30 00:00:00           jobs.perl.org
# 50722 2013-12-18 00:00:00  frontofficebanking.com
# 50726 2013-10-22 12:00:00  frontofficebanking.com
# 50727 2013-04-23 12:00:00  frontofficebanking.com
# 50749 2013-11-12 15:00:00              grb.uk.com
#
# [1484 rows x 11 columns]

# %% [markdown]
# Now that dummy values are set as None, it is time to check for invalid values

# %%
# Get salary that is 0
salary_is_0 = df['Salary'].str.fullmatch('0',na=False)
df[salary_is_0]
# Out:
#              Id                                             Title  \
# 10453  68712324                Private Client Director  Guildford
# 10461  68068322           Clinical Nurse Manager (Rn)  Barchester
# 10503  71680705                  Ppc Client Manager (Entry Level)
# 10513  72445032                Contract Manager / Project Manager
# 10524  68064583               Exclusive  Qualified Social Workers
# ...         ...                                               ...
# 50567  70086312                          Assistant Wealth Manager
# 50573  68511191   Financial Planner  International Eb Consultancy
# 50580  68511163           Office Based Mortgage Broker, Cambridge
# 50737  69693532           Locum Gp With Potential For Partnership
# 50744  71280413  Project Manager / Payments (Essential) / Watford
#
#                 Location                   Company   ContractType  \
# 10453          Guildford     Pro Recruitment Group  non-specified
# 10461            Ashford     Barchester Healthcare  non-specified
# 10503  South East London                    Propel  non-specified
# 10513         Winchester        Red Kite Selection  non-specified
# 10524            Lincoln  Action First Recruitment  non-specified
# ...                  ...                       ...            ...
# 50567             London             Roland Dowell  non-specified
# 50573           The City             Roland Dowell  non-specified
# 50580          Cambridge              Morris Jones  non-specified
# 50737                 Uk   Mayfield Medical Centre      part_time
# 50744                 Uk                       Rdf  non-specified
#
#         ContractTime                          Category Salary  \
# 10453      permanent         Accounting & Finance Jobs      0
# 10461      permanent         Healthcare & Nursing Jobs      0
# 10503      permanent  PR, Advertising & Marketing Jobs      0
# 10513      permanent                  Engineering Jobs      0
# 10524      permanent         Healthcare & Nursing Jobs      0
# ...              ...                               ...    ...
# 50567      permanent         Accounting & Finance Jobs      0
# 50573      permanent         Accounting & Finance Jobs      0
# 50580      permanent         Accounting & Finance Jobs      0
# 50737  non-specified         Healthcare & Nursing Jobs      0
# 50744      permanent                           IT Jobs      0
#
#                  OpenDate           CloseDate              SourceName
# 10453 2013-04-20 00:00:00 2013-07-19 00:00:00           totaljobs.com
# 10461 2013-09-04 12:00:00 2013-12-03 12:00:00           totaljobs.com
# 10503 2012-12-15 15:00:00 2013-03-15 15:00:00           totaljobs.com
# 10513 2012-08-26 15:00:00 2012-10-25 15:00:00           totaljobs.com
# 10524 2013-08-15 12:00:00 2013-09-14 12:00:00           totaljobs.com
# ...                   ...                 ...                     ...
# 50567 2012-03-13 12:00:00 2012-06-11 12:00:00     ifaonlinejobs.co.uk
# 50573 2012-07-11 00:00:00 2012-08-10 00:00:00     ifaonlinejobs.co.uk
# 50580 2012-12-16 15:00:00 2013-01-15 15:00:00     ifaonlinejobs.co.uk
# 50737 2013-01-06 12:00:00 2013-01-20 12:00:00       jobs.gponline.com
# 50744 2013-10-05 15:00:00 2013-11-04 15:00:00  cardandpaymentjobs.com
#
# [1013 rows x 11 columns]

# %% [markdown]
# It can also be seen that some Salary is set as 0, since these are all jobs and not volunteering events, every salary should be more than 0! These data would be set to None as well

# %%
for ind in df[salary_is_0].index:
    # Record to errorDict
    errorDict = addToErrorDict(errorDict,ind,df['Id'][ind],'Salary','0','None','Value is 0','Set from 0 to None instread')

# Replace those values with none
df.loc[salary_is_0,'Salary'] = None
df[df['Salary'].isna()]
# Out:
#              Id                                              Title  \
# 5      67944712                        Theatre Lead/Deputy Manager
# 7      68346203  Test Analyst  Join A Leading Fund Manager  Ess...
# 17     70519783                  Water Quality Engineer  Middlesex
# 69     67945892                 Senior Structural Engineer  London
# 131    66905220                   Business Development Manager  Fm
# ...         ...                                                ...
# 50726  68718953                        Trainee Broker Ote Uncapped
# 50727  71802817                              Tax Reporting Manager
# 50737  69693532            Locum Gp With Potential For Partnership
# 50744  71280413   Project Manager / Payments (Essential) / Watford
# 50749  72420369              Graduate Operations Technical Analyst
#
#              Location                  Company   ContractType   ContractTime  \
# 5                  Uk  Orleston Associates Ltd  non-specified  non-specified
# 7               Essex                 Randstad  non-specified      permanent
# 17                 Uk                 Randstad  non-specified      permanent
# 69             London                 Randstad  non-specified      permanent
# 131    Leicestershire            Fusion People  non-specified      permanent
# ...               ...                      ...            ...            ...
# 50726          London            One Two Trade  non-specified      permanent
# 50727          London          Integral Search  non-specified      permanent
# 50737              Uk  Mayfield Medical Centre      part_time  non-specified
# 50744              Uk                      Rdf  non-specified      permanent
# 50749      Hungerford            non-specified  non-specified  non-specified
#
#                         Category Salary            OpenDate  \
# 5               Engineering Jobs   None 2012-04-24 00:00:00
# 7               Engineering Jobs   None 2013-04-12 00:00:00
# 17              Engineering Jobs   None 2013-12-14 00:00:00
# 69              Engineering Jobs   None 2013-04-04 15:00:00
# 131             Engineering Jobs   None 2013-07-31 12:00:00
# ...                          ...    ...                 ...
# 50726  Accounting & Finance Jobs   None 2013-09-22 12:00:00
# 50727  Accounting & Finance Jobs   None 2013-02-22 12:00:00
# 50737  Healthcare & Nursing Jobs   None 2013-01-06 12:00:00
# 50744                    IT Jobs   None 2013-10-05 15:00:00
# 50749                    IT Jobs   None 2013-09-13 15:00:00
#
#                 CloseDate              SourceName
# 5     2012-05-24 00:00:00    rengineeringjobs.com
# 7     2013-06-11 00:00:00    rengineeringjobs.com
# 17    2014-01-13 00:00:00    rengineeringjobs.com
# 69    2013-06-03 15:00:00    rengineeringjobs.com
# 131   2013-08-30 12:00:00    rengineeringjobs.com
# ...                   ...                     ...
# 50726 2013-10-22 12:00:00  frontofficebanking.com
# 50727 2013-04-23 12:00:00  frontofficebanking.com
# 50737 2013-01-20 12:00:00       jobs.gponline.com
# 50744 2013-11-04 15:00:00  cardandpaymentjobs.com
# 50749 2013-11-12 15:00:00              grb.uk.com
#
# [2497 rows x 11 columns]

# %%
# Get null salary to exclude them
null_salary = df['Salary'].isna()
# Get salary with digits and maybe decimal places to exclude them
salary_w_digit = df[~null_salary]['Salary'].str.fullmatch('\d*\.?\d*',na=False)
# Get invalid salaries
df[~null_salary][~salary_w_digit]
# 36K, /Year, To , per Year invalid values found
# Out:
#              Id                                              Title  \
# 12     67946056      Mobile Senior Mri Radiographer  Central/ East
# 101    69669920                          Software And Systems Test
# 106    67946543      Junior Software Consultant Financial Services
# 320    72247697      Site/Project Manager  Dunstable, Bedfordshire
# 517    69669916  Senior Scientist  Biosimilars Mass Spectrometrist
# ...         ...                                                ...
# 49235  69734297                    Contracts Engineer (Mechanical)
# 49436  69092365                         Ifa  Professional Practice
# 49519  67784900                                   Economic Planner
# 50253  69555936                                Pensions Technician
# 50599  68511184             New Homes Mortgage Protection Advisers
#
#          Location                  Company   ContractType   ContractTime  \
# 12             Uk  Orleston Associates Ltd  non-specified  non-specified
# 101    Birmingham  Orleston Associates Ltd  non-specified  non-specified
# 106     Guildford  Orleston Associates Ltd  non-specified  non-specified
# 320     Dunstable                 Randstad  non-specified       contract
# 517            Uk  Orleston Associates Ltd  non-specified  non-specified
# ...           ...                      ...            ...            ...
# 49235      London  Bluefire Consulting Ltd  non-specified      permanent
# 49436     Belfast        Johnstongreer Ltd      full_time      permanent
# 49519        Kent             Macdonald Co      full_time      permanent
# 50253    Brighton                     Hays  non-specified      permanent
# 50599          Uk   Mortgage Advice Bureau  non-specified      permanent
#
#                         Category          Salary            OpenDate  \
# 12              Engineering Jobs             36K 2013-06-21 12:00:00
# 101             Engineering Jobs      33000/Year 2013-07-19 15:00:00
# 106             Engineering Jobs      40000/Year 2013-08-01 12:00:00
# 320             Engineering Jobs  35480 To 37480 2013-11-22 00:00:00
# 517             Engineering Jobs  30500 To 32500 2013-12-10 15:00:00
# ...                          ...             ...                 ...
# 49235           Engineering Jobs      30000/Year 2013-06-17 00:00:00
# 49436  Accounting & Finance Jobs   42500per Year 2013-09-29 12:00:00
# 49519           Engineering Jobs  25000 To 27000 2012-08-02 12:00:00
# 50253  Accounting & Finance Jobs  43000 To 45000 2013-04-17 12:00:00
# 50599  Accounting & Finance Jobs      37500/Year 2012-01-30 12:00:00
#
#                 CloseDate                    SourceName
# 12    2013-07-05 12:00:00          rengineeringjobs.com
# 101   2013-08-02 15:00:00          rengineeringjobs.com
# 106   2013-08-15 12:00:00          rengineeringjobs.com
# 320   2013-12-06 00:00:00          rengineeringjobs.com
# 517   2014-01-09 15:00:00          rengineeringjobs.com
# ...                   ...                           ...
# 49235 2013-09-15 00:00:00              londonjobs.co.uk
# 49436 2013-10-29 12:00:00                    nijobs.com
# 49519 2012-10-01 12:00:00   jobs.planningresource.co.uk
# 50253 2013-05-17 12:00:00  professionalpensionsjobs.com
# 50599 2012-04-29 12:00:00           ifaonlinejobs.co.uk
#
# [460 rows x 11 columns]

# %%
# Exclude previously found values to get more different invalid values
invalid_salary1 = df[~null_salary]['Salary'].str.contains(r'Year|To|K')
df[~null_salary][~invalid_salary1 & ~salary_w_digit]
# ~, per Hour,- invalid values found
# Out:
#              Id                                            Title  \
# 2124   67904794                         Cisco Network Consultant
# 3776   69001894                                 Vending Operator
# 3780   70764179               Rgn Sexual Health, Family Planning
# 3795   69560030  Aluminium Fabricators Required  Immediate Start
# 4021   68217483         Mechanical Maintenance Engineer / Fitter
# ...         ...                                              ...
# 45103  69868543                 Associate Transportation Planner
# 45521  71911455           Ks**** Primary Teacher North Leicester
# 46432  69035071          Primary Supply Teachers Ks**** & Ks****
# 47289  67770221     Design Engineer  Autocad  Electrical Designs
# 48722  71888673               Conceptual Designer / Art Director
#
#              Location                   Company   ContractType   ContractTime  \
# 2124         The City       Jam Recruitment Ltd  non-specified      permanent
# 3776               Uk                      Fmcv      part_time  non-specified
# 3780             Kent    Support Services Group      part_time  non-specified
# 3795   Great Yarmouth      Workshop Recruitment  non-specified       contract
# 4021           London     Randstad Construction  non-specified       contract
# ...               ...                       ...            ...            ...
# 45103              Uk  Resourcing Solutions Ltd  non-specified      permanent
# 45521    Loughborough             non-specified  non-specified       contract
# 46432        Brighton          Capita Education      part_time       contract
# 47289          Witham             non-specified  non-specified  non-specified
# 48722          London                    Become      full_time      permanent
#
#                                Category          Salary            OpenDate  \
# 2124                            IT Jobs  49000 ~  51000 2013-04-05 00:00:00
# 3776        Hospitality & Catering Jobs        9.99 p/h 2012-07-20 00:00:00
# 3780          Healthcare & Nursing Jobs  14.43 per Hour 2012-05-30 00:00:00
# 3795                   Engineering Jobs   30680 ~ 32680 2013-11-12 12:00:00
# 4021                   Engineering Jobs   26840 ~ 28840 2013-12-01 15:00:00
# ...                                 ...             ...                 ...
# 45103                  Engineering Jobs  29000 ~  31000 2012-10-02 15:00:00
# 45521                     Teaching Jobs  25400 ~  27400 2013-03-02 12:00:00
# 46432                     Teaching Jobs  12.36 per Hour 2012-12-28 00:00:00
# 47289                  Engineering Jobs  26000 -  28000 2013-03-09 15:00:00
# 48722  PR, Advertising & Marketing Jobs   39000 ~ 41000 2012-04-20 15:00:00
#
#                 CloseDate             SourceName
# 2124  2013-07-04 00:00:00       cv-library.co.uk
# 3776  2012-09-18 00:00:00       cv-library.co.uk
# 3780  2012-06-29 00:00:00       cv-library.co.uk
# 3795  2014-01-11 12:00:00       cv-library.co.uk
# 4021  2013-12-15 15:00:00       cv-library.co.uk
# ...                   ...                    ...
# 45103 2012-12-01 15:00:00      justengineers.net
# 45521 2013-03-16 12:00:00             hays.co.uk
# 46432 2013-01-11 00:00:00  jobs.newstatesman.com
# 47289 2013-04-08 15:00:00   britishjobsonthe.net
# 48722 2012-06-19 15:00:00    Brand Republic Jobs
#
# [110 rows x 11 columns]

# %%
# Exclude previously found values to get more different invalid values
invalid_salary2 = df[~null_salary]['Salary'].str.contains(r'~|[Hh]our|\-')
df[~null_salary][~invalid_salary1 & ~salary_w_digit & ~invalid_salary2]
#p/h invalid values found, nothing else
# Out:
#              Id                                              Title  \
# 3776   69001894                                   Vending Operator
# 4892   70758515  Part Time Home Based Compliance Support Consul...
# 9524   69214043  Performing Arts Drama Music Art Qts Supply Tea...
# 26028  68363853                             Care Worker Job Surrey
# 28138  71091672           Health Visitor (Dn**** Area)  Nottingham
# 29766  68347305  Marketing Executive (Financial Services / Tech...
# 40272  69150013                                    Esol **** Posts
# 40346  71600933   Senior Training Officer, Safe Guarding In School
# 40836  69960958           Part Time Tutor In New Media Development
# 44220  69731349                        Careers & Employment Worker
#
#          Location                            Company ContractType  \
# 3776           Uk                               Fmcv    part_time
# 4892   Birmingham  Compliance Resource Solutions Ltd    part_time
# 9524     Tamworth                  Aspire People Ltd    part_time
# 26028   Guildford                      non-specified    part_time
# 28138  Nottingham                      The A24 Group    part_time
# 29766      London                 Easywebrecruitment    part_time
# 40272   Leicester                Cmt Uk Pedagogy Ltd    part_time
# 40346      London         Wandsworth Borough Council    part_time
# 40836      Bangor                  Bangor University    part_time
# 44220          Uk                      non-specified    part_time
#
#         ContractTime                          Category     Salary  \
# 3776   non-specified       Hospitality & Catering Jobs   9.99 p/h
# 4892   non-specified         Accounting & Finance Jobs  15.09 p/h
# 9524       permanent                     Teaching Jobs  13.79 p/h
# 26028  non-specified         Healthcare & Nursing Jobs  12.48 p/h
# 28138  non-specified         Healthcare & Nursing Jobs  14.61 p/h
# 29766  non-specified  PR, Advertising & Marketing Jobs  15.33 p/h
# 40272  non-specified                     Teaching Jobs  14.71 p/h
# 40346  non-specified                     Teaching Jobs   9.38 p/h
# 40836  non-specified                     Teaching Jobs  14.57 p/h
# 44220  non-specified                     Teaching Jobs   11.0 p/h
#
#                  OpenDate           CloseDate        SourceName
# 3776  2012-07-20 00:00:00 2012-09-18 00:00:00  cv-library.co.uk
# 4892  2012-12-09 15:00:00 2013-01-08 15:00:00  cv-library.co.uk
# 9524  2013-09-09 00:00:00 2013-10-09 00:00:00       fish4.co.uk
# 26028 2013-09-23 15:00:00 2013-11-22 15:00:00    careworx.co.uk
# 28138 2013-07-07 00:00:00 2013-07-21 00:00:00    staffnurse.com
# 29766 2012-07-22 15:00:00 2012-08-05 15:00:00     jobsite.co.uk
# 40272 2012-01-31 00:00:00 2012-03-01 00:00:00    Jobcentre Plus
# 40346 2012-06-22 15:00:00 2012-07-22 15:00:00    Jobcentre Plus
# 40836 2012-04-18 00:00:00 2012-06-17 00:00:00    Jobcentre Plus
# 44220 2013-09-28 15:00:00 2013-10-12 15:00:00   jobstoday.co.uk

# %% [markdown]
# From the 3 cells above, it can be seen that 'Salary' comes in formats like
# <ul>
# <li>XX p/h</li>
# <li>XX - XX</li>
# <li>XX To XX</li>
# <li>XX ~ XX</li>
# <li>XXk</li>
# <li>XX /Year</li>
# <li>XX per Year</li>
# <li>XX per Hour</li>
# </ul>
#
# All these values would be reformatted to its correct value

# %%
# Function to reformat 'Salary'
def col_salary(data):
    range_values = r'(\d*\.?\d*)\s*(?:[tT]o|~|\-)\s*(\d*\.?\d*)'
    per_year = r'^(\d+)\s?(?:per|/)\s?[yY]ear$'
    k_salary = r'(\d*\.?\d*)[kK]'
    per_hour = r'(\d*\.?\d*)\s*p(?:/|er)\s*[hH](?:our)?'
    if data == 'None':
        return None
    else:
        # Yearly
        if re.fullmatch(per_year,data):
            floats = [float(x) for x in re.match(per_year,data).groups()]
            return str(floats[0])
        # Range values
        elif re.fullmatch(range_values,data):
            floats = [float(x) for x in re.match(range_values,data).groups()]
            return str(sum(floats)/2)
        # Values with K
        elif re.fullmatch(k_salary,data):
            floats = [float(x) for x in re.match(k_salary,data).groups()]
            return str(floats[0]*1000)
        # Salary per hour
        elif re.fullmatch(per_hour,data):
            floats = [float(x) for x in re.match(per_hour,data).groups()]
            return str(floats[0]*37.5*52)
        else: 
            # Print and return he data if it was not correctly processed
            if not re.fullmatch(r'\d*\.?\d*',data):
                # Data not filtered by regex
                print(data)
            else:
                return data

# %%
# Record to error dict
for row in df.index:
    val = df['Salary'][row]
    if val != None:
        new_val = col_salary(df['Salary'][row])
        if val != new_val:
            fix = 'Change '+str(val)+' To '+str(new_val)
            errorDict = addToErrorDict(errorDict,row,df['Id'][row],'Salary',val,new_val,'Incorrect Format',fix)

# %%
# Format salary using the function col_salary
df['Salary'] = df['Salary'].apply(lambda x: col_salary(str(x)))

# %%
valid_salary = df['Salary'].str.fullmatch('\d*\.?\d*',na=False)
df[~df['Salary'].isna()][~valid_salary]
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2328\1645166485.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[~df['Salary'].isna()][~valid_salary]
# Empty DataFrame
# Columns: [Id, Title, Location, Company, ContractType, ContractTime, Category, Salary, OpenDate, CloseDate, SourceName]
# Index: []

# %% [markdown]
# From the output above, it can be seen that all values of Salary are in the correct format, with none values as none and others as numeric values. Since all are in the correct format now, we will convert "Salary" into numeric values with 2 decimal places

# %%
df['Salary'] = pd.to_numeric(df['Salary'])
df['Salary'] = df['Salary'].round(2)
errorDict = addToErrorDict(errorDict,'ALL','ALL','Salary','String','Numeric','Incorrect format','Switch to numeric format')

# %% [markdown]
# From here, we are done converting Salary column into numeric values

# %% [markdown]
# ### Task 2.11 Checking for duplicates

# %% [markdown]
# Lastly, let's check for and drop duplicates

# %%
df[df.duplicated(['Company','ContractType','ContractTime','Salary','OpenDate','Location'],keep=False)]
# Out:
#              Id             Title         Location Company ContractType  \
# 50677  60905059   Pricing Analyst  Gloucestershire   Jobg8    full_time
# 50679  71295301  Pricing Analyst   Gloucestershire   Jobg8    full_time
#
#       ContractTime                   Category   Salary            OpenDate  \
# 50677    permanent  Accounting & Finance Jobs  35000.0 2012-02-05 15:00:00
# 50679    permanent  Accounting & Finance Jobs  35000.0 2012-02-05 15:00:00
#
#                 CloseDate         SourceName
# 50677 2012-05-05 15:00:00  jobsfinancial.com
# 50679 2012-05-05 15:00:00  jobsfinancial.com

# %%
duplicates = df.duplicated(['Company','ContractType','ContractTime','Salary','OpenDate','Location'])
for ind in df.index[duplicates]:
    errorDict = addToErrorDict(errorDict,'ALL',df['Id'][ind],'ALL','ALL','ALL','Duplicated values','Removed duplicated values')
df.drop_duplicates(['Company','ContractType','ContractTime','Salary','OpenDate','Location'],inplace=True)

# %% [markdown]
# Now, let's move on to Salary imputation

# %% [markdown]
# ### Task 2.12 Salary Imputation

# %%
df['Salary'].describe().round(2)
# Out:
# count       48252.00
# mean        34884.87
# std         66100.50
# min          5000.00
# 25%         23000.00
# 50%         31200.00
# 75%         42500.00
# max      10000000.00
# Name: Salary, dtype: float64

# %%
# Get box plot stats of salary
salaries = df['Salary'][~np.isnan(df['Salary'])]
stats = boxplot_stats(salaries)
stats
# Out:
# [{'mean': 34884.87406739617,
#   'iqr': 19500.0,
#   'cilo': 31060.627655994584,
#   'cihi': 31339.372344005416,
#   'whishi': 71500.0,
#   'whislo': 5000.0,
#   'fliers': array([87500., 80000., 77500., ..., 93600., 90000., 90000.]),
#   'q1': 23000.0,
#   'med': 31200.0,
#   'q3': 42500.0}]

# %% [markdown]
# It seems like outliers are approximately 70k to 90k. Let's filter these values out

# %%
# Lower bound of valid salary
more = df['Salary'] > stats[0]['whislo']
# Upper bound of valid salary
fil = df['Salary'] < 80000

# %%
# Get data with no salaries
df[df['Salary'].isna()]
# Out:
#              Id                                              Title  \
# 5      67944712                        Theatre Lead/Deputy Manager
# 7      68346203  Test Analyst  Join A Leading Fund Manager  Ess...
# 17     70519783                  Water Quality Engineer  Middlesex
# 69     67945892                 Senior Structural Engineer  London
# 131    66905220                   Business Development Manager  Fm
# ...         ...                                                ...
# 50726  68718953                        Trainee Broker Ote Uncapped
# 50727  71802817                              Tax Reporting Manager
# 50737  69693532            Locum Gp With Potential For Partnership
# 50744  71280413   Project Manager / Payments (Essential) / Watford
# 50749  72420369              Graduate Operations Technical Analyst
#
#              Location                  Company   ContractType   ContractTime  \
# 5                  Uk  Orleston Associates Ltd  non-specified  non-specified
# 7               Essex                 Randstad  non-specified      permanent
# 17                 Uk                 Randstad  non-specified      permanent
# 69             London                 Randstad  non-specified      permanent
# 131    Leicestershire            Fusion People  non-specified      permanent
# ...               ...                      ...            ...            ...
# 50726          London            One Two Trade  non-specified      permanent
# 50727          London          Integral Search  non-specified      permanent
# 50737              Uk  Mayfield Medical Centre      part_time  non-specified
# 50744              Uk                      Rdf  non-specified      permanent
# 50749      Hungerford            non-specified  non-specified  non-specified
#
#                         Category  Salary            OpenDate  \
# 5               Engineering Jobs     NaN 2012-04-24 00:00:00
# 7               Engineering Jobs     NaN 2013-04-12 00:00:00
# 17              Engineering Jobs     NaN 2013-12-14 00:00:00
# 69              Engineering Jobs     NaN 2013-04-04 15:00:00
# 131             Engineering Jobs     NaN 2013-07-31 12:00:00
# ...                          ...     ...                 ...
# 50726  Accounting & Finance Jobs     NaN 2013-09-22 12:00:00
# 50727  Accounting & Finance Jobs     NaN 2013-02-22 12:00:00
# 50737  Healthcare & Nursing Jobs     NaN 2013-01-06 12:00:00
# 50744                    IT Jobs     NaN 2013-10-05 15:00:00
# 50749                    IT Jobs     NaN 2013-09-13 15:00:00
#
#                 CloseDate              SourceName
# 5     2012-05-24 00:00:00    rengineeringjobs.com
# 7     2013-06-11 00:00:00    rengineeringjobs.com
# 17    2014-01-13 00:00:00    rengineeringjobs.com
# 69    2013-06-03 15:00:00    rengineeringjobs.com
# 131   2013-08-30 12:00:00    rengineeringjobs.com
# ...                   ...                     ...
# 50726 2013-10-22 12:00:00  frontofficebanking.com
# 50727 2013-04-23 12:00:00  frontofficebanking.com
# 50737 2013-01-20 12:00:00       jobs.gponline.com
# 50744 2013-11-04 15:00:00  cardandpaymentjobs.com
# 50749 2013-11-12 15:00:00              grb.uk.com
#
# [2497 rows x 11 columns]

# %% [markdown]
# These null values as well as values out of range would be used for imputation

# %%
# Set values out of range as None
df.loc[~fil,'Salary'] = None
df.loc[~more,'Salary'] = None
df[df['Salary'].isna()]
# Out:
#              Id                                              Title  \
# 5      67944712                        Theatre Lead/Deputy Manager
# 7      68346203  Test Analyst  Join A Leading Fund Manager  Ess...
# 17     70519783                  Water Quality Engineer  Middlesex
# 69     67945892                 Senior Structural Engineer  London
# 131    66905220                   Business Development Manager  Fm
# ...         ...                                                ...
# 50727  71802817                              Tax Reporting Manager
# 50730  69815649                           Futures Dma Desk Support
# 50737  69693532            Locum Gp With Potential For Partnership
# 50744  71280413   Project Manager / Payments (Essential) / Watford
# 50749  72420369              Graduate Operations Technical Analyst
#
#              Location                  Company   ContractType   ContractTime  \
# 5                  Uk  Orleston Associates Ltd  non-specified  non-specified
# 7               Essex                 Randstad  non-specified      permanent
# 17                 Uk                 Randstad  non-specified      permanent
# 69             London                 Randstad  non-specified      permanent
# 131    Leicestershire            Fusion People  non-specified      permanent
# ...               ...                      ...            ...            ...
# 50727          London          Integral Search  non-specified      permanent
# 50730          London                    Agora  non-specified      permanent
# 50737              Uk  Mayfield Medical Centre      part_time  non-specified
# 50744              Uk                      Rdf  non-specified      permanent
# 50749      Hungerford            non-specified  non-specified  non-specified
#
#                         Category  Salary            OpenDate  \
# 5               Engineering Jobs     NaN 2012-04-24 00:00:00
# 7               Engineering Jobs     NaN 2013-04-12 00:00:00
# 17              Engineering Jobs     NaN 2013-12-14 00:00:00
# 69              Engineering Jobs     NaN 2013-04-04 15:00:00
# 131             Engineering Jobs     NaN 2013-07-31 12:00:00
# ...                          ...     ...                 ...
# 50727  Accounting & Finance Jobs     NaN 2013-02-22 12:00:00
# 50730  Accounting & Finance Jobs     NaN 2013-06-13 15:00:00
# 50737  Healthcare & Nursing Jobs     NaN 2013-01-06 12:00:00
# 50744                    IT Jobs     NaN 2013-10-05 15:00:00
# 50749                    IT Jobs     NaN 2013-09-13 15:00:00
#
#                 CloseDate              SourceName
# 5     2012-05-24 00:00:00    rengineeringjobs.com
# 7     2013-06-11 00:00:00    rengineeringjobs.com
# 17    2014-01-13 00:00:00    rengineeringjobs.com
# 69    2013-06-03 15:00:00    rengineeringjobs.com
# 131   2013-08-30 12:00:00    rengineeringjobs.com
# ...                   ...                     ...
# 50727 2013-04-23 12:00:00  frontofficebanking.com
# 50730 2013-08-12 15:00:00  frontofficebanking.com
# 50737 2013-01-20 12:00:00       jobs.gponline.com
# 50744 2013-11-04 15:00:00  cardandpaymentjobs.com
# 50749 2013-11-12 15:00:00              grb.uk.com
#
# [3519 rows x 11 columns]

# %% [markdown]
# Now its time to build a model and impute on the empty values!

# %%
# Use attributes such as 'ContractTime','ContractType' and 'Category' for training the model
dataset = df[fil&more][['Salary','ContractTime','ContractType','Category']]

# Use pd.get_dummies to turn categorical values into numerical ones
dataset = pd.get_dummies(dataset)
# encoder = LabelEncoder()

# Get columns of dataset that is not Salary
cols_xsalary = [col for col in list(dataset.columns) if col !='Salary']

# Split dataset into training and testing
X_train_xna, X_test, y_train_xna, y_test = train_test_split(dataset.loc[:,cols_xsalary],dataset.loc[:,['Salary']],random_state=123)

# Use Decision Tree Regressor for this dataset
dtr_xna = DecisionTreeRegressor()
dtr_xna.fit(X_train_xna,y_train_xna)

print('r-squared for Salary fitting = ',dtr_xna.score(dataset[cols_xsalary],dataset['Salary']).round(2))
# Out:
# r-squared for Salary fitting =  0.23

# %%
# Set out of range values as none
df.loc[~fil,'Salary'] = None
df.loc[~more,'Salary'] = None

# %%
# Get data with null salary
imputed_salaries_na = df[df['Salary'].isna()][['Salary','ContractTime','ContractType','Category']].copy() 
imputed_salaries_na = pd.get_dummies(imputed_salaries_na)

# Get prediction from the trained model
imputed_salaries_na.loc[:,'Salary']  = dtr_xna.predict(imputed_salaries_na.drop(['Salary'],axis=1))
imputed_salaries_na.loc[:,'Salary']

# Combine the predicted values with the existing dataset to form a full training set
X_train = pd.concat([X_train_xna,imputed_salaries_na[cols_xsalary]])
X_train

y_train = pd.concat([y_train_xna,imputed_salaries_na.loc[:,['Salary']]])
y_train.shape

# Train model on newly created model
dtr = DecisionTreeRegressor()
dtr.fit(X_train,y_train)

print('r-squared for Decision Tree Regressor = ',dtr.score(X_test,y_test))
# Out:
# r-squared for Decision Tree Regressor =  0.23333770409825338

# %%
df.loc[df['Salary'].isna(),'Salary'] = imputed_salaries_na['Salary']
df[df['Salary'].isna()]
# Out:
# Empty DataFrame
# Columns: [Id, Title, Location, Company, ContractType, ContractTime, Category, Salary, OpenDate, CloseDate, SourceName]
# Index: []

# %% [markdown]
# After imputation, it can be seen that every row of data has a salary value!

# %% [markdown]
# ### Task 2.13 Final Format Checking

# %% [markdown]
# Before saving the file, let's convert everything to its correct format

# %%
# Convert object columns into strings
errorDict = addToErrorDict(errorDict,'ALL','ALL','Title,Location,Company,ContractType,ContractTime,Category,SourceName','Object','String','In Object format','Convert to String format')
df[['Title','Location','Company','ContractType','ContractTime','Category','SourceName']] = df[['Title','Location','Company','ContractType','ContractTime','Category','SourceName']].astype('string')

# %%
# Check namings and data types of each column
df.dtypes
# Out:
# Id                       int64
# Title                   string
# Location                string
# Company                 string
# ContractType            string
# ContractTime            string
# Category                string
# Salary                 float64
# OpenDate        datetime64[ns]
# CloseDate       datetime64[ns]
# SourceName              string
# dtype: object

# %%
df['ContractType'].value_counts()
# Out:
# non-specified    37883
# full_time        11283
# part_time         1583
# Name: ContractType, dtype: Int64

# %%
df['ContractTime'].value_counts()
# Out:
# permanent        31052
# non-specified    14001
# contract          5696
# Name: ContractTime, dtype: Int64

# %%
df['Category'].value_counts()
# Out:
# IT Jobs                             13170
# Healthcare & Nursing Jobs            8066
# Engineering Jobs                     7517
# Accounting & Finance Jobs            6770
# Sales Jobs                           4869
# Hospitality & Catering Jobs          4376
# Teaching Jobs                        3455
# PR, Advertising & Marketing Jobs     2526
# Name: Category, dtype: Int64

# %%
# Round string into 2 decimal places
errorDict = addToErrorDict(errorDict,'ALL','ALL','Salary','Unknown decimal places','2 decimal places','Has unknown decimal places','Convert to 2 decimal places')
df['Salary'].round(decimals = 2)
# Out:
# 0        14400.00
# 1        24500.00
# 2        17250.00
# 3        46500.00
# 4        45000.00
#            ...
# 50748    25400.00
# 50749    39340.76
# 50750    36000.00
# 50751    20000.00
# 50752    18000.00
# Name: Salary, Length: 50749, dtype: float64

# %% [markdown]
# Now that all data is supposedly in its right format, its time to save them into a file!

# %% [markdown]
# ## Saving data
# Save the parsed and cleaned data as well as the error list, named as:
# - \<student\_id\>_dataset1_solution.csv
# - \<student\_id\>_errorlist.csv

# %%
# Save cleaned dataset into the csv file, and exclude the index column
df.to_csv('s3936897_dataset1_solution.csv',index=False)

# %%
# errorDict was a dictionary, after all values are inserted, it is converted into a dataframe
# The columns and values are checked before saving into a csv file
errorlist = pd.DataFrame(errorDict)
errorlist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76022 entries, 0 to 76021
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   indexOfdf   76022 non-null  object
#  1   Id          76022 non-null  object
#  2   ColumnName  76022 non-null  object
#  3   Original    76022 non-null  object
#  4   Modified    76022 non-null  object
#  5   ErrorType   76022 non-null  object
#  6   Fixing      76022 non-null  object
# dtypes: object(7)
# memory usage: 4.1+ MB

# %%
errorlist.to_csv('s3936897_errorlist.csv')

# %% [markdown]
# ## Summary

# %% [markdown]
# It is unfortunate that the model did very badly, possible ways of improving this could include position extraction from the title ('Senior','Junior','Graduate').

# %% [markdown]
# There are still plenty errors within the dataset that could have been missed, given more time and computing resources, more detailed information extraction is definitely possible
